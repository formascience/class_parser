# %%
import pdfplumber
from statistics import mean


def extract_slides(pdf_path: str,
                   min_avg_len: int = 10,
                   max_lines: int = 20,
                   merge_tol: float = 2.0):
    slides = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            txt = page.extract_text() or ""
            lines = [l for l in txt.splitlines() if l.strip()]
            if not lines:                      # page vide
                continue
            if mean(map(len, lines)) < min_avg_len or len(lines) > max_lines:
                continue

            words = page.extract_words(extra_attrs=["size"], use_text_flow=True)
            # regroupe en lignes
            rows, cur, cur_top = [], [], None
            for w in sorted(words, key=lambda w: w["top"]):
                if cur_top is None or abs(w["top"] - cur_top) <= merge_tol:
                    cur.append(w); cur_top = cur_top or w["top"]
                else:
                    rows.append(cur); cur, cur_top = [w], w["top"]
            if cur: rows.append(cur)

            first5 = rows[:5]
            title = (
                " ".join(w["text"] for w in max(first5,
                                                key=lambda r: mean(w["size"] for w in r)))
                if first5 else f"Slide {page.page_number}"
            )

            slides.append({
                "id": f"SL_{page.page_number:03}",   # <─ identifiant slide
                "title": title,
                "content": txt.strip()
            })
    return slides




slides = extract_slides("./volume/slides/cours_4.pdf")

for slide in slides[:10]:
    print(f"Slide number: {slide['id']}")
    print(f"Slide title: {slide['title']}")
    print(slide["content"])
    print("="*100)
# Out:
# Slide number: SL_001
# Slide title: Biochimie du Gène et de l'Expression Génique
# Biochimie du Gène et de l'Expression Génique
# (13 h cours – 11 chapitres)
# Drs. Pascal Dollé, Didier Devys, Philippe Kastner
# (Institut de Génétique et de Biologie Moléculaire et
# Cellulaire [IGBMC], Parc d'innovation, Illkirch)
# Dr. Jean Muller (Inserm U 1112, Génétique Médicale,
# CRBS, Faculté de Médecine)
# ====================================================================================================
# Slide number: SL_002
# Slide title: 1. Structure et propriétés des acides nucléiques
# P.
# Dollé
# D.
# Devys
# Sommaire / Plan du cours (1)
# 1. Structure et propriétés des acides nucléiques
# 2. Réplication de l'ADN
# 3. Réparation de l'ADN (anomalies et mécanismes de correction)
# 4. Recombinaison de l’ADN (définition, généralités)
# 5. Transcription de l'ADN (synthèse des ARN)
# 6. Modifications (maturation) de l'ARN chez les eucaryotes
# 7. Régulation de la transcription
# 8. Code génétique
# 9. Traduction (synthèse des protéines) P. Kastner
# 10. Organisation et évolution des génomes eucaryotes animaux
# 11. Méthodes en biologie moléculaire et biotechnologie J. Muller
# ====================================================================================================
# Slide number: SL_006
# Slide title: Structure et propriétés des acides nucléiques
# Chapitre 1 :
# Structure et propriétés des acides nucléiques
# Aperçu historique / Définition
# - Le premier acide nucléique est décrit au XIXème siècle : Miescher, un médecin suisse,
# isole en 1869 à partir de leucocytes de pus de plaies une substance riche en phosphore
# nommée nucléine
# - Nature chimique élucidée en 1927 : acide désoxyribonucléique ou ADN,
# polymère d'unités dénommées nucléotides
# Les polynucléotides biologiques sont:
# - le support moléculaire de l'information génétique : ADN, et ARN pour
# certains virus
# - des effecteurs de l'expression de cette information: acide ribonucléique
# ou ARN, groupés en 4 classes principales : ARN ribosomiques (ARNr), ARN
# de transfert (ARNt), ARN messagers (ARNm), autres ARN "non codants"
# NB : texte en italiques : informations complémentaires (non requises pour l'examen)
# ====================================================================================================
# Slide number: SL_007
# Slide title: 1. Les nucléotides
# 1. Les nucléotides
# Un nucléotide résulte de :
# 1°) la condensation d'un ose (pentose) avec une base (hétérocycle azoté),
# qui donne un nucléoside
# 2°) l'estérification de l'ose par l'acide phosphorique produit un nucléotide
# ====================================================================================================
# Slide number: SL_008
# Slide title: 1.1. Les bases azotées
# 1.1. Les bases azotées
# Les dérivés oxy et/ou amino de la pyrimidine et de la purine forment les
# deux familles de bases des nucléotides naturels
# 1.1.1. Bases pyrimidiques
# 4-amino-2-oxy-pyrimidine
# Remarque : les noms courants des bases ne sont pas ceux de la chimie organique, mais font référence à leurs
# conditions de découverte :
# uracile (1885) -> car caractérisé par synthèse chimique de dérivés de l'acide urique
# thymine (1893) -> isolée à partir de thymus de veau
# cytosine (1894) -> "cyto" (cellule – bien qu'isolée aussi à partie de thymus de veau)
# pyrimidine = contraction de "pyridine" et amidine ; pyridine -> du grec pyro = feu car inflammable !
# ====================================================================================================
# Slide number: SL_009
# Slide title: 1.1.2. Bases puriques
# 1.1.2. Bases puriques
# Remarque : les noms courants des bases ne sont pas ceux de la chimie organique, mais font référence à leurs
# conditions de découverte :
# guanine (1844) -> isolée à partir de guano !
# adénine (1885) -> isolée à partir d'extrait de pancréas (aden en grec) de bœuf
# purine : car caractérisée/purifiée à partir d'acide urique ("pure urine" !)
# ====================================================================================================
# Slide number: SL_010
# Slide title: - deux puriques communes aux deux types d'acides nucléique :
# Les nucléotides de l'ADN, comme ceux de l'ARN, comportent principalement
# quatre de ces bases azotées :
# - deux puriques communes aux deux types d'acides nucléique :
# adénine, guanine
# - une pyrimidique commune : cytosine
# - une pyrimidique spécifique : l'uracile pour l'ARN et son dérivé
# méthylé, la thymine pour l'ADN
# ====================================================================================================
# Slide number: SL_011
# Slide title: 5-méthylcytosine
# 1.1.3. Les bases modifiées dans l'ADN ou l'ARN
# - 5-méthylcytosine : dans l'ADN des plantes et animaux, sauf les insectes
# (cf. chapitre 5 : méthylation au niveau de dinucléotides CpG)
# - N6-méthyladénine : présente dans l'ADN des bactéries. Cette méthylation permet
# aux enzymes de restriction de la bactérie de reconnaître son propre ADN vis-à-vis
# d'ADN étrangers (virus).
# - les ARN (principalement ARNt) contiennent diverses bases modifiées ou
# inhabituelles : xanthine (2,6-oxypurine), hypoxanthine (6-oxypurine),
# etc
# (cf. chapitre 9 - Traduction)
# ====================================================================================================
# Slide number: SL_012
# Slide title: 1.1.4. Autres dérivés : molécules d'intérêt biologique et médical
# 1.1.4. Autres dérivés : molécules d'intérêt biologique et médical
# - des dérivés méthylés de la xanthine, sont présents dans notre alimentation
# ou boissons (produits de métabolisme des alcaloïdes végétaux) et/ou ont des
# usages médicaux : caféine, théobromine (un des composés du cacao/chocolat,
# puissant antioxydant), théophylline (présente, comme caféine, dans thé, mais aussi
# médicament : traitement des crises d'asthme – bronchodilatateur, relaxant des muscles
# lisses, vasodilatateur)
# Contrairement à ce que son nom pourrait laisser croire, la théobromine ne comporte pas d'atome de brome : son nom
# dérive du nom scientifique du cacaoyer (Theobroma, étymologiquement "aliment des dieux")
# ====================================================================================================
# Slide number: SL_013
# Slide title: Des analogues des bases sont utilisés :
# Des analogues des bases sont utilisés :
# - comme molécules de marquage expérimental.
# Exemple : 5-bromo-désoxyuridine (BrdU), incorporée à la place des thymines lors de la
# réplication de l'ADN, détectable par immunohistochimie (-> analyses de la multiplication cellulaire)
# (Extrait d'une publication de notre
# équipe de recherche)
# Double marquage BrdU / Drd1 (récepteur
# dopaminergique, marque les neurones
# dopaminergiques en différenciation) sur coupes de
# striatum d'embryon de souris. Certaines cellules sont
# doublement positives (flèches en C4).
# - comme agents thérapeutiques : agissant en compétition avec les bases naturelles, ils
# bloquent la multiplication des bactéries ou virus (antibiotiques, antiviraux), ou la
# mitose (antitumoraux, inhibent la prolifération de cellules à activité mitotique intense)
# Exemple : acyclovir, médicament anti-viral (Herpès) dérivé de la guanine :
# Autre exemple : AZT (azathymidine) :
# voir formule en cours d'enzymologie –
# inhibiteur compétitif de la transcriptase
# inverse du virus VIH (SIDA) : voir plus loin
# ====================================================================================================

# %%
from models import Slides, Content, ContentSection, SectionSlideMapping

formated_slides = []


for slide in slides:
    #-print(type(slide['id']), type(slide['title']), type(slide['content']))
    formated_slides.append(Slides(id=slide['id'], 
                                title=slide['title'],
                                content=slide['content']))

formated_slides
# Out:
# [Slides(id='SL_001', title="Biochimie du Gène et de l'Expression Génique", content="Biochimie du Gène et de l'Expression Génique\n(13 h cours – 11 chapitres)\nDrs. Pascal Dollé, Didier Devys, Philippe Kastner\n(Institut de Génétique et de Biologie Moléculaire et\nCellulaire [IGBMC], Parc d'innovation, Illkirch)\nDr. Jean Muller (Inserm U 1112, Génétique Médicale,\nCRBS, Faculté de Médecine)"),
#  Slides(id='SL_002', title='1. Structure et propriétés des acides nucléiques', content="P.\nDollé\nD.\nDevys\nSommaire / Plan du cours (1)\n1. Structure et propriétés des acides nucléiques\n2. Réplication de l'ADN\n3. Réparation de l'ADN (anomalies et mécanismes de correction)\n4. Recombinaison de l’ADN (définition, généralités)\n5. Transcription de l'ADN (synthèse des ARN)\n6. Modifications (maturation) de l'ARN chez les eucaryotes\n7. Régulation de la transcription\n8. Code génétique\n9. Traduction (synthèse des protéines) P. Kastner\n10. Organisation et évolution des génomes eucaryotes animaux\n11. Méthodes en biologie moléculaire et biotechnologie J. Muller"),
#  Slides(id='SL_006', title='Structure et propriétés des acides nucléiques', content='Chapitre 1 :\nStructure et propriétés des acides nucléiques\nAperçu historique / Définition\n- Le premier acide nucléique est décrit au XIXème siècle : Miescher, un médecin suisse,\nisole en 1869 à partir de leucocytes de pus de plaies une substance riche en phosphore\nnommée nucléine\n- Nature chimique élucidée en 1927 : acide désoxyribonucléique ou ADN,\npolymère d\'unités dénommées nucléotides\nLes polynucléotides biologiques sont:\n- le support moléculaire de l\'information génétique : ADN, et ARN pour\ncertains virus\n- des effecteurs de l\'expression de cette information: acide ribonucléique\nou ARN, groupés en 4 classes principales : ARN ribosomiques (ARNr), ARN\nde transfert (ARNt), ARN messagers (ARNm), autres ARN "non codants"\nNB : texte en italiques : informations complémentaires (non requises pour l\'examen)'),
#  Slides(id='SL_007', title='1. Les nucléotides', content="1. Les nucléotides\nUn nucléotide résulte de :\n1°) la condensation d'un ose (pentose) avec une base (hétérocycle azoté),\nqui donne un nucléoside\n2°) l'estérification de l'ose par l'acide phosphorique produit un nucléotide"),
#  Slides(id='SL_008', title='1.1. Les bases azotées', content='1.1. Les bases azotées\nLes dérivés oxy et/ou amino de la pyrimidine et de la purine forment les\ndeux familles de bases des nucléotides naturels\n1.1.1. Bases pyrimidiques\n4-amino-2-oxy-pyrimidine\nRemarque : les noms courants des bases ne sont pas ceux de la chimie organique, mais font référence à leurs\nconditions de découverte :\nuracile (1885) -> car caractérisé par synthèse chimique de dérivés de l\'acide urique\nthymine (1893) -> isolée à partir de thymus de veau\ncytosine (1894) -> "cyto" (cellule – bien qu\'isolée aussi à partie de thymus de veau)\npyrimidine = contraction de "pyridine" et amidine ; pyridine -> du grec pyro = feu car inflammable !'),
#  Slides(id='SL_009', title='1.1.2. Bases puriques', content='1.1.2. Bases puriques\nRemarque : les noms courants des bases ne sont pas ceux de la chimie organique, mais font référence à leurs\nconditions de découverte :\nguanine (1844) -> isolée à partir de guano !\nadénine (1885) -> isolée à partir d\'extrait de pancréas (aden en grec) de bœuf\npurine : car caractérisée/purifiée à partir d\'acide urique ("pure urine" !)'),
#  Slides(id='SL_010', title="- deux puriques communes aux deux types d'acides nucléique :", content="Les nucléotides de l'ADN, comme ceux de l'ARN, comportent principalement\nquatre de ces bases azotées :\n- deux puriques communes aux deux types d'acides nucléique :\nadénine, guanine\n- une pyrimidique commune : cytosine\n- une pyrimidique spécifique : l'uracile pour l'ARN et son dérivé\nméthylé, la thymine pour l'ADN"),
#  Slides(id='SL_011', title='5-méthylcytosine', content="1.1.3. Les bases modifiées dans l'ADN ou l'ARN\n- 5-méthylcytosine : dans l'ADN des plantes et animaux, sauf les insectes\n(cf. chapitre 5 : méthylation au niveau de dinucléotides CpG)\n- N6-méthyladénine : présente dans l'ADN des bactéries. Cette méthylation permet\naux enzymes de restriction de la bactérie de reconnaître son propre ADN vis-à-vis\nd'ADN étrangers (virus).\n- les ARN (principalement ARNt) contiennent diverses bases modifiées ou\ninhabituelles : xanthine (2,6-oxypurine), hypoxanthine (6-oxypurine),\netc\n(cf. chapitre 9 - Traduction)"),
#  Slides(id='SL_012', title="1.1.4. Autres dérivés : molécules d'intérêt biologique et médical", content='1.1.4. Autres dérivés : molécules d\'intérêt biologique et médical\n- des dérivés méthylés de la xanthine, sont présents dans notre alimentation\nou boissons (produits de métabolisme des alcaloïdes végétaux) et/ou ont des\nusages médicaux : caféine, théobromine (un des composés du cacao/chocolat,\npuissant antioxydant), théophylline (présente, comme caféine, dans thé, mais aussi\nmédicament : traitement des crises d\'asthme – bronchodilatateur, relaxant des muscles\nlisses, vasodilatateur)\nContrairement à ce que son nom pourrait laisser croire, la théobromine ne comporte pas d\'atome de brome : son nom\ndérive du nom scientifique du cacaoyer (Theobroma, étymologiquement "aliment des dieux")'),
#  Slides(id='SL_013', title='Des analogues des bases sont utilisés :', content="Des analogues des bases sont utilisés :\n- comme molécules de marquage expérimental.\nExemple : 5-bromo-désoxyuridine (BrdU), incorporée à la place des thymines lors de la\nréplication de l'ADN, détectable par immunohistochimie (-> analyses de la multiplication cellulaire)\n(Extrait d'une publication de notre\néquipe de recherche)\nDouble marquage BrdU / Drd1 (récepteur\ndopaminergique, marque les neurones\ndopaminergiques en différenciation) sur coupes de\nstriatum d'embryon de souris. Certaines cellules sont\ndoublement positives (flèches en C4).\n- comme agents thérapeutiques : agissant en compétition avec les bases naturelles, ils\nbloquent la multiplication des bactéries ou virus (antibiotiques, antiviraux), ou la\nmitose (antitumoraux, inhibent la prolifération de cellules à activité mitotique intense)\nExemple : acyclovir, médicament anti-viral (Herpès) dérivé de la guanine :\nAutre exemple : AZT (azathymidine) :\nvoir formule en cours d'enzymologie –\ninhibiteur compétitif de la transcriptase\ninverse du virus VIH (SIDA) : voir plus loin"),
#  Slides(id='SL_014', title='1.1.5. Propriétés des bases azotées', content='1.1.5. Propriétés des bases azotées\n* La conjugaison des doubles liaisons (structure cyclique, délocalisation des\nélectrons Π des doubles liaisons) fait que :\n- la molécule est fortement stabilisée dans une configuration plane\n- la molécule existe sous différentes formes tautomères :\nforme cétone <-> forme énol\n(on a aussi pour certaines bases des formes amine <-> imine)\nTautomérie : équilibre impliquant un déplacement de protons'),
#  Slides(id='SL_015', title='cétone', content="à pH 7 (pH physiologique), l'équilibre est très largement en faveur des formes cétone"),
#  Slides(id='SL_016', title="* Spectre d'absorption (photons) :", content='* Spectre d\'absorption (photons) :\ndu fait de la présence des hétérocycles, les bases ont des propriétés\nd\'absorption caractéristique dans l\'ultraviolet :\nA\n(absorbance ou\n"densité optique":\nD.O., mesurée au\nspectrophotomètre)\nRappel :\nDosage des protéines :\nabsorption vers 260-280 nm\ndu fait de la présence d\'AA\naromatiques\nCes propriétés sont utilisées pour la détection et le dosage des acides\nnucléiques en solution (mesure de l\'absorbance à 260 nm)'),
#  Slides(id='SL_017', title='1.1.6. Transformations chimiques des bases', content='1.1.6. Transformations chimiques des bases\n* Dans la cellule a lieu une désamination, "spontanée" mais plus ou moins\nlente, des bases, surtout pour les pyrimidines :\ncytosine à uracile 5-méthylcytosine à thymine\nadénine à hypoxanthine guanine à xanthine\n* Les radiations altèrent les bases (ultraviolet : "pontage" de deux bases\nsuperposées par liaisons covalentes ; rayons X ou gamma : cassure de cycles)\n* Divers agents chimiques réagissent avec les bases (ex : acide nitreux =>\ndésamination oxydative ; radicaux libres : dommages oxydatifs)\nà Des mécanismes de correction interviennent dans la cellule\n(cf. chapitre 3 : Réparation de l\'ADN )'),
#  Slides(id='SL_018', title='1.2. Les nucléosides', content="1.2. Les nucléosides\nUne liaison covalente (liaison N-osidique) lie les bases à un pentose.\nPentose * : ribose dans les acides ribonucléiques (ARN)\n2-désoxyribose dans les acides désoxyribonucléiques (ADN)\nCaractéristiques :\n- l'ose est sous forme hémiacétalique (furanose)\n- l'énantiomère est de la série D\n- l'anomère est en conformation β\n- liaison N-osidique entre le carbone C1 (anomérique) du furanose et\nl'azote N1 des pyrimidines ou N9 des purines *\nExceptions (exemples) : nucléosides de certains microorganismes où l'ose est l'arabinose :\narabinoslycytosine/arabinosyladénosine: traitement anti-herpès/leucémie) ;\nnucléosides inhabituels dans ARNt : uracile lié par son atome C5 = pseudo-uridine (cf. chap. 8)"),
#  Slides(id='SL_019', title='Convention : pour les', content="Convention : pour les\ndistinguer de ceux des\nbases, les atomes C\ndes oses sont\nnumérotés 1', 2', etc"),
#  Slides(id='SL_020', title='Nomenclature :', content='Nomenclature :\nBases azotées Nucléosides Désoxyribonucléosides\n(Pyrimidines)\nCytosine Cytidine 2\'-désoxycytidine\nUracile Uridine 2\'-désoxyuridine\nThymine Thymidine 2\'-désoxythymidine\n(Purines)\nAdénine Adénosine 2\'-désoxyadénosine\nGuanine Guanosine 2\'-désoxyxguanosine\nXanthine Xanthosine\nHypoxanthine Inosine\nRemarques :\nSuffixe "idine" pour nucléosides pyrimidiques; "osine" à puriques\nDans les ADN ou ARN, on peut se référer à la base ou au nucléoside par\nsimple abréviation (initiale) : A, G, T, C, U (I pour inosine)'),
#  Slides(id='SL_021', title='nomenclature internationale Remarque :', content='Remarque : nomenclature internationale (Codes définis par l\'IUPAC)\nUtilisée pour les comparaisons/alignements de séquences -> Détermination de séquences "consensus"\nExemples – seront vus en chapitre 5 :\n* séquence conservée (consensus) d\'un des\néléments importants des promoteurs eucaryotes\n(Inr = Initiator) :\nPyr-Pyr-A-N-(T ou A)-Pyr-Pyr ó YYANWYY\n* autre manière de montrer les séquences\nconsensus : taille des bases proportionnelle à\nleur fréquence\n(exemple de la séquence TATA des promoteurs\neucaryotes :)\nNe pas apprendre par cœur … sera utile si on vous montre de telles séquences "consensus" avec abréviations'),
#  Slides(id='SL_022', title='1.3. Les nucléotides', content="1.3. Les nucléotides\nCe sont des esters-phosphates de nucléosides (condensation alcool-acide).\nNB : outre leur rôle de constituants des acides nucléiques, les nucléotides ont d'autres importantes fonctions\ncellulaires (donneur d'énergie : ATP ; molécule signal : AMP cyclique ; coenzymes : NAD, FAD, CoA ...)"),
#  Slides(id='SL_023', title="Structure des liaisons ester et anhydride d'acide :", content="Structure des liaisons ester et anhydride d'acide :\nRq : à pH physiologique, l'acide phosphorique est ionisé (phosphate) -> porte des\ncharges négatives"),
#  Slides(id='SL_024', title='substrats utilisés pour la biosynthèse des acides nucléiques', content='Nomenclature, et exemples de nucléotides :\nRemarque : les (désoxy)ribonucléosides triphosphate (ATP/dATP, UTP, etc) sont les\nsubstrats utilisés pour la biosynthèse des acides nucléiques'),
#  Slides(id='SL_025', title='2. Les acides nucléiques', content="2. Les acides nucléiques\nCe sont des enchaînements de nucléosides 5'-phosphate par l'intermédiaire de\nliaisons phosphodiester :\nADN :\n- l'ose est le 2'-désoxyribose\n- les bases sont: adénine, guanine (purines), cytosine, thymine (pyrimidines)\nARN :\n- l'ose est le ribose\n- les bases sont: adénine, guanine (purines), cytosine, uracile (pyrimidines) *\n(* + bases inhabituelles dans certains ARN, principalement ARNt - Chapitre 8 )"),
#  Slides(id='SL_026', title='2.1. La liaison phosphodiester', content="2.1. La liaison phosphodiester\n* Schéma général de réaction (Précision / Voir chapitres suivants : ce sont des\nnucléosides 5' triphosphate qui sont utilisés pour la synthèse des ADN ou ARN)\nImplication fondamentale : les chaînes polynucléotidiques sont vectorisées. Par\nconvention on les écrit de gauche à droite, dans le sens extrémité phosphate 5' à\nextrémité 3'"),
#  Slides(id='SL_027', title='2.1. La liaison phosphodiester', content='2.1. La liaison phosphodiester\n* Schéma général de réaction (Précision / Voir chapitres suivants : ce sont des\nnucléosides 5\' triphosphate qui sont utilisés pour la synthèse des ADN ou ARN)\nNB : la présence du groupement OH 2\' du ribose confère un caractère instable\naux liaisons phosphodiester de l\'ARN : les ARN sont plus "facilement" dégradés\n(par diverses enzymes cellulaires, en présence d\'une base forte NaOH...) => les ARN\nsont des molécules plus "fragiles" que les ADN'),
#  Slides(id='SL_028', title='* Représentation schématique simplifiée et abréviations pour écrire des', content='* Représentation schématique simplifiée et abréviations pour écrire des\nchaînes polynucléotidiques\n(di)nucléotide\nExemple d\'un polymère :\n-> La représentation la plus simple ne donnera que les abréviations des bases,\nen respectant le sens vectoriel ("orientation") de la chaîne\nNB : Par convention (ouvrages, articles scientifiques …) , les séquences sont toujours\ndonnées et écrites dans l\'orientation 5\' -> 3\''),
#  Slides(id='SL_029', title='2.2. Structure spatiale des acides désoxyribonucléiques (ADN)', content="2.2. Structure spatiale des acides désoxyribonucléiques (ADN)\n* Résultats expérimentaux : à partir d'ADN purifié (bactéries, cellules\neucaryotes...), on mesure que :\n[A]+[G] = [T]+[C] [Pur] = [Pyr]\nLes fractions molaires des bases sont telles que :\n[A] = [T] et [G] = [C]\n(règle de Chargaff, 1940)"),
#  Slides(id='SL_030', title="- une double hélice formée de deux chaînes d'ADN dont les paires de bases", content='* L\'analyse aux rayons X de cristaux de molécules d\'ADN, réalisée en 1953 par\nCrick, Watson (prix Nobel 1962) et Franklin, a montré la structure tridimensionnelle\nde l\'ADN, dont les caractéristiques sont :\n- une double hélice formée de deux chaînes d\'ADN dont les paires de bases\nsont complémentaires\n- les deux chaînes sont antiparallèles (orientations opposées 5\' -> 3\')\n- les enchaînements oses-phosphates forment les "squelettes" hélicoïdaux\nparallèles extérieurs, les plans des oses étant presque perpendiculaires aux\nplans des bases\n- les plans des bases sont perpendiculaires à l\'axe des hélices, et chacune\ndes bases d\'une chaîne est appariée à celle de l\'autre chaîne par des liaisons\nhydrogène, les deux bases ("paire de bases") étant situées dans un même\nplan\n- les bases appariées sont complémentaires (A-T ou G-C) et sont à l\'intérieur\ndu cylindre central de la double hélice'),
#  Slides(id='SL_031', title='thymine – adénine : par 2 liaisons hydrogène', content='* Appariements des bases (pyrimidines – purines) :\nthymine – adénine : par 2 liaisons hydrogène\ncytosine – guanine : par 3 liaisons hydrogène\n(NB : bases sous forme cétone)'),
#  Slides(id='SL_032', title='* Plusieurs conformations ont été', content="* Plusieurs conformations ont été\ntrouvées. La plus stable et la plus courante\n(conformation B) :\n- enroulement droit (dextrogyre) de\nl'hélice\n- pas de l'hélice (un tour complet) : 3,4 nm\n- 10 paires de bases (pb) par tour\n- rotation du plan des bases : 36°"),
#  Slides(id='SL_033', title='+ image animée', content='+ image animée'),
#  Slides(id='SL_034', title='"Intérieur" de la double hélice', content='"Intérieur" de la double hélice\n(bases azotées) : hydrophobe\n(mais permettant quand même\nl\'établissement de certaines\nliaisons : protéines (chaînes\nlatérales d\'amino acides) / ADN)\nSurface externe (phosphates\nionisés) : hydrophile\n<- Vue dans l\'axe de la double\nhélice : représentation de deux\npaires de bases successives'),
#  Slides(id='SL_035', title="- une double hélice formée de deux chaînes d'ADN dont les paires de bases", content='* L\'analyse aux rayons X de cristaux de molécules d\'ADN, réalisée en 1953 par\nCrick, Watson (prix Nobel 1962) et Franklin, a montré la structure\ntridimensionnelle de l\'ADN, dont les caractéristiques sont :\n- une double hélice formée de deux chaînes d\'ADN dont les paires de bases\nsont complémentaires\n- les deux chaînes sont antiparallèles (orientations opposées 5\' -> 3\')\n- les enchaînements oses-phosphates forment les "squelettes" hélicoïdaux\nparallèles extérieurs, les plans des oses étant presque perpendiculaires aux\nplans des bases\n- les plans des bases sont perpendiculaires à l\'axe des hélices, et chacune\ndes bases d\'une chaîne est appariée à celle de l\'autre chaîne par des liaisons\nhydrogène, les deux bases ("paire de bases") étant situées dans un même\nplan\n- les bases appariées dites complémentaires (A-T ou G-C) sont à l\'intérieur\ndu cylindre de la double hélice'),
#  Slides(id='SL_036', title='* Deux autres conformations', content='* Deux autres conformations\nhélicoïdales (plus rares) existent :\nConformation A : hélice droite plus\ncompacte (car bases inclinées "en biais"\ndans la double hélice), caractéristique de\ncertaines spores bactériennes, et\nd\'hybrides ADN-ARN formés lors de la\nréplication et de la transcription de l\'ADN\nConformation Z : hélice gauche, plus\nétirée en "zigzag" (pas = 4,5 nm; 12\npaires de bases par tour), trouvée in vivo\npour certains segments d\'ADN eucaryote\n(riches en GC, souvent méthylés)\n* La stabilité de la structure de l\'ADN est assurée par les liaisons H entre bases\ncomplémentaires, mais aussi interactions hydrophobes / électrostatiques entre bases\nsuccessives empilées\n* Stabilité ≠ rigidité: l\'ADN peut adopter différentes conformations (surenroulements,\n"empaquetage" chromatinien, boucles ...)'),
#  Slides(id='SL_037', title='2.3. Propriétés des ADN', content='2.3. Propriétés des ADN\n(A) Etat ionique et solubilité\nLes ADN portent de nombreux groupes ionisables (atomes ionisables des\nbases ...). Toutefois, aux pH physiologiques, les bases ne sont pas ionisées et\nne portent aucune charge.\nLe groupe phosphodiester possède une seule fonction acide (pK 1,5 à 2).\nChacun de ces groupes possède donc, à pH physiologique, un seul\ngroupement ionisé => un ADN donné porte un nombre de charges\nnégatives égal au nombre de nucléotides qui le composent'),
#  Slides(id='SL_038', title="- l'ADN est un polyanion, soluble en milieu aqueux", content="- l'ADN est un polyanion, soluble en milieu aqueux\n- la saturation saline des charges négatives + déshydratation alcoolique\n(éthanol) entraîne la précipitation : permet la purification de l'ADN\n- du fait de leurs charges négatives, en champ électrique (électrophorèse),\nles molécules d'ADN migrent vers l'électrode + . Elles peuvent être\nséparées en fonction de leur taille, grâce à des gels (agarose) agissant\ncomme tamis moléculaires :\nmolécules de grande taille -> migration ralentie\nVisualisation\nde l'ADN ?\n-> cf. Chapitre 3\n(Voir TD 4 pour détails - exemple)"),
#  Slides(id='SL_039', title="(B) Dénaturation de l'ADN / Effet sur l'absorbance", content='(B) Dénaturation de l\'ADN / Effet sur l\'absorbance\nDénaturation (d\'un ADN bicaténaire) : séparation des 2 chaînes (brins) de la\ndouble hélice, sans rupture de liaisons phosphodiester\nTempérature élevée => rupture des liaisons hydrogène entre paires de bases\n=> séparation des 2 brins d\'ADN : dénaturation thermique\n(On peut aussi effectuer une dénaturation chimique : urée ou pH alcalin - NaOH)\n* Un refroidissement lent permet le réappariement des brins\n* Refroidissement rapide ne permet pas un réappariement total\nEtapes de "dénaturation/renaturation" sont utilisées en laboratoire:\n- appariement d\'un polynucléotide d\'intérêt (sonde) = hybridation moléculaire\n- réactions de PCR, de séquençage d\'ADN, etc\n(cf. dernier chapitre 11 : "Méthodes en biotechnologie")'),
#  Slides(id='SL_040', title='Tm', content='Température de fusion ou "demi-dénaturation" (Tm,"temperature of\nmelting") : caractéristique d\'un ADN donné\nPeut être déterminée par mesure de l\'absorbtion à 260 nm : en effet, un ADN\nbicaténaire (hélicoïdal) présente une absorption moindre que le même ADN\nsous forme monocaténaire (l\'empilement des bases dans la double hélice diminue\nleurs propriétés d\'absorption)\n=> la séparation des brins entraîne une augmentation de l\'absorption :\nc\'est l\'effet dit "hyperchrome".\nTm = point d\'inflexion de la courbe sigmoïde'),
#  Slides(id='SL_041', title='La détermination du Tm est importante pour les expériences en laboratoire', content='La détermination du Tm est importante pour les expériences en laboratoire\n(diverses techniques d’analyse et/ou de modification des ADN)\n* Tm dépend de la taille des molécules d\'ADN, et de la composition en bases :\npourcentage de (paires de) bases G-C (par rapport au % A-T)\n-> à taille égale, plus un ADN est riche en G-C, plus son Tm sera élevé\nEn pratique: T = 94°C permet de dénaturer des ADN génomiques (humain...)\n* ADN de taille et séquence spécifique (laboratoire) : on peut calculer le Tm\nADN ≤ 20 paires de bases (p.b.) : Tm = (A+T) x 2 + (G+C) x 4\nADN plus longs, pour N p.b.: Tm = [(A+T) x 2 + (G+C) X 4] x (1 + [N-20/20])\n(Des formules plus complexes prennent en compte la concentration ionique Na+)\nExemple : importance de déterminer le Tm des "amorces" (courts ADN simple brin, généralement de\nlongueur ~ 18-20 nucléotides) pour cycles de dénaturation/renaturation des réactions de PCR\n(les techniques de séquençage de l\'ADN impliquent aussi l\'appariement d\'amorces, cf. chap. 11)\n(Exemple : soit une amorce de 18 nucléotides dont 10 [G+C] : Tm calculé = 56°C)'),
#  Slides(id='SL_043', title="(A) Organisation de l'ADN viral -> Virus à ADN", content='(A) Organisation de l\'ADN viral -> Virus à ADN\nLes ADN viraux sont doubles brins et circulaires, au moins pendant la réplication\nMais : différentes conformations possibles dans la particule infectieuse, ex :\nADN double brin circulaire (polyomavirus)\nADN double brin linéaire (herpès virus, adénovirus)\nADN simple brin (parvovirus, certains bactériophages)\nCe matériel génétique est\ngénéralement associé à des\nprotéines qui forment une capside\n(Remarque : le virus de l\'hépatite B est un\nvirus à ADN particulier, qui utilise une étape\nde transcription inverse pour répliquer son\ngénome, après synthèse d\'un ARN "pré-\ngénomique" dans la cellule infectée)\n(encapsidation du génome du bactériophage lambda)'),
#  Slides(id='SL_044', title="(B) Organisation de l'ADN des bactéries", content='(B) Organisation de l\'ADN des bactéries\n-> Le plus souvent un seul chromosome (ADN double brin généralement\ncirculaire), organisé en super-hélices et compacté (associé à des protéines)\npour former le nucléoïde\n-> présence additionnelle de molécules d\'ADN double brin circulaire de\npetite taille : plasmides, en nombre variable (peuvent coder pour la\nrésistance à un antibiotique ; également outils ("vecteurs") en laboratoire pour\nétudier et/ou modifier des ADN d\'intérêt, produire une protéine d\'intérêt, etc)\nSchéma du chromosome d\'E. coli :\nsur-enroulement et organisation\nen nucléoïde'),
#  Slides(id='SL_045', title="(C) Organisation de l'ADN nucléaire des eucaryotes", content="(C) Organisation de l'ADN nucléaire des eucaryotes\n- Plusieurs chromosomes (ADN double brin linéaire), de taille variable\n- Leurs extrémités sont protégées\npar des structures spécifiques,\nvariables selon les espèces\n(repliements, télomères,\nprotéines associées ...)\n- Interactions ADN-protéines\n(dont : histones) (voir chap. 7)\n-> structure chromatinienne\n(nucléosomes ; hétérochromatine et\neuchromatine …)\n=> grande compaction de l'ADN\n(Cf. chapitres ultérieurs : régulation\ntranscriptionnelle...; aussi UE 5 :\ncours Pr. Viville)"),
#  Slides(id='SL_046', title='Vidéo / Animation "How DNA is packaged" : sera montrée en TD', content='Vidéo / Animation "How DNA is packaged" : sera montrée en TD\nhttps://dnalc.cshl.edu/resources/animations/\n(Choisir : "How DNA is Packaged (Advanced)" ; d\'autres vidéos sont disponibles)'),
#  Slides(id='SL_047', title="(D) Organisation de l'ADN mitochondrial", content='(D) Organisation de l\'ADN mitochondrial\n* Dans chaque cellule humaine (excepté gamètes) :\n- un noyau contenant 46 chromosomes (état diploïde : 2 x 22 autosomes + XX ou XY)\n- ~ 100 à 1000 mitochondries avec plusieurs molécules d\'ADN par mitochondrie\n* La molécule d\'ADN mitochondrial :\n- ADN double brin circulaire, ~ 16 000 paires de bases (cf. aussi chapitres 5 et 10)\n- quelques molécules (~ 1 à 15) par mitochondrie\n- 1 à 2 % de la masse totale d\'ADN de la cellule\nMolécules d\'ADN mitochondrial\n* Mode de transmission : généralement, seul l\'ADN mitochondrial maternel est\ntransmis à la descendance\n(Remarque : les mitochondries ont vraisemblablement évolué par endosymbiose : une cellule "pré-eucaryote" anaérobie\naurait phagocyté une cellule procaryote aérobie, ancêtre de la mitochondrie)'),
#  Slides(id='SL_048', title='2.5. Les acides ribonucléiques (ARN) : structure et organisation', content='2.5. Les acides ribonucléiques (ARN) : structure et organisation\n(Notions générales - Détails seront traités en cours ultérieurs et enseignements spécialisés)\n(A) ARN génomiques viraux -> Virus à ARN\n* Les ARN viraux sont linéaires et simple brin (très rares virus à ARN double\nbrin)\n* Deux types de réplication pour les\nvirus à ARN :\n- réplication par l’ARN (enzyme : ARN\npolymérase ARN-dépendante, codée par le\ngénome viral)\nExemples : virus de la grippe, de la\npoliomyélite, des hépatites A et C,\ncoronavirus'),
#  Slides(id='SL_049', title='2.5. Les acides ribonucléiques (ARN) : structure et organisation', content='2.5. Les acides ribonucléiques (ARN) : structure et organisation\n(Notions générales - Détails seront traités en cours ultérieurs et enseignements spécialisés)\n* Deux types de réplication pour les\nvirus à ARN :\n- réplication par l\'ADN (enzyme :\ntranscriptase inverse *) et par intégration\ndans le génome de l\'hôte : rétrovirus\nExemple : virus du SIDA (HIV, Human\nImmunodeficiency Virus)\n* (cf. Chapitre 2)\nRemarque : des infections ancestrales par rétrovirus ont abouti à la présence d\'un type de séquences répétées\nde notre génome (8% du génome humain, en principe séquences "dormantes") ; on parle de rétrovirus\nendogènes ou endorétrovirus (HERV, human endogenous retroviruses) : cf. chapitre 10'),
#  Slides(id='SL_050', title='(B) ARN procaryotes (bactéries) et eucaryotes', content="(B) ARN procaryotes (bactéries) et eucaryotes\n3 grands types d'ARN: ribosomique (ARNr), de transfert (ARNt), messager (ARNm)\n+ autres ARN fonctionnels chez eucaryotes\nAutres\nARN\n(seulement chez\neucaryotes)\n-> Seront traités dans chapitres suivants (5 à 9)"),
#  Slides(id='SL_052', title='(D) Structure secondaire / tertiaire des ARN', content='(D) Structure secondaire / tertiaire des ARN\n- Sous l\'effet des forces d\'empilement (van der Waals) entre bases successives,\nune molécule d\'ARN tend à former une hélice simple droite irrégulière\n- Des conformations stabilisantes en double hélice se forment entre deux brins\nARN-ADN : transitoirement dans la cellule lors de la réplication et de la\ntranscription de l\'ADN ... ou de manière expérimentale*,\nou dans une molécule d\'ARN lorsque deux segments présentent une\ncomplémentarité suffisante pour un appariement d\'au moins 3-4 paires de\nbases (G-C, A-U)\n=> Motifs de structure secondaire en "épingle à cheveu", ou "tige et boucle"\n(tige = structure en double hélice : cf. hélice A vue précédemment)\n* "hybridation moléculaire" : appariement expérimental entre un ARN (ou ADN) spécifique\nmarqué = sonde et l\'ARN (ou ADN) cellulaire'),
#  Slides(id='SL_053', title='Schéma général de', content="Schéma général de\nstructures secondaires\nadoptées par l'ARN\n(NB : O = base azotée)"),
#  Slides(id='SL_054', title='Exemple :', content="Exemple :\nstructure de\nl'ARNr 16 S *\nd'Escherichia coli\n( : extrémités 5' et\n3' de l'ARN)\n* L'usage a consacré de désigner les\nStructure 3D d'une sous- ARN ribosomiques par leurs\nunité ribosomique 30 S propriétés de sédimentation, liées à\n(Thermus thermophilus) leur masse volumique, et on parle par\nARNr = orange ; protéines =\nexemple d'ARNr 16 S, 23 S, où S est le\nbleu Svedberg (1 S = 10 -13 seconde)"),
#  Slides(id='SL_055', title='ARNt Exemple : structure en feuille de trèfle / en "L" des (secondaire) (tertiaire)', content='Exemple : structure en feuille de trèfle (secondaire) / en "L" (tertiaire) des ARNt\n(cf. chapitres 8, 9 : code génétique, traduction)'),
#  Slides(id='SL_056', title="2.6. L'hydrolyse enzymatique des acides nucléiques", content='2.6. L\'hydrolyse enzymatique des acides nucléiques\nDe nombreuses enzymes catalysent l\'hydrolyse de liaisons phosphodiester\ndes ADN et/ou ARN. Ce sont des phosphodiestérases appelées\n(désoxy)ribonucléases, ou plus simplement nucléases ("DNase, RNase")\nPar définition :\n- exonucléase : hydrolyse à partir de nucléotides en bout de chaîne\n* extrémité 5\' = activité exonucléase 5\' -> 3\'\n* extrémité 3\' = activité exonucléase 3\' -> 5\'\n- endonucléase : hydrolyse de liaisons à l\'intérieur de chaîne(s)\nRemarque : un type particulier d\'endo-désoxyribonucléases procaryotes est appelé enzymes de restriction –\nutilisés en recherche et biotechnologie : cf. chapitre 11'),
#  Slides(id='SL_057', title='*', content="*\nType de coupure :\n(Exemples à ne pas retenir) – Remarque : structure\nd'une RNase montrée en cours d'enzymologie ->\n* Aspergillus : champignon (moisissure) = eucaryote"),
#  Slides(id='SL_058', title="Réplication de l'ADN", content='Chapitre 2 :\nRéplication de l\'ADN\n1. Introduction / Aperçu du cycle cellulaire\n- La vie de la cellule se déroule entre deux mitoses (ou entrée en sénescence /\nmort cellulaire). Le cycle cellulaire, de durée variable, dure en moyenne 30 h\n(mammifères)\n- vers la moitié du cycle commence la réplication de l\'ADN ou phase S :\nsynthèse d\'ADN qui "duplique" le génome d\'une cellule afin de préparer sa\ndivision. Environ 8 h sont nécessaires pour recopier l\'ADN de chaque\nchromosome. Pendant cette phase, la transcription est essentiellement\ninhibée. L\'entrée en phase S engage la cellule vers une nouvelle division.\n- après la phase G2 où chaque gène est représenté en 4 exemplaires (2\nchromatides par chromosome), survient la mitose (traitée en Biologie Cellulaire – UE5)'),
#  Slides(id='SL_059', title='Aperçu schématique du cycle cellulaire :', content='Aperçu schématique du cycle cellulaire :\nLes chromosomes sont dupliqués :\n2n chromosomes\n2 chromatides par chromosome\n= 4 fois chaque gène\nAvant réplication :\n2n chromosomes\n= 2 fois chaque gène\n(sauf pour certains gènes - chromosome Y…)\nè Cellules à multiplication rapide : cycle cellulaire ~ 30 h, la phase S durant ~ 8 h\n(Humain ; chez eucaryotes unicellulaires/levures, peut être ~ 40 minutes)\nS : Synthèse (d\'ADN) ; G : "Gap"'),
#  Slides(id='SL_060', title="2. Principe / notions fondamentales sur la synthèse d'ADN", content='2. Principe / notions fondamentales sur la synthèse d\'ADN\n2.1. Mode de réplication : conservatif ou semi-conservatif ?\nConceptuellement, deux modes sont possibles :\n- "Conservatif" : l\'ADN parental est dupliqué sous forme d\'un ADN double brin néoformé ; après\ndivision, l\'une des cellules filles contient l\'ADN néoformé\n- "Semi-conservatif" : chaque brin d\'ADN sert de matrice pour la synthèse du brin complémentaire.\nL\'ADN/chromosomes des cellules filles contient un brin parental + un brin néoformé\n-> L\'expérience de Meselson et Stahl (1958) a démontré un mode de réplication\nsemi-conservatif'),
#  Slides(id='SL_061', title='2.2. Les unités de réplication', content='2.2. Les unités de réplication (en anglais, "Replicons")\n- Chaque unité est caractérisé par une origine et une terminaison\n- 1 ou plusieurs replicons par génome selon les espèces\nEx : 1 seul pour E. coli ; > 30 000 pour souris, humain (s\'il n\'y avait qu\'un replicon par\nchromosome, il faudrait ~ 800 h pour répliquer l\'ADN)\n- Chaque unité eucaryote est répliquée une fois par cycle cellulaire\n(initiation : rôle de complexes protéiques appelés ORC [origin replication complex] et pre-RC [pre-\nreplicative complex] -> mise en place des protéines hélicase)\nCarte simplifiée du chromosome d\'E. coli Portion de chromosome d\'eucaryote\n(OriC: origine; TerC: terminaison)'),
#  Slides(id='SL_062', title='2.3. La réplication est bidirectionnelle :', content='2.3. La réplication est bidirectionnelle :\n- initiation à l\'origine de réplication\n- progression dans les deux sens\n=> notion de "fourches de réplication", progressant en sens opposés\nMultiples "bulles" de réplication\nsur un chromosome d\'embryon\nVisualisation des fourches de réplication\namphibien (microscopie\nsur un chromosome circulaire\nélectronique à transmission)\n(microscopie électronique à balayage)'),
#  Slides(id='SL_063', title="2.4. Réplication et contraintes physiques/topologiques de l'ADN", content="2.4. Réplication et contraintes physiques/topologiques de l'ADN\n* L'ADN (bactérien ou nucléaire eucaryote) est fortement compacté\n* La dénaturation partielle (nécessaire à la réplication et à la transcription) crée\ndes contraintes supplémentaires : torsion et sur-enroulement de la double hélice\nNoyau de cellule eycaryote : visualisation 3D de\nADN (chromosome) d'E. coli\nl'hétérochromatine (rouge) / euchromatine (bleu\n+ jaune)\nTranscription\nRéplication\nPrecatenates + supercoils - supercoils + supercoils\nEnzymes permettant le relâchement de sur-enroulements : topoisomérases"),
#  Slides(id='SL_064', title='* ADN nucléaire eucaryote :', content='* ADN nucléaire eucaryote :\nla structure chromatinienne\nen nucléosomes, et les\n"marques d\'histones"\n(modifications de certains\namino-acides d\'histones,\nimportantes pour la régulation\nde l\'expression de gènes)*,\ndoivent être remises en\nplace après réplication de\nl\'ADN\nIl existe plusieurs copies des gènes\nd\'histones chez les vertébrés.\nGènes transcrits activement (ce\nqui est très inhabituel) en phase S\ndu cycle cellulaire, permettant la\nsynthèse rapide de nouvelles\nhistones\n(* cf. chapitre 6 "Régulation\ntranscriptionnelle", et UE 5)'),
#  Slides(id='SL_065', title="2.5. Principe de la synthèse – mode d'action des ADN polymérases", content="2.5. Principe de la synthèse – mode d'action des ADN polymérases\nModèle le plus simple\nL'expérience montre\npour la réplication d'un\nqu'il est faux !\nADN bicaténaire :\nDésoxyribonucléoside\ntriphosphate\nLes ADN polymérases (sans exception) parcourent\nle brin matriciel de 3' vers 5' : addition de\nnucléotides sur hydroxyles 3'\nLe brin néosynthétisé s'allonge de 5' vers 3'"),
#  Slides(id='SL_066', title='- par ajout (et appariement) de bases complémentaires à celles', content="Ainsi, la synthèse d'un brin d'ADN se fait :\n- par copie d'un brin matriciel, lu (parcouru) dans le sens 3' à 5'\n- par ajout (et appariement) de bases complémentaires à celles\ndu brin matriciel (-> polymérisation/synthèse de liaisons phosphodiester\nsur hydroxyles (OH) 3'-terminaux du brin synthétisé)\n=> élongation du brin néosynthétisé dans le sens 5' à 3'\n----------------------------------------------------------------------------------------------------------------------------------------------------------------------\nNB : vrai aussi pour les ARN polymérases (synthèse de l'ARN, cf. chapitre 5)\n….. et les transcriptases inverses"),
#  Slides(id='SL_067', title="Ceci implique que la synthèse d'ADN procède de manière discontinue sur", content="Ceci implique que la synthèse d'ADN procède de manière discontinue sur\nl'un des brins : fragments d'Okazaki\n(découverts en 1968)\nde longueur 1000 à 2000 nucléotides (coli), mais seulement 100 à 200 nucléotides chez\nles eucaryotes\nSens de progression de la\nfourche de réplication"),
#  Slides(id='SL_068', title="* 3. La réaction de polymérisation de l'ADN", content='3. La réaction de polymérisation de l\'ADN *\n- La condensation se fait à partir d\'un substrat "activé" : un des\ndésoxyribonucléosides triphosphates. La rupture d\'une liaison riche en énergie\nfournit l\'énergie nécessaire à la condensation\n-> le nucléoside monophosphate restant sera estérifié par une fonction acide de\nson phosphate sur la fonction alcool du carbone 3\' du ribose\n-> le pyrophosphate restant sera rapidement détruit par une pyrophosphatase\n(* Détail du site actif : cf. chapitre 5 -> similitude avec ARN polymérases)\n- NB : inversement, en ajoutant une molécule d\'eau sur cette liaison ester, on\nprovoquera une réaction d\'hydrolyse qui détachera le dernier nucléotide et\nlibérera le carbone 3\' du nucléotide précédent (cf. section 4.3)'),
#  Slides(id='SL_069', title="(l'un des dNTP)", content="(l'un des dNTP)"),
#  Slides(id='SL_070', title='4. Les ADN polymérases', content='4. Les ADN polymérases\n4.1. Types\nBactéries (ex. E. coli) : 3 types\nii\nprincipaux :\nADN polymérases (pol.) I, II, III\nEucaryotes : 5 types principaux\nADN pol. α, β, γ, δ, ε,\ncomposées de plusieurs sous-unités\n(+ autres ADN pol. "spécialisées" dans des\nétapes de la réparation ou dans la synthèse\ntranslésionnelle : cf. chapitre 3)\nModèle de la structure de l\'ADN pol. I de coli (isolée en 1957;\nstructure publiée en 1993 – A. Kornberg, Nobel 1959) :\nmodèle de la "main" enserrant l\'ADN'),
#  Slides(id='SL_071', title='4.2. Rôles', content="4.2. Rôles\nType Localisation Rôle(s)\nE. coli\nADN pol. I Réplication (élimine les amorces ARN), réparation\nADN pol. II Réparation\nADN pol. III Réplication (synthèse brin précoce et tardif)\nHumain\nADN pol. α Noyau Réplication (initiation après action primase)\nADN pol. β Noyau Réparation\nADN pol. γ Mitochondrie Réplication, réparation (ADN mitochondrial *)\nADN pol. δ Noyau Réplication (synthèse brin tardif), réparation\nADN pol. ε Noyau Réplication (synthèse brin précoce),\nréparation\n(* Non traitée - la réplication de l'ADN mitochondrial a plusieurs particularités ; on notera que la pol. γ est\ncodée par un gène nucléaire [chromosome 15], et importée dans la mitochondrie)"),
#  Slides(id='SL_072', title="- d'ADN (mono- ou bicaténaire), apportant la chaîne matricielle", content="4.3. Substrats - conditions d'activité des ADN polymérases\nNécessitent la présence :\n- des quatre désoxyribonucléosides triphosphates (dNTPs)\n- d'ADN (mono- ou bicaténaire), apportant la chaîne matricielle\n=> Les ADN polymérases sont ADN-dépendantes\n- d'un sel de magnésium\n(2 ions Mg++ cofacteurs minéraux dans site actif)\n*\n- d'une amorce : ADN ou ARN, apparié à la chaîne d'ADN matricielle\net dont le dernier nucléotide présente une extrémité 3' OH libre\n----------------------------------------------------------------------------------------------------------------------------------------------------------------------\n* Différence majeure avec les ARN polymérases, qui ne requièrent\npas d'amorce"),
#  Slides(id='SL_073', title='4.4. Activité catalytique additionnelle des ADN polymérases', content='4.4. Activité catalytique additionnelle des ADN polymérases\nLes ADN pol. impliquées dans la réplication ont une activité\nexonucléase 3\' à 5\'\nBrin en synthèse\nSite de polymérisation\nBrin\nSite d\'activité exonucléase\nmatriciel\nPolymérisation Mésappariement -> hydrolyse\nPermet la "correction d\'erreurs" : lorsqu\'un nucléotide incorrect est incorporé\nSite catalytique voisin du site de polymérisation; deux cas de figure :\n* nucléotide correct incorporé : activité polymérase plus rapide que\nl\'exonucléase -> la synthèse continue\n* nucléotide incorrect = mésappariement : l\'activité exonucléase intervient\n-> hydrolyse / excision'),
#  Slides(id='SL_074', title='après réplication -> fiabilité du processus de réplication', content='* Remarque sur les taux d\'erreurs (mauvaises bases incorporées)\naprès réplication -> fiabilité du processus de réplication\nEtape / Mécanisme de correction Erreur par nucléotide\npolymérisé\n5\nPolymérisation 1 pour 10\nCorrection par activité exonucléase 3\'-> 5\' 2\n1 pour 10\nCorrection des mésappariements 2\n1 pour 10\n(mécanisme de réparation post-réplicatif – Chap. 3)\nTaux d\'erreur final 9\n1 pour 10\nCes mécanismes sont indispensables pour assurer un taux d\'erreurs (mutations ->\nmodification du génome) "tolérable" pour la cellule et l\'organisme\nNB : taux d\'erreurs réplication de l\'ADN << transcription (synthèse d\'ARN)\n(cf. chapitre 5)'),
#  Slides(id='SL_075', title='(reverse transcriptase)', content="4.5. Un type très particulier d'ADN polymérase : transcriptase inverse\n(reverse transcriptase)\nADN polymérases ARN-dépendantes : catalysent la polymérisation\nd'un ADN simple brin à partir d'ARN (nécessitent une amorce)\n* caractéristiques de virus à ARN rétrovirus\n* activités transcriptases inverses eucaryotes :\n- télomérase (cf. section 6)\n- transcriptases inverses des\nrétrotransposons (cf. chapitre 10)\nModèle de la structure 3D de la transcriptase inverse du virus HIV ->\n-> Enzymes couramment utilisées en laboratoire :\n- pour rétro-transcrire des ARNm (séquençage, études fonctionnelles)\n- pour technique de RT-PCR (exemple : tests diagnostic Covid-19/SARSCoV2)"),
#  Slides(id='SL_076', title='5. Autres protéines impliquées dans la réplication / Mise en', content="5. Autres protéines impliquées dans la réplication / Mise en\nplace et progression de la fourche réplicative\nDiverses protéines sont nécessaires à la formation et au fonctionnement de la\nfourche de réplication\nVue d'ensemble :"),
#  Slides(id='SL_077', title='5.1. ADN hélicase', content='5.1. ADN hélicase\nActivité enzymatique de séparation et "déroulement" (dénaturation locale)\ndes brins de la double hélice d\'ADN (ATP-dépendant)\nADN hélicase procaryote : structure tridimensionnelle en anneau hexamérique\n-> 6 sous-unités s\'assemblent autour d\'un des brins de l\'ADN (= brins tardifs), au niveau de l\'origine de réplication ;\nelles lient à tour de rôle (2 par 2) et hydrolysent l\'ATP (en rouge), permettant la progression)'),
#  Slides(id='SL_078', title="5.2. ADN primase : synthèse d'amorces pour les ADN polymérases", content='5.2. ADN primase : synthèse d\'amorces pour les ADN polymérases\nActivité d\'ARN polymérase : synthétise un court\nARN, apparié à l\'ADN matriciel (cf. chap. 5 : les ARN\npol. ne requièrent pas d\'amorce; substrats : rNTPs)\nCet ARN sert d\'amorce à une\nADN polymérase, qui prend le relais\nEucaryotes :\n- la primase est associée à l\'ADN\npolymérase α , qui\n(voir schéma suivant, et T.D.)\nsynthétise d\'abord une court segment\nd\'ADN\nPPP\n- puis l\'ADN polymérase ε ou δ se met en\nplace et poursuit la synthèse\n(Primase = terme anglais : amorce se dit "primer" en anglais)'),
#  Slides(id='SL_079', title="Le complexe primase + ADN pol. α est lui-même associé à l'ADN hélicase,", content='(avec ADN pol. a)\nLe complexe primase + ADN pol. α est lui-même associé à l\'ADN hélicase,\net ainsi progressera (le long du brin "tardif") au fur et à mesure du\ndéplacement de la fourche réplicative\nCe complexe moléculaire est désigné sous le terme "primosome"\n(Note : le suffixe "… ome" est souvent employé pour désigner des complexes ou organites cellulaires :\nribosome, spliceosome, nucléosome, endosome, protéasome, etc)'),
#  Slides(id='SL_080', title='5.3. Mise en place du clamp ("collier coulissant")', content='5.3. Mise en place du clamp ("collier coulissant")\nProtéines associées à l\'ADN polymérase (chez E. coli, on les considère comme des sous-\nunités de l\'ADN pol. III ), qui maintiennent la polymérase sur l\'ADN :\nAmorce + ADN synthétisé par pol. a\nADN matriciel simple brin\nA\nB\n(delta ou epsilon)\nStructure 3D du clamp :\nA: Modèle avec ADN (coli)\nB: comparaison clamp de coli et humain (PCNA)'),
#  Slides(id='SL_081', title='5.4. Protéines SSB ("Single strand DNA-binding proteins")', content='5.4. Protéines SSB ("Single strand DNA-binding proteins")\nAffinité pour l\'ADN simple brin : se lient à l\'ADN dénaturé (phénomène\ncoopératif) et stabilisent la conformation de simple brin "déroulé"\nModèles moléculaires / structure 3D de protéine SSB humaine (hétérotrimère de sous-unités "RPA") :\n~8 nucléotides "couverts" par chaque protéine. Dans le modèle du bas, l\'ADN (rouge) est vu de face'),
#  Slides(id='SL_082', title='5.5. Topoisomérases', content='5.5. Topoisomérases\nLe déroulement de l\'ADN crée un surtorsion\ndans la région non dénaturée (surenroulement)\nTopoisomérases : relâchent les contraintes de\ntorsion, en effectuant des coupures réversibles\nde l\'ADN\nsc = "supercoiled" DNA'),
#  Slides(id='SL_084', title='5.6. Mécanisme de dégradation des amorces ARN', content="5.6. Mécanisme de dégradation des amorces ARN\nProcaryotes :\n-> intervention de l'ADN polymérase I : activité d'exonucléase 5' à 3'\nEucaryotes :\n-> intervention de nucléase FEN1 (agit aussi pour réparation de cassures\ndouble brin), et de ribonucléase (ARNase) H\n=> après hydrolyse de l'amorce et remplacement par de l'ADN, il reste\nune brèche simple brin"),
#  Slides(id='SL_085', title='5.7. ADN ligase', content='5.7. ADN ligase\n- "lie" (par liaison phosphodiester) des brins d\'ADN séparés\n- utilise l\'ATP pour activer l\'extrémité 5\' (énergie de synthèse de liaison)\n- agit sur brèches simple brin (réplication, réparation), ou pour lier des ADN\ndouble brin (réparation : cf. chapitre 3 ; utilisation aussi en laboratoire pour réaliser des\n"constructions" d\'ADN : plasmides ou autres vecteurs (exemple : virus recombinants pour thérapie\ngénique, etc)\n(Trois types d\'ADN ligases chez Humain ; l\'une agissant dans noyau et mitochondries)'),
#  Slides(id='SL_086', title='5.8. Résumé :', content='5.8. Résumé :\nSchéma de la chronologie\nde la synthèse du brin\nretardé\n(ici: E. coli)'),
#  Slides(id='SL_087', title="5. 9. Retour à la vue d'ensemble de la fourche de réplication (F.R.) et des", content="5. 9. Retour à la vue d'ensemble de la fourche de réplication (F.R.) et des\ncomplexes moléculaires qui y agissent\nAgencement d'une F.R.\nprocaryote : les molécules\nd'ADN pol. sont associées\ndans un volumineux\ncomplexe\nà\nVisualisation en microscopie\nélectronique du complexe de\nréplication du bactériophage T4"),
#  Slides(id='SL_088', title='eucaryote La fourche réplicative a un agencement similaire,', content='La fourche réplicative eucaryote (ici: mammifère) a un agencement similaire,\nmais les molécules d\'ADN pol. (δ et ε) fonctionnent indépendamment\nε\n-> Quelques mol d\'ADN pol. δ terminent la synthèse de fragments d\'Okazaki "en retard" par rapport\nau brin précoce'),
#  Slides(id='SL_089', title='Télomères – enzyme télomérase', content='6. Réplication des chromosomes eucaryotes :\nTélomères – enzyme télomérase\nLes chromosomes de cellules eucaryotes contiennent à leurs extrémités\ndes séquences répétées appelées télomères,\nse terminant par un segment 3\' simple brin :\nEn leur absence, l\'ADN des chromosomes étant linéaire, il y aurait à chaque\ncycle de réplication un léger raccourcissement de l\'ADN\n(impossibilité de remplacer la dernière amorce du brin tardif par de l\'ADN)\nRemarque : en l\'absence de réplication, l\'extrémité des chromosomes forme une boucle ->\n(boucle télomérique ou "t-loop"), qui protège les extrémités de la dégradation par\nexonucléases'),
#  Slides(id='SL_090', title="Problème du raccourcissement des chromosomes si les télomères/télomérase n'existaient pas", content='Problème du raccourcissement des chromosomes si les télomères/télomérase n\'existaient pas\nInfographie disponible sur le site "The Nobel Prize"\nhttps://www.nobelprize.org/prizes/medicine/2009/illustrated-information/'),
# ...
#  Slides(id='SL_121', title='Xeroderma pigmentosum', content="Xeroderma pigmentosum\n- un des premiers syndromes héréditaires caractérisés sur le plan génétique et\nmoléculaire\n- incidence ~ 1:250 000 aux USA\n- cancers cutanés multiples (surtout basocellulaires) causés par l'exposition solaire;\ndécès par mélanome ou autres cancers métastatiques ; anomalies oculaires\n- principalement dus à l'insuffisance de réparation des dimères de thymine UV-\ninduits\n- divers sous-types, causés par mutations de XPA à G, mais aussi\nPOLH = ADN polymérase êta\nhttp://www.enfantsdelalune.org/ : association pour le Xeroderma Pigmentosum"),
#  Slides(id='SL_123', title='Gènes / mutations BRCA1, BRCA2', content='Gènes / mutations BRCA1, BRCA2\n- en cause dans 5-10% des cancers du sein (totaux) et\n20-25% (avec hérédité) ; également risque de cancer\novarien, et autres (prostate, pancréas...)\n- BRCA1 et 2 ont aussi été appelés FANCS et FANCD1 :\nresponsable d\'anémie de Fanconi (avec tumeurs) si 2\ncopies mutées\n- deux protéines faisant partie du complexe de\nréparation des cassures double brin par recombinaison\nhomologue (BRCA1 agit aussi dans "mismatch repair")\n- diagnostic génétique : certaines mutations BRCA1 ou 2\nà mastectomie / ovariectomie préventives\n(BRCA : breast cancer susceptibility genes)'),
#  Slides(id='SL_124', title='A', content='A\nSource : Hindustan Times, 2015'),
#  Slides(id='SL_125', title="Recombinaison de l'ADN", content='Chapitre 4 :\nRecombinaison de l\'ADN\n(Définition, principes, implications en pathologie… et en recherche)\nIntroduction\nLa recombinaison est une des propriétés fondamentales du matériel génétique :\n- permet le brassage des gènes (échanges gènes maternels et paternels pendant\nrecombinaison méiotique)\n- un des "moteurs" (avec d\'autres mécanismes : transposition, rétrotransposition,\ncf. chapitre 10 ) de l\'évolution des génomes et de l\'adaptabilité des espèces\nDeux grands types de mécanismes de recombinaison :\n1. Recombinaison générale ("recombinaison homologue")\n2. Recombinaison spécifique de site\n(Recombinaison : échange/modification de brins d\'ADN, impliquant une coupure, puis une\nréunion de brins – et aboutissant à des réarrangements des séquences nucléotidiques)'),
#  Slides(id='SL_126', title='1. Recombinaison générale ou homologue', content="1. Recombinaison générale ou homologue\n1.1. Principes généraux et contexte\nPeut se produire en n'importe quel locus (région) chromosomique\n-> chez les bactéries, elle se produit entre diploïdes partiels lors de transferts génétiques tels la\nconjugaison (non traitée). Les mécanismes sont principalement étudiés chez E. coli, et chez des\neucaryotes simples : levures.\n-> chez les eucaryotes (champignons, végétaux et animaux), a lieu avant la première\ndivision méiotique dans les cellules germinales : recombinaison méiotique\n-> peut avoir lieu dans les cellules somatiques : recombinaison mitotique =\nmécanisme de réparation\nLa recombinaison aura lieu (sauf erreur) entre séquences homologues de deux\nchromatides = chromosomes après réplication de leur ADN"),
#  Slides(id='SL_127', title="à échange d'information génétique", content='Recombinaison méiotique : provoquera\nl\'échange de segments d\'ADN par "crossing-\nover" (ou enjambement) : entre chromatides\nà échange d\'information génétique\nChez l\'humain, on estime à\n1 à 5 recombinaisons par\nchromosome et par méiose\n≠ Recombinaison mitotique * : induite\nlors de la réplication si anomalies de\nl\'ADN (ex : cassures double brin...) :\nblocage de la fourche de réplication,\nnécessitant un mécanisme de\nrecombinaison pour leur réparation\n(cf. chapitre 3)\nSchéma : principe de la recombinaison\n* Répare l\'ADN avant la mitose\n(crossing-over) méiotique\nRemarque: la recombinaison méiotique (sera traitée en détail dans l\'UE5) a certainement évolué à partir d\'un\nmécanisme ancestral de recombinaison servant à la réparation de l\'ADN, et qu\'on retrouve dans les\norganismes procaryotes et eucaryotes actuels'),
#  Slides(id='SL_128', title='Application en recherche biomédicale :', content="Application en recherche biomédicale :\non peut induire (provoquer) cette recombinaison homologue entre un ADN\nintroduit dans la cellule, modifié au sein de la région d'homologie, et l'un des\nchromosomes ciblés\n-> introduction de mutations ciblées de gènes dans des organismes modèles\nanimaux (cellules souches embryonnaires de souris) pour étudier la fonction\nde gènes et des protéines qu'ils codent\n(-> Prix Nobel 2007, Evans & Capecchi)"),
#  Slides(id='SL_129', title='1.2. Etapes de la recombinaison homologue', content='1.2. Etapes de la recombinaison homologue\n- Coupure double brin par une endonucléase spécifique\n(dans le cas de la réparation, cette coupure est accidentelle !)\n- Hydrolyse limitée (exonucléase) 5\' à 3\' : extrémités\ndébordantes 3\'\n- L\'une des extrémités s\'apparie (après dénaturation de la\ndouble hélice) à la séquence homologue sur l\'autre ADN\n(protéines impliquées dans le phénomène non schématisées)\n- Appariement de l\'autre extrémité, et synthèse d\'ADN :\n(structure particulière à 4 brins = "molécule de jonction" ou jonction de Holliday)\n- Séparation des brins et ligation *\n*\nDifférence entre recombinaison méiotique ou mitotique\n(ADN polymérases impliquées seraient pol. d ou pol. "inhabituelles")'),
#  Slides(id='SL_130', title='La recombinaison générale implique la recombinase RecA (E. coli), et ses', content='La recombinaison générale implique la recombinase RecA (E. coli), et ses\nhomologues eucaryotes\n* Se fixe de manière coopérative sur l\'ADN simple brin, et forme un appariement entre ce\nbrin et le brin complémentaire sur la molécule d\'ADN homologue : structure "triple brin"\ncomprenant l\'ADN double brin hétéroduplex et l\'ADN simple brin déplacé ("D-loop")\n* Plusieurs homologues de RecA chez mammifères, spécialisés dans la\nrecombinaison méiotique ou mitotique (humain : RAD51, assistée de BRCA2)'),
#  Slides(id='SL_131', title='Différence fondamentale dans la séparation des ADN recombinés lors de la', content='Différence fondamentale dans la séparation des ADN recombinés lors de la\nrecombinaison mitotique (réparatrice) et méiotique ("crossing-over")\n-> Action de protéines spécialisées (non détaillées-non illustrées), distinctes pour les 2 processus\n(Voir chapitre 3)\nMEIOTIQUE\nRéparation de l\'ADN : séparation des Recombinaison méiotique :\nchromatides (sans échange de brins) ... séparation/ligation => échange de\nmais le segment resynthétisé est copié à partir brins = "crossing-over"\ndu chromosome non endommagé\n=> peut entraîner une conversion\n(NB: conversion génique possible aussi)\ngénique/perte d\'hétérozygotie\n-> implications en pathologie/cancer'),
#  Slides(id='SL_132', title='1.3. Anomalies de la recombinaison', content='1.3. Anomalies de la recombinaison\nGénéralement délétères (nocives)\n* Anomalies de la recombinaison méiotique, qui parfois a lieu entre régions de\nséquences similaires, mais pas véritablement homologues = crossing-over inégal\n* Peuvent survenir aussi pendant recombinaison mitotique\n-> Conséquences possibles : perte ou duplication de segments chromosomiques,\nou translocations chromosomiques (si recombinaison entre chromosomes non\nhomologues)\nà Avortements spontanés, syndromes malformatifs\nà Pathologies (leucémies ...)\nMais de telles anomalies peuvent être un moteur de l\'évolution :\n"brassage d\'exons", duplication de gènes ... , parfois bénéfiques (apparition d\'une nouvelle fonction ou\nfonction améliorée) à sélection positive, avantage évolutif pour la population ayant subi le changement\n(cf. chapitre 10 – "Evolution des génomes")'),
#  Slides(id='SL_133', title='Plusieurs types de leucémies ou lymphomes sont caractérisés par des', content='Plusieurs types de leucémies ou lymphomes sont caractérisés par des\nréarrangements chromosomiques spécifiques\nExemple de la translocation t (9,22), responsable de leucémie myéloïde chronique\nChr. 22q-\nappelé "chromosome\nChr. 9\nPhiladelphie" *\nChr. 22 Chr. 9q+\n(Translocation dite réciproque : sans perte de matériel génétique)\n(* Découvert en 1959 par 2 laboratoires, tous 2 à Philadelphie !)'),
#  Slides(id='SL_134', title='La translocation relie les séquences codant pour 2 protéines distinctes', content='La translocation relie les séquences codant pour 2 protéines distinctes\n=> production d\'une protéine dite "chimère", à propriétés oncogéniques\nAbl (Abelson) : récepteur membranaire à activité tyrosine kinase ; Bcr : sérine/thréonine kinase.\nLa protéine chimère a une activité constitutive (indépendante de ses ligands) => stimulation de la division\ncellulaire, inhibition de la réparation – instabilité génomique\nNB : sera aussi au programme de l\'UE5 – 2ème semestre'),
#  Slides(id='SL_135', title='2. Recombinaison spécifique de site', content="2. Recombinaison spécifique de site\nContrairement à la recombinaison homologue, qui nécessite d’assez longues\nséquences chromosomiques homologues, la recombinaison spécifique de site\nimplique des enzymes qui reconnaissent de courtes séquences spécifiques de\nnucléotides = recombinases spécifiques de site\n2.1 : Recombinaisons spécifiques de gènes du système immunitaire\n2.2 : Recherche biomédicale : utilisation d'une recombinase agissant\nnormalement chez procaryotes pour mutagenèse ciblée dans des\nmodèles animaux (souris …)"),
#  Slides(id='SL_136', title='2.1. Recombinaison au niveau des gènes codant pour les anticorps', content='2.1. Recombinaison au niveau des gènes codant pour les anticorps\n(cellules/lymphocytes B), et les récepteurs de surface des lymphocytes T\nExtrait du cours sur les Protéines (Dr Lamour) … -> "complément" de ce cours !'),
#  Slides(id='SL_137', title='la région codant la région variable', content="Dans les gènes codant pour les immunoglobulines : un segment précis code pour la région\nconstante, mais une ou deux réactions de recombinaison d'ADN auront lieu dans\nla région codant la région variable :\n(1°) Chaînes légères : un segment V et un segment J sont reliés par recombinaison d'ADN :\nrecombinaison aléatoire dans chaque cellule précurseur de lymphocyte\nADN du gène\nd'une chaîne légère\nADN après\nrecombinaison\nLes segments colorés sont des exons (cf. chap. 5, 6)\nChez l'humain : ~ 30 segments V (chaîne κ) ; ~ 40 segments V (chaîne λ)\n(Réactions ayant lieu dans les précurseurs de lymphocytes B ou T)"),
#  Slides(id='SL_138', title=': recombinaison', content='(2°) Chaînes lourdes : un segment V, un segment D, un segment J sont liés par 2 étapes de\nrecombinaison :\nADN du gène\nd\'une chaîne lourde\nADN après\nrecombinaisons\n=> Phénomène combinatoire permettant une extrême diversité (> 2 x 106 combinaisons)\n=> la recombinaison V(D)J ne se fait pas au nucléotide près : quelques nucléotides peuvent être\nperdus ou insérés -> ajoute à la diversité\nChez l\'humain : ~ 1000 segments V ("Variable") ; 27 segments D ("Diversity") ; 6 segments J ("Joining")'),
#  Slides(id='SL_139', title="Les recombinases spécifiques de site sont des enzymes s'associant à de", content='Les recombinases spécifiques de site sont des enzymes s\'associant à de\ncourtes séquences spécifiques d\'ADN, et catalysant l\'échange de brins à\nleur niveau.\n-> Les enzymes RAG1, RAG2 ("Recombination-Activating Genes", prix Nobel 1987,\nS. Tonegawa) catalysent les recombinaisons site-spécifiques dans les gènes\ncodant pour les immunoglobulines\n( + autres protéines impliquées dans ce phénomène, dont Artemis [impliquée également dans le\nmécanisme NHEJ] ou l\'ADN ligase IV)\nExemples de recombinases agissant chez procaryotes :\n- chez des bactériophages \'"virus de bactéries" , exemple du bactériophage lambda : une ADN\nintégrase catalyse l\'échange de brins et l\'intégration du génome viral dans une région du\nchromosome bactérien\n-> 2.2 : cas de la recombinase Cre : outil pour les travaux de recherche'),
#  Slides(id='SL_140', title='Cre 2.2. La recombinase', content='2.2. La recombinase appelée Cre est produite normalement par un\nbactériophage. Elle se lie et induit une recombinaison d\'ADN au niveau de\nséquences spécifiques (séquences loxP de 34 paires de bases), importantes pour la\n"multiplication" du phage dans la bactérie\nà le système Cre-loxP est très utilisé pour introduire des mutations ciblées de gènes dans\ndivers modèles d\'étude animaux : en introduisant des séquences loxP (non présentes\nnaturellement) dans la région ciblée. On peut même induire des mutations dites\nsomatiques : ne se produiront que dans un tissu/type cellulaire précis, au cours de la vie de\nl\'animal !\n(Cre : Causes recombination ; loxP : locus of crossing [x] over, phage P1)'),
#  Slides(id='SL_141', title='Mutations somatiques (tissu-spécifiques) ciblées', content='Mutations somatiques (tissu-spécifiques) ciblées\n: principe / schéma général\n<- Ces souris B sont produites à partir\nA B\nde cellules souches embryonnaires\n(cellules ES) dans lesquelles on a\nobtenu le remplacement du gène X\nnormal par sa version "floxée", par\nrecombinaison homologue\nCellule\ndu\nfoie\n* Souris A : porte un transgène (ADN introduit expérimentalement) exprimant la recombinase Cre dans un tissu\nd\'intérêt (promoteur spécifique) – ici le foie\n* Souris B : homozygote pour une version modifiée d\'un gène d\'intérêt : 2 sites loxP flanquent un exon (ou le gène\nentier)… en jargon = souris "floxée"\nPour en savoir plus : vidéo (explique aussi mode d\'action de la recombinase) :\n(Si questions : séance TD 4)\nhttps://www.youtube.com/watch?app=desktop&v=I9M7PY9JAkA'),
#  Slides(id='SL_142', title="Principe de la méthode d'inactivation ciblée", content='Principe de la méthode d\'inactivation ciblée\nde gènes par recombinaison homologue\ndans des cellules souches embryonnaires\n(ES, embryonic stem cells) de souris\nIntroduction dans cellules ES d\'un ADN linéaire modifié,\nporteur de mutation/inactivation du gène d\'intérêt +\nmarqueur(s) de sélection\nDans certaines cellules (événement rare), l\'ADN s\'intègre par\nrecombinaison homologue à la place du gène normal ->\nidentification/sélection des clones de cellules qui l\'ont intégré\nGénération de souris porteuses de la\nmutation d\'intérêt (après injection des cellules\nES mutées dans blastocystes/embryons\nreceveurs, réimplantés dans mères porteuses)\n(ou… "la GPA chez la souris" !)\n=>\n(Pourra être explicité en séance de TD)'),
#  Slides(id='SL_143', title="Certains schémas de ce cours ont été adaptés à partir d'illustrations provenant des ouvrages", content="Certains schémas de ce cours ont été adaptés à partir d'illustrations provenant des ouvrages\nsuivants, conseillés pour y trouver des explications ou notions complémentaires :\n- Biologie moléculaire de la cellule, B. Alberts et al. (Garland science, Flammarion)\n- Chimie, biochimie & biologie moléculaire, sous la dir. de B. Sablonnière (Omniscience)\n- Biologie moléculaire UE1, S. Beaumont (EdiScience)\n- Biochimie et biologie moléculaire, P. Kamoun et al. (Flammarion)\n- Biochimie générale, J-H. Weil (Masson)\nCertaines illustrations sont tirées d'articles scientifiques (refs. sur diapos) ou de l'espace\nnumérique (creative commons licensing)\nMentions légales :\nL'utilisation des documents de cours est strictement réservée à l'usage privé des étudiants inscrits en\nLicence « Sciences pour la Santé » à l'université de Strasbourg. Leur diffusion et/ou mise en réseau\nest strictement réservée à l'université de Strasbourg, et à une association agréée (association\namicale des étudiants en médecine de Strasbourg). Toute autre utilisation, diffusion ou mise en\nréseau est interdite. Ces documents sont interdits à la vente ou à la location, et à tout usage par des\norganismes privés (préparations, etc). L'ensemble de ces documents relève des législations française\net internationale sur le droit d'auteur et la propriété intellectuelle.")]

# %%
import pdfplumber
from statistics import mean

pdf_path = "./volume/slides/cours_4_plan.pdf"

with pdfplumber.open(pdf_path) as pdf:
    slides_dict = {}
    all_text = []

    for page in pdf.pages:
        text = page.extract_text(layout=True)
        # Remove multiple consecutive newlines
        text = '\n'.join(line for line in text.splitlines() if line.strip())
        all_text.append(text)
    
    full_text = '\n'.join(all_text)
    
print(full_text)
# Out:
#                         Chapitre 4 - Réplication et réparation de l’ADN
#           I. STRUCTURE ET PROPRIÉTÉS DES ACIDES NUCLÉIQUES
#           1. Les nucléotides
#                1.1. Les bases azotées
#                       1.1.1. Les bases pyrimidiques
#                       1.1.2. Les bases puriques
#                       1.1.3. Les bases modifiées dans l’ADN et l’ARN
#                       1.1.4. Autres dérivés : molécules d’intérêt biologique et médical
#                       1.1.5. Propriétés des bases azotées
#                       1.1.6. Transformation chimique des bases
#                1.2. Les nucléosides
#                       1.2.1. Le pentose
#                       1.2.2. La liaison osidique
#                       1.2.3. Nomenclature
#                1.3. Les nucléotides
#                       1.3.1. Nomenclature
#                       1.3.2. Nucléotides d’intérêt biologique
#           2. Les acides nucléiques
#                2.1. La liaison phosphodiester
#                2.2. Structure spatiale des acides desoxyribonucléiques (ADN)
#                2.3. Propriétés des ADN
#                      2.3.1. État ionique et solubilité
#                      2.3.2. Dénaturation de l’ADN / Effet sur l’absorbance
#                2.4. Organisation des ADN
#                      2.4.1. Organisation de l’ADN viral
#                      2.4.2. Organisation de l’ADN des bactéries
#                      2.4.3. Organisation de l’ADN nucléaire des eucaryotes
#                      2.4.4. Organisation de l’ADN mitochondrial
#                2.5. Les acides ribonucléiques (ARN): structure et organisation
#                      2.5.1. ARN génomiques viraux
#                      2.5.2. ARN cellulaire (procaryotes et eucaryotes)
#                      2.5.3. Autres ARN fonctionnels eucaryotes - ARN “non codants”
#                      2.5.4. Structure secondaire / tertiaire des ARN
#                2.6. L’hydrolyse enzymatique des acides nucléiques
#           II. RÉPLICATION DE L’ADN
#           1.  Introduction / Aperçu du cycle cellulaire
#           2.  Principe / notions fondamentales sur la synthèse d’ADN
#                2.1. Mode de réplication: conservatif ou semi-conservatif ?
#                2.2. Les unités de réplication (“Réplicons”)
#                2.3. La réplication est bidirectionnelle
#                2.4. Réplication et contraintes physiques
#                2.5. Principe de la synthèse - mode d’action des ADN polymérases
#           3.  La réaction de polymérisation de l’ADN
#                3.1. Mode d'action de l'ADN polymérase
#                3.2. Mécanisme
#           4.  Les ADN polymérases
#                4.1. Types
#                4.2. Rôles
#                4.3. Autres activités catalytiques des ADN polymérases
#           5.  Autres protéines impliquées dans la réplication / Mise en place et progression
#               de la fourche réplicative
#                5.1. Mise en place du “clamp” (collier coulissant)
#                5.2. ADN hélicase
#                5.3. Protéines SSB
#                5.4. Topoisomérase
#                5.5. ADN primase
#                5.6. Mécanisme de dégradation des amorces ARN
#                5.7. ADN ligase
#                5.8. Résumé: schéma de la chronologie de la synthèse du brin retardé
#                5.9. Retour à la vue d’ensemble de la fourche de réplication et des complexes
#                     moléculaires y agissant
#           6.  Réplication des chromosomes eucaryotes: Télomères - enzyme télomérase
#           7.  La réplication est une cible thérapeutique
#           III. RÉPARATION DE L’ADN - Anomalies de l'ADN et mécanismes de correction
#           Introduction
#           1. Anomalies (lésions) de l'ADN
#                1.1. Causes physiques
#                1.2. Agents mutagènes chimiques : exemples
#                1.3. Causes "(patho)physiologiques"
#           2. Mécanismes de correction
#                2.1. Correction immédiate
#                2.2. Réparation par excision de base (BER)
#                2.3. Réparation par excision de nucléotides (NER)
#                2.4. Correction des mésappariements ("Mismatch Repair")
#                2.5. Réparation des coupures double brin
#                2.6. Les ADN polymérases translésionnelles ("DNA damage bypass")
#           3. Syndromes et maladies dus à des défauts de réparation de l'ADN
#           VI. RECOMBINAISON DE L’ADN
#           Introduction
#           1. Recombinaison générale ou homologue
#                1.1. Principes généraux et contexte
#                1.2. Étapes de la recombinaison homologue
#                1.3. Anomalies de la recombinaison
#           2. Recombinaison spécifique de site
#                2.1. Recombinaisons spécifiques de gènes du système immunitaire
#                2.2. La recombinase appelée Cre est produite normalement par un bactériophage.

# %%
from models import Content, ContentSection, SectionSlideMapping
from typing import List, Dict, Optional

# %%
import tiktoken
encoder = tiktoken.get_encoding("cl100k_base")  # GPT-4 encoding
text_course_outline = str(full_text)
text_course_content = str(slides)
token_count, token_count_outline = len(encoder.encode(text_course_content)), len(encoder.encode(text_course_outline))
print(token_count, token_count_outline)
# Out:
# 27099 1490

# %%
import dotenv
dotenv.load_dotenv()

import openai

client = openai.OpenAI()

system_prompt = """
You are a course structure analyzer specialized in French academic content.  
Your task is to parse a raw course outline text containing numbered section titles (like "I.", "1.", "1.1.", etc.) or indented bullet points.
and generate a hierarchical JSON structure matching this Pydantic model:

class ContentSection:
    id: str = ""
    title: str
    content: str = ""
    subsections: List[ContentSection]

class Content:
    sections: List[ContentSection]

Requirements:
- Detect all section titles and nest subsections correctly based on numbering.
- Maintain full recursive hierarchy.
- Return valid JSON exactly matching the Content model structure.
- Include every section and subsection with their titles.
- Ignore the content and the id of the sections, you only need to return the outline.
- Return ONLY the JSON, no additional text or explanation.
"""

user_message = full_text  # ton texte brut extrait

response = client.responses.parse(
    model="gpt-4.1-mini",
    input=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_message}
    ],
    text_format=Content,
    temperature=0
)

outline = response.output_parsed

print(outline.print_outline())
# Out:
# Course Outline:
# ==================================================
# Chapitre 4 - Réplication et réparation de l’ADN
#   I. STRUCTURE ET PROPRIÉTÉS DES ACIDES NUCLÉIQUES
#     1. Les nucléotides
#       1.1. Les bases azotées
#         1.1.1. Les bases pyrimidiques
#         1.1.2. Les bases puriques
#         1.1.3. Les bases modifiées dans l’ADN et l’ARN
#         1.1.4. Autres dérivés : molécules d’intérêt biologique et médical
#         1.1.5. Propriétés des bases azotées
#         1.1.6. Transformation chimique des bases
#       1.2. Les nucléosides
#         1.2.1. Le pentose
#         1.2.2. La liaison osidique
#         1.2.3. Nomenclature
#       1.3. Les nucléotides
#         1.3.1. Nomenclature
#         1.3.2. Nucléotides d’intérêt biologique
#     2. Les acides nucléiques
#       2.1. La liaison phosphodiester
#       2.2. Structure spatiale des acides desoxyribonucléiques (ADN)
#       2.3. Propriétés des ADN
#         2.3.1. État ionique et solubilité
#         2.3.2. Dénaturation de l’ADN / Effet sur l’absorbance
#       2.4. Organisation des ADN
#         2.4.1. Organisation de l’ADN viral
#         2.4.2. Organisation de l’ADN des bactéries
#         2.4.3. Organisation de l’ADN nucléaire des eucaryotes
#         2.4.4. Organisation de l’ADN mitochondrial
#       2.5. Les acides ribonucléiques (ARN): structure et organisation
#         2.5.1. ARN génomiques viraux
#         2.5.2. ARN cellulaire (procaryotes et eucaryotes)
#         2.5.3. Autres ARN fonctionnels eucaryotes - ARN “non codants”
#         2.5.4. Structure secondaire / tertiaire des ARN
#       2.6. L’hydrolyse enzymatique des acides nucléiques
#   II. RÉPLICATION DE L’ADN
#     1.  Introduction / Aperçu du cycle cellulaire
#     2.  Principe / notions fondamentales sur la synthèse d’ADN
#       2.1. Mode de réplication: conservatif ou semi-conservatif ?
#       2.2. Les unités de réplication (“Réplicons”)
#       2.3. La réplication est bidirectionnelle
#       2.4. Réplication et contraintes physiques
#       2.5. Principe de la synthèse - mode d’action des ADN polymérases
#     3.  La réaction de polymérisation de l’ADN
#       3.1. Mode d'action de l'ADN polymérase
#       3.2. Mécanisme
#     4.  Les ADN polymérases
#       4.1. Types
#       4.2. Rôles
#       4.3. Autres activités catalytiques des ADN polymérases
#     5.  Autres protéines impliquées dans la réplication / Mise en place et progression de la fourche réplicative
#       5.1. Mise en place du “clamp” (collier coulissant)
#       5.2. ADN hélicase
#       5.3. Protéines SSB
#       5.4. Topoisomérase
#       5.5. ADN primase
#       5.6. Mécanisme de dégradation des amorces ARN
#       5.7. ADN ligase
#       5.8. Résumé: schéma de la chronologie de la synthèse du brin retardé
#       5.9. Retour à la vue d’ensemble de la fourche de réplication et des complexes moléculaires y agissant
#     6.  Réplication des chromosomes eucaryotes: Télomères - enzyme télomérase
#     7.  La réplication est une cible thérapeutique
#   III. RÉPARATION DE L’ADN - Anomalies de l'ADN et mécanismes de correction
#     Introduction
#     1. Anomalies (lésions) de l'ADN
#       1.1. Causes physiques
#       1.2. Agents mutagènes chimiques : exemples
#       1.3. Causes "(patho)physiologiques"
#     2. Mécanismes de correction
#       2.1. Correction immédiate
#       2.2. Réparation par excision de base (BER)
#       2.3. Réparation par excision de nucléotides (NER)
#       2.4. Correction des mésappariements ("Mismatch Repair")
#       2.5. Réparation des coupures double brin
#       2.6. Les ADN polymérases translésionnelles ("DNA damage bypass")
#     3. Syndromes et maladies dus à des défauts de réparation de l'ADN
#   VI. RECOMBINAISON DE L’ADN
#     Introduction
#     1. Recombinaison générale ou homologue
#       1.1. Principes généraux et contexte
#       1.2. Étapes de la recombinaison homologue
#       1.3. Anomalies de la recombinaison
#     2. Recombinaison spécifique de site
#       2.1. Recombinaisons spécifiques de gènes du système immunitaire
#       2.2. La recombinase appelée Cre est produite normalement par un bactériophage.

# %%
while len(outline.sections) == 1:
    outline.sections = outline.sections[0].subsections

print(outline.sections[0])
# Out:
# id='' title='I. STRUCTURE ET PROPRIÉTÉS DES ACIDES NUCLÉIQUES' content=[] subsections=[ContentSection(id='', title='1. Les nucléotides', content=[], subsections=[ContentSection(id='', title='1.1. Les bases azotées', content=[], subsections=[ContentSection(id='', title='1.1.1. Les bases pyrimidiques', content=[], subsections=[]), ContentSection(id='', title='1.1.2. Les bases puriques', content=[], subsections=[]), ContentSection(id='', title='1.1.3. Les bases modifiées dans l’ADN et l’ARN', content=[], subsections=[]), ContentSection(id='', title='1.1.4. Autres dérivés : molécules d’intérêt biologique et médical', content=[], subsections=[]), ContentSection(id='', title='1.1.5. Propriétés des bases azotées', content=[], subsections=[]), ContentSection(id='', title='1.1.6. Transformation chimique des bases', content=[], subsections=[])]), ContentSection(id='', title='1.2. Les nucléosides', content=[], subsections=[ContentSection(id='', title='1.2.1. Le pentose', content=[], subsections=[]), ContentSection(id='', title='1.2.2. La liaison osidique', content=[], subsections=[]), ContentSection(id='', title='1.2.3. Nomenclature', content=[], subsections=[])]), ContentSection(id='', title='1.3. Les nucléotides', content=[], subsections=[ContentSection(id='', title='1.3.1. Nomenclature', content=[], subsections=[]), ContentSection(id='', title='1.3.2. Nucléotides d’intérêt biologique', content=[], subsections=[])])]), ContentSection(id='', title='2. Les acides nucléiques', content=[], subsections=[ContentSection(id='', title='2.1. La liaison phosphodiester', content=[], subsections=[]), ContentSection(id='', title='2.2. Structure spatiale des acides desoxyribonucléiques (ADN)', content=[], subsections=[]), ContentSection(id='', title='2.3. Propriétés des ADN', content=[], subsections=[ContentSection(id='', title='2.3.1. État ionique et solubilité', content=[], subsections=[]), ContentSection(id='', title='2.3.2. Dénaturation de l’ADN / Effet sur l’absorbance', content=[], subsections=[])]), ContentSection(id='', title='2.4. Organisation des ADN', content=[], subsections=[ContentSection(id='', title='2.4.1. Organisation de l’ADN viral', content=[], subsections=[]), ContentSection(id='', title='2.4.2. Organisation de l’ADN des bactéries', content=[], subsections=[]), ContentSection(id='', title='2.4.3. Organisation de l’ADN nucléaire des eucaryotes', content=[], subsections=[]), ContentSection(id='', title='2.4.4. Organisation de l’ADN mitochondrial', content=[], subsections=[])]), ContentSection(id='', title='2.5. Les acides ribonucléiques (ARN): structure et organisation', content=[], subsections=[ContentSection(id='', title='2.5.1. ARN génomiques viraux', content=[], subsections=[]), ContentSection(id='', title='2.5.2. ARN cellulaire (procaryotes et eucaryotes)', content=[], subsections=[]), ContentSection(id='', title='2.5.3. Autres ARN fonctionnels eucaryotes - ARN “non codants”', content=[], subsections=[]), ContentSection(id='', title='2.5.4. Structure secondaire / tertiaire des ARN', content=[], subsections=[])]), ContentSection(id='', title='2.6. L’hydrolyse enzymatique des acides nucléiques', content=[], subsections=[])])]

# %%
def assign_ids(sec: ContentSection, parent_id: str = "", parent_section: Optional[ContentSection] = None):
    # Determine current section number
    if parent_id == "":
        # Top level section
        sec.id = f"SEC_{len([s for s in outline.sections if s.id.startswith('SEC_')])+ 1}"
    else:
        # Subsection - append next number to parent id
        parent_nums = parent_id.replace("SEC_", "")
        sibling_count = len([s for s in parent_section.subsections if s.id.startswith(f"SEC_{parent_nums}.")])
        sec.id = f"SEC_{parent_nums}.{sibling_count + 1}"
    
    # Recursively assign ids to subsections
    for sub in sec.subsections:
        assign_ids(sub, sec.id, sec)

for s in outline.sections:
    assign_ids(s)
outline_json = outline.model_dump_json()

# %%
outline
# Out:
# Content(sections=[ContentSection(id='SEC_1', title='I. STRUCTURE ET PROPRIÉTÉS DES ACIDES NUCLÉIQUES', content=[], subsections=[ContentSection(id='SEC_1.1', title='1. Les nucléotides', content=[], subsections=[ContentSection(id='SEC_1.1.1', title='1.1. Les bases azotées', content=[], subsections=[ContentSection(id='SEC_1.1.1.1', title='1.1.1. Les bases pyrimidiques', content=[], subsections=[]), ContentSection(id='SEC_1.1.1.2', title='1.1.2. Les bases puriques', content=[], subsections=[]), ContentSection(id='SEC_1.1.1.3', title='1.1.3. Les bases modifiées dans l’ADN et l’ARN', content=[], subsections=[]), ContentSection(id='SEC_1.1.1.4', title='1.1.4. Autres dérivés : molécules d’intérêt biologique et médical', content=[], subsections=[]), ContentSection(id='SEC_1.1.1.5', title='1.1.5. Propriétés des bases azotées', content=[], subsections=[]), ContentSection(id='SEC_1.1.1.6', title='1.1.6. Transformation chimique des bases', content=[], subsections=[])]), ContentSection(id='SEC_1.1.2', title='1.2. Les nucléosides', content=[], subsections=[ContentSection(id='SEC_1.1.2.1', title='1.2.1. Le pentose', content=[], subsections=[]), ContentSection(id='SEC_1.1.2.2', title='1.2.2. La liaison osidique', content=[], subsections=[]), ContentSection(id='SEC_1.1.2.3', title='1.2.3. Nomenclature', content=[], subsections=[])]), ContentSection(id='SEC_1.1.3', title='1.3. Les nucléotides', content=[], subsections=[ContentSection(id='SEC_1.1.3.1', title='1.3.1. Nomenclature', content=[], subsections=[]), ContentSection(id='SEC_1.1.3.2', title='1.3.2. Nucléotides d’intérêt biologique', content=[], subsections=[])])]), ContentSection(id='SEC_1.2', title='2. Les acides nucléiques', content=[], subsections=[ContentSection(id='SEC_1.2.1', title='2.1. La liaison phosphodiester', content=[], subsections=[]), ContentSection(id='SEC_1.2.2', title='2.2. Structure spatiale des acides desoxyribonucléiques (ADN)', content=[], subsections=[]), ContentSection(id='SEC_1.2.3', title='2.3. Propriétés des ADN', content=[], subsections=[ContentSection(id='SEC_1.2.3.1', title='2.3.1. État ionique et solubilité', content=[], subsections=[]), ContentSection(id='SEC_1.2.3.2', title='2.3.2. Dénaturation de l’ADN / Effet sur l’absorbance', content=[], subsections=[])]), ContentSection(id='SEC_1.2.4', title='2.4. Organisation des ADN', content=[], subsections=[ContentSection(id='SEC_1.2.4.1', title='2.4.1. Organisation de l’ADN viral', content=[], subsections=[]), ContentSection(id='SEC_1.2.4.2', title='2.4.2. Organisation de l’ADN des bactéries', content=[], subsections=[]), ContentSection(id='SEC_1.2.4.3', title='2.4.3. Organisation de l’ADN nucléaire des eucaryotes', content=[], subsections=[]), ContentSection(id='SEC_1.2.4.4', title='2.4.4. Organisation de l’ADN mitochondrial', content=[], subsections=[])]), ContentSection(id='SEC_1.2.5', title='2.5. Les acides ribonucléiques (ARN): structure et organisation', content=[], subsections=[ContentSection(id='SEC_1.2.5.1', title='2.5.1. ARN génomiques viraux', content=[], subsections=[]), ContentSection(id='SEC_1.2.5.2', title='2.5.2. ARN cellulaire (procaryotes et eucaryotes)', content=[], subsections=[]), ContentSection(id='SEC_1.2.5.3', title='2.5.3. Autres ARN fonctionnels eucaryotes - ARN “non codants”', content=[], subsections=[]), ContentSection(id='SEC_1.2.5.4', title='2.5.4. Structure secondaire / tertiaire des ARN', content=[], subsections=[])]), ContentSection(id='SEC_1.2.6', title='2.6. L’hydrolyse enzymatique des acides nucléiques', content=[], subsections=[])])]), ContentSection(id='SEC_2', title='II. RÉPLICATION DE L’ADN', content=[], subsections=[ContentSection(id='SEC_2.1', title='1.  Introduction / Aperçu du cycle cellulaire', content=[], subsections=[]), ContentSection(id='SEC_2.2', title='2.  Principe / notions fondamentales sur la synthèse d’ADN', content=[], subsections=[ContentSection(id='SEC_2.2.1', title='2.1. Mode de réplication: conservatif ou semi-conservatif ?', content=[], subsections=[]),  ...

# %%
print(outline.print_outline())
# Out:
# Course Outline:
# ==================================================
# I. STRUCTURE ET PROPRIÉTÉS DES ACIDES NUCLÉIQUES
#   1. Les nucléotides
#     1.1. Les bases azotées
#       1.1.1. Les bases pyrimidiques
#       1.1.2. Les bases puriques
#       1.1.3. Les bases modifiées dans l’ADN et l’ARN
#       1.1.4. Autres dérivés : molécules d’intérêt biologique et médical
#       1.1.5. Propriétés des bases azotées
#       1.1.6. Transformation chimique des bases
#     1.2. Les nucléosides
#       1.2.1. Le pentose
#       1.2.2. La liaison osidique
#       1.2.3. Nomenclature
#     1.3. Les nucléotides
#       1.3.1. Nomenclature
#       1.3.2. Nucléotides d’intérêt biologique
#   2. Les acides nucléiques
#     2.1. La liaison phosphodiester
#     2.2. Structure spatiale des acides desoxyribonucléiques (ADN)
#     2.3. Propriétés des ADN
#       2.3.1. État ionique et solubilité
#       2.3.2. Dénaturation de l’ADN / Effet sur l’absorbance
#     2.4. Organisation des ADN
#       2.4.1. Organisation de l’ADN viral
#       2.4.2. Organisation de l’ADN des bactéries
#       2.4.3. Organisation de l’ADN nucléaire des eucaryotes
#       2.4.4. Organisation de l’ADN mitochondrial
#     2.5. Les acides ribonucléiques (ARN): structure et organisation
#       2.5.1. ARN génomiques viraux
#       2.5.2. ARN cellulaire (procaryotes et eucaryotes)
#       2.5.3. Autres ARN fonctionnels eucaryotes - ARN “non codants”
#       2.5.4. Structure secondaire / tertiaire des ARN
#     2.6. L’hydrolyse enzymatique des acides nucléiques
# II. RÉPLICATION DE L’ADN
#   1.  Introduction / Aperçu du cycle cellulaire
#   2.  Principe / notions fondamentales sur la synthèse d’ADN
#     2.1. Mode de réplication: conservatif ou semi-conservatif ?
#     2.2. Les unités de réplication (“Réplicons”)
#     2.3. La réplication est bidirectionnelle
#     2.4. Réplication et contraintes physiques
#     2.5. Principe de la synthèse - mode d’action des ADN polymérases
#   3.  La réaction de polymérisation de l’ADN
#     3.1. Mode d'action de l'ADN polymérase
#     3.2. Mécanisme
#   4.  Les ADN polymérases
#     4.1. Types
#     4.2. Rôles
#     4.3. Autres activités catalytiques des ADN polymérases
#   5.  Autres protéines impliquées dans la réplication / Mise en place et progression de la fourche réplicative
#     5.1. Mise en place du “clamp” (collier coulissant)
#     5.2. ADN hélicase
#     5.3. Protéines SSB
#     5.4. Topoisomérase
#     5.5. ADN primase
#     5.6. Mécanisme de dégradation des amorces ARN
#     5.7. ADN ligase
#     5.8. Résumé: schéma de la chronologie de la synthèse du brin retardé
#     5.9. Retour à la vue d’ensemble de la fourche de réplication et des complexes moléculaires y agissant
#   6.  Réplication des chromosomes eucaryotes: Télomères - enzyme télomérase
#   7.  La réplication est une cible thérapeutique
# III. RÉPARATION DE L’ADN - Anomalies de l'ADN et mécanismes de correction
#   Introduction
#   1. Anomalies (lésions) de l'ADN
#     1.1. Causes physiques
#     1.2. Agents mutagènes chimiques : exemples
#     1.3. Causes "(patho)physiologiques"
#   2. Mécanismes de correction
#     2.1. Correction immédiate
#     2.2. Réparation par excision de base (BER)
#     2.3. Réparation par excision de nucléotides (NER)
#     2.4. Correction des mésappariements ("Mismatch Repair")
#     2.5. Réparation des coupures double brin
#     2.6. Les ADN polymérases translésionnelles ("DNA damage bypass")
#   3. Syndromes et maladies dus à des défauts de réparation de l'ADN
# VI. RECOMBINAISON DE L’ADN
#   Introduction
#   1. Recombinaison générale ou homologue
#     1.1. Principes généraux et contexte
#     1.2. Étapes de la recombinaison homologue
#     1.3. Anomalies de la recombinaison
#   2. Recombinaison spécifique de site
#     2.1. Recombinaisons spécifiques de gènes du système immunitaire
#     2.2. La recombinase appelée Cre est produite normalement par un bactériophage.

# %% [markdown]
# ## Pass 1.bis mapping slide number to section title

# %%
def build_mapping_prompt(outline_json: str, slides: List[dict]) -> str:
    """
    Génère le prompt demandant au modèle de produire le mapping section→slides.

    Paramètres
    ----------
    outline_json : str   JSON du plan (chaque section possède un id SEC_***)
    slides       : list  Liste de dicts {"id": "SL_***", "title": ..., "content": ...}

    Retour
    ------
    str : prompt clair et contraignant, prêt pour client.responses.parse
    """
    return f"""
OBJECTIF
Associer chaque section du plan aux diapositives pertinentes.

DONNÉES
1) PLAN_JSON : (structure hiérarchique, chaque section a un identifiant unique "SEC_xxx")


This is the structure of the outline that you will receive:
class ContentSection(BaseModel):
    id: str
    title: str
    content: Optional[str] = ""
    subsections: List["ContentSection"] = Field(default_factory=list)
    
class Content(BaseModel):
    sections: List[ContentSection]

This is the actual outline:

{outline_json}

          


2) SLIDES : (liste ordonnée, chaque slide a un identifiant unique "SL_xxx")
{slides}

FORMAT DE SORTIE — STRICTEMENT OBLIGATOIRE
Un JSON **valide** contenant UNE SEULE clé de premier niveau : "mapping".

This is the pydantic model SectionSlideMapping that you will use to return the mapping:

class MappingItem(BaseModel):
    section_id: str
    slide_ids:  List[str]

class SectionSlideMapping(BaseModel):
    mapping: List[MappingItem]


Exemple de structure attendue :
{{
  "mapping": [
    {{ "section_id": "SEC_1", "slide_ids": ["SL_001", "SL_002"] }},
    {{ "section_id": "SEC_1.1", "slide_ids": ["SL_003", "SL_004"] }}
  ]
}}

CONTRAINTES À RESPECTER IMPÉRATIVEMENT
- Chaque "section_id" présent dans PLAN_JSON doit apparaître **exactement une fois**.
- Chaque "slide_id" présent dans SLIDES doit apparaître **au moins une fois** (aucune slide orpheline).
- "slide_ids" est un tableau d'identifiants ; l’ordre interne n’a pas d’importance.
- N’utilise **que** des identifiants existants ; n’invente pas de clés ni de champs.
- AUCUNE explication, commentaire ou clé supplémentaire : la sortie doit être **uniquement** le JSON demandé.
""".strip()


mapping_rsp = client.responses.parse(
    model="gpt-4.1-mini",
    input=[{"role":"user",
            "content": build_mapping_prompt(outline_json, slides)}],
    text_format=SectionSlideMapping,          # ← schéma fixe
    temperature=0
)
slides_by_section: Dict[str, List[str]] = {
    item.section_id: item.slide_ids
    for item in mapping_rsp.output_parsed.mapping
}

# %%
section_mapping = mapping_rsp.output_parsed

print(section_mapping.visualize_mapping(outline))
# Out:
# Section-to-Slides Mapping:
# ============================================================
#
# [Root] SEC_1
# Title: I. STRUCTURE ET PROPRIÉTÉS DES ACIDES NUCLÉIQUES
# Slides: 2 slide(s)
# Slide IDs: SL_002, SL_006
#
#   [Level 1] SEC_1.1
#   Title: 1. Les nucléotides
#   Slides: 1 slide(s)
#   Slide IDs: SL_007
#
#     [Level 2] SEC_1.1.1
#     Title: 1.1. Les bases azotées
#     Slides: 10 slide(s)
#     Slide IDs: SL_008, SL_009, SL_010, SL_011, SL_012, SL_013, SL_014, SL_015, SL_016, SL_017
#
#     [Level 2] SEC_1.1.2
#     Title: 1.2. Les nucléosides
#     Slides: 4 slide(s)
#     Slide IDs: SL_018, SL_019, SL_020, SL_021
#
#     [Level 2] SEC_1.1.3
#     Title: 1.3. Les nucléotides
#     Slides: 3 slide(s)
#     Slide IDs: SL_022, SL_023, SL_024
#
#   [Level 1] SEC_1.2
#   Title: 2. Les acides nucléiques
#   Slides: 1 slide(s)
#   Slide IDs: SL_025
#
#     [Level 2] SEC_1.2.1
#     Title: 2.1. La liaison phosphodiester
#     Slides: 2 slide(s)
#     Slide IDs: SL_026, SL_027
#
#     [Level 2] SEC_1.2.2
#     Title: 2.2. Structure spatiale des acides desoxyribonucléiques (ADN)
#     Slides: 8 slide(s)
#     Slide IDs: SL_029, SL_030, SL_031, SL_032, SL_033, SL_034, SL_035, SL_036
#
#     [Level 2] SEC_1.2.3
#     Title: 2.3. Propriétés des ADN
#     Slides: 5 slide(s)
#     Slide IDs: SL_037, SL_038, SL_039, SL_040, SL_041
#
#     [Level 2] SEC_1.2.4
#     Title: 2.4. Organisation des ADN
#     Slides: 5 slide(s)
#     Slide IDs: SL_043, SL_044, SL_045, SL_046, SL_047
#
#     [Level 2] SEC_1.2.5
#     Title: 2.5. Les acides ribonucléiques (ARN): structure et organisation
#     Slides: 7 slide(s)
#     Slide IDs: SL_048, SL_049, SL_050, SL_052, SL_053, SL_054, SL_055
#
#     [Level 2] SEC_1.2.6
#     Title: 2.6. L’hydrolyse enzymatique des acides nucléiques
#     Slides: 2 slide(s)
#     Slide IDs: SL_056, SL_057
#
# [Root] SEC_2
# Title: II. RÉPLICATION DE L’ADN
# Slides: 18 slide(s)
# Slide IDs: SL_058, SL_059, SL_060, SL_061, SL_062, SL_063, SL_064, SL_065, SL_066, SL_067, SL_068, SL_069, SL_070, SL_071, SL_072, SL_073, SL_074, SL_075
#
#   [Level 1] SEC_2.5
#   Title: 5.  Autres protéines impliquées dans la réplication / Mise en place et progression de la fourche réplicative
#   Slides: 12 slide(s)
#   Slide IDs: SL_076, SL_077, SL_078, SL_079, SL_080, SL_081, SL_082, SL_084, SL_085, SL_086, SL_087, SL_088
#
#   [Level 1] SEC_2.6
#   Title: 6.  Réplication des chromosomes eucaryotes: Télomères - enzyme télomérase
#   Slides: 6 slide(s)
#   Slide IDs: SL_089, SL_090, SL_091, SL_092, SL_093, SL_094
#
#   [Level 1] SEC_2.7
#   Title: 7.  La réplication est une cible thérapeutique
#   Slides: 1 slide(s)
#   Slide IDs: SL_095
#
# [Root] SEC_3
# Title: III. RÉPARATION DE L’ADN - Anomalies de l'ADN et mécanismes de correction
# Slides: 3 slide(s)
# Slide IDs: SL_096, SL_097, SL_098
#
#   [Level 1] SEC_3.1
#   Title: Introduction
#   Slides: 2 slide(s)
#   Slide IDs: SL_099, SL_100
#
#   [Level 1] SEC_3.2
#   Title: 1. Anomalies (lésions) de l'ADN
#   Slides: 8 slide(s)
#   Slide IDs: SL_101, SL_102, SL_103, SL_104, SL_105, SL_106, SL_107, SL_108
#
#   [Level 1] SEC_3.3
#   Title: 2. Mécanismes de correction
#   Slides: 9 slide(s)
#   Slide IDs: SL_109, SL_110, SL_111, SL_112, SL_113, SL_114, SL_115, SL_116, SL_118
#
#   [Level 1] SEC_3.4
#   Title: 3. Syndromes et maladies dus à des défauts de réparation de l'ADN
#   Slides: 3 slide(s)
#   Slide IDs: SL_119, SL_120, SL_121
#
# [Root] SEC_4
# Title: VI. RECOMBINAISON DE L’ADN
# Slides: 1 slide(s)
# Slide IDs: SL_125
#
#   [Level 1] SEC_4.1
#   Title: Introduction
#   Slides: 9 slide(s)
#   Slide IDs: SL_126, SL_127, SL_128, SL_129, SL_130, SL_131, SL_132, SL_133, SL_134
#
#   [Level 1] SEC_4.3
#   Title: 2. Recombinaison spécifique de site
#   Slides: 9 slide(s)
#   Slide IDs: SL_135, SL_136, SL_137, SL_138, SL_139, SL_140, SL_141, SL_142, SL_143

# %%
from models import CourseWithSlides
course_with_slides = CourseWithSlides(content=outline, slides=formated_slides, mapping=section_mapping)
course_with_slides
# Out:
# CourseWithSlides(content=Content(sections=[ContentSection(id='SEC_1', title='Introduction', content=['L1SpS: UE 2 Les molécules du vivant\nPlan du cours\n• Introduction\n• Notions fondamentales\n• Le génome humain\n• Projet de séquençage\n• Architecture globale\n• Génome mitochondrial\n• Génome nucléaire\n• Description des principaux éléments constituants\n• Gènes (codants et non-codants), pseudogènes et éléments répétés\n• Comparaison aux autres génomes\n• Les types de variations du génome humain et leurs conséquences\n• La variabilité du génome humain\n• Evolution des génomes: notions essentielles, mécanismes\n2', 'L1SpS: UE 2 Les molécules du vivant\nIntroduction\n3', 'L1SpS: UE 2 Les molécules du vivant\nL’arbre de la vie\nNotions essentielles:\n• Evolution\n• Temps\n• Adaptation\n• Sélection\nLUCA\nLast Universal Common Ancestor\n4', 'L1SpS: UE 2 Les molécules du vivant\nArbre des eucaryotes\nChoix d’organismes modèles\n• Intérêt(s) économique(s)\n• Intérêt(s) technique(s)\n• Facilités hébergement,\n• Développement embryonnaire/temps\nde génération\n• Partage d’éléments communs (ADN)\n• Hérités/Transmis\n35 eucaryotes\n18 métazoaires\n5', "L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Définition\n• En biologie, l'homologie désigne un caractère propre à plusieurs\nespèces hérité d'un ancêtre commun. Les structures en question, qu'elles\nsoient d'ordre anatomique, moléculaire ou génétique, partagent donc une\nhistoire évolutive.\n• ≠ analogie (ex: ailes oiseaux et insectes qui est une évolution séparée)\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\névolué à partir d’un gène ancestral suite à une spéciation\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\nl’évolution de cette espèce.\n6", "L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Définition\n• En biologie, l'homologie désigne un caractère propre à plusieurs espèces\nhérité d'un ancêtre commun. Les structures en question, qu'elles soient\nd'ordre anatomique, moléculaire ou génétique, partagent donc une histoire\névolutive.\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\névolué à partir d’un gène ancestral suite à une spéciation\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\nl’évolution de cette espèce.\n7", 'L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Exemple\n8', 'L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Comment déterminer si les gènes sont homologues ou pas?\n• Les séquences des génomes peuvent être alignées entres elles tout comme\nles séquences des protéines.\n• La comparaison de 2 séquences permet d’établir une évaluation de leur\nproximité ou de leur éloignement par le calcul:\n• du pourcentage d’identité* entre ces 2 séquences\n* résidus strictement identique\n• du pourcentage de similarité* entre ces 2 séquences\n* résidus identique + proche (critère à déterminer; ex: caractéristiques physicochimiques)\n• Seuil de significativité >20% (dépendant de la famille de protéines)\n9', 'L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Remarques:\n• Un % similarité/identité non significatif ne veut pas dire que les gènes, ne sont\npas homologues.\n• 2 séquences similaires peuvent l’être :\n• par hasard (région de faible complexité)\n• par convergence évolutive\n<15% identité\nActine humaine MreB bactérienne\n10', 'L1SpS: UE 2 Les molécules du vivant\nBiologie du gène – dogme central\n11', 'L1SpS: UE 2 Les molécules du vivant\nRéférences\n• Le génome est une des références d’un organisme\n…\nméthylome\nprotéome\ntranscriptome\ngénome\n12'], subsections=[ContentSection(id='SEC_1.1', title='Notions fondamentales', content=['L1SpS: UE 2 Les molécules du vivant\nL’arbre de la vie\nNotions essentielles:\n• Evolution\n• Temps\n• Adaptati ...

# %%
new_content = course_with_slides.content
type(new_content)
# Out:
# models.Content

# %% [markdown]
# # Volumen of tokens

# %%
import tiktoken
encoder = tiktoken.get_encoding("cl100k_base")  # GPT-4 encoding
text_course_with_slides = str(course_with_slides)
token_count = len(encoder.encode(text_course_with_slides))
print(token_count)
# Out:
# 26206

# %%
content_to_send = Content(sections=new_content.sections[:])
content_json_str = content_to_send.model_dump_json()
content_json_str
# Out:
# '{"sections":[{"id":"SEC_1","title":"Introduction","content":["L1SpS: UE 2 Les molécules du vivant\\nPlan du cours\\n• Introduction\\n• Notions fondamentales\\n• Le génome humain\\n• Projet de séquençage\\n• Architecture globale\\n• Génome mitochondrial\\n• Génome nucléaire\\n• Description des principaux éléments constituants\\n• Gènes (codants et non-codants), pseudogènes et éléments répétés\\n• Comparaison aux autres génomes\\n• Les types de variations du génome humain et leurs conséquences\\n• La variabilité du génome humain\\n• Evolution des génomes: notions essentielles, mécanismes\\n2","L1SpS: UE 2 Les molécules du vivant\\nIntroduction\\n3","L1SpS: UE 2 Les molécules du vivant\\nL’arbre de la vie\\nNotions essentielles:\\n• Evolution\\n• Temps\\n• Adaptation\\n• Sélection\\nLUCA\\nLast Universal Common Ancestor\\n4","L1SpS: UE 2 Les molécules du vivant\\nArbre des eucaryotes\\nChoix d’organismes modèles\\n• Intérêt(s) économique(s)\\n• Intérêt(s) technique(s)\\n• Facilités hébergement,\\n• Développement embryonnaire/temps\\nde génération\\n• Partage d’éléments communs (ADN)\\n• Hérités/Transmis\\n35 eucaryotes\\n18 métazoaires\\n5","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Définition\\n• En biologie, l\'homologie désigne un caractère propre à plusieurs\\nespèces hérité d\'un ancêtre commun. Les structures en question, qu\'elles\\nsoient d\'ordre anatomique, moléculaire ou génétique, partagent donc une\\nhistoire évolutive.\\n• ≠ analogie (ex: ailes oiseaux et insectes qui est une évolution séparée)\\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\\névolué à partir d’un gène ancestral suite à une spéciation\\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\\nl’évolution de cette espèce.\\n6","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Définition\\n• En biologie, l\'homologie désigne un caractère propre à plusieurs espèces\\nhérité d\'un ancêtre commun. Les structures en question, qu\'elles soient\\nd\'ordre anatomique, moléculaire ou génétique, partagent donc une histoire\\névolutive.\\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\\névolué à partir d’un gène ancestral suite à une spéciation\\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\\nl’évolution de cette espèce.\\n7","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Exemple\\n8","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Comment déterminer si les gènes sont homologues ou pas?\\n• Les séquences des génomes peuvent être alignées entres elles tout comme\\nles séquences des protéines.\\n• La comparaison de 2 séquences permet d’établir une évaluation de leur\\nproximité ou de leur éloignement par le calcul:\\n• du pourcentage d’identité* entre ces 2 séquences\\n* résidus strictement identique\\n• du pourcentage de similarité* entre ces 2 séquences\\n* résidus identique + proche (critère à déterminer; ex: caractéristiques physicochimiques)\\n• Seuil de significativité >20% (dépendant de la famille de protéines)\\n9","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Remarques:\\n• Un % similarité/identité non significatif ne veut pas dire que les gènes, ne sont\\npas homologues.\\n• 2 séquences similaires peuvent l’être :\\n• par hasard (région de faible complexité)\\n• par convergence évolutive\\n<15% identité\\nActine humaine MreB bactérienne\\n10","L1SpS: UE 2 Les molécules du vivant\\nBiologie du gène – dogme central\\n11","L1SpS: UE 2 Les molécules du vivant\\nRéférences\\n• Le génome est une des références d’un organisme\\n…\\nméthylome\\nprotéome\\ntranscriptome\\ngénome\\n12"],"subsections":[{"id":"SEC_1.1","title":"Notions fondamentales","content":["L1SpS: UE 2 Les molécules du vivant\\nL’arbre de la vie\\nNotio ...

# %%
content_to_send.sections[0].content.pop(0)
# Out:
# 'L1SpS: UE 2 Les molécules du vivant\nPlan du cours\n• Introduction\n• Notions fondamentales\n• Le génome humain\n• Projet de séquençage\n• Architecture globale\n• Génome mitochondrial\n• Génome nucléaire\n• Description des principaux éléments constituants\n• Gènes (codants et non-codants), pseudogènes et éléments répétés\n• Comparaison aux autres génomes\n• Les types de variations du génome humain et leurs conséquences\n• La variabilité du génome humain\n• Evolution des génomes: notions essentielles, mécanismes\n2'

# %%
for i in content_to_send.sections[0].content:
    print ("="*100)
    print(i)
    print ("="*100)
# Out:
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# Introduction
# 3
# ====================================================================================================
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# L’arbre de la vie
# Notions essentielles:
# • Evolution
# • Temps
# • Adaptation
# • Sélection
# LUCA
# Last Universal Common Ancestor
# 4
# ====================================================================================================
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# Arbre des eucaryotes
# Choix d’organismes modèles
# • Intérêt(s) économique(s)
# • Intérêt(s) technique(s)
# • Facilités hébergement,
# • Développement embryonnaire/temps
# de génération
# • Partage d’éléments communs (ADN)
# • Hérités/Transmis
# 35 eucaryotes
# 18 métazoaires
# 5
# ====================================================================================================
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Définition
# • En biologie, l'homologie désigne un caractère propre à plusieurs
# espèces hérité d'un ancêtre commun. Les structures en question, qu'elles
# soient d'ordre anatomique, moléculaire ou génétique, partagent donc une
# histoire évolutive.
# • ≠ analogie (ex: ailes oiseaux et insectes qui est une évolution séparée)
# • Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant
# évolué à partir d’un gène ancestral suite à une spéciation
# • Paralogie (gènes paralogues): gènes homologues au sein de la même
# espèce ayant évolué à partir d’un gène ancestral par duplication au cours de
# l’évolution de cette espèce.
# 6
# ====================================================================================================
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Définition
# • En biologie, l'homologie désigne un caractère propre à plusieurs espèces
# hérité d'un ancêtre commun. Les structures en question, qu'elles soient
# d'ordre anatomique, moléculaire ou génétique, partagent donc une histoire
# évolutive.
# • Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant
# évolué à partir d’un gène ancestral suite à une spéciation
# • Paralogie (gènes paralogues): gènes homologues au sein de la même
# espèce ayant évolué à partir d’un gène ancestral par duplication au cours de
# l’évolution de cette espèce.
# 7
# ====================================================================================================
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Exemple
# 8
# ====================================================================================================
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Comment déterminer si les gènes sont homologues ou pas?
# • Les séquences des génomes peuvent être alignées entres elles tout comme
# les séquences des protéines.
# • La comparaison de 2 séquences permet d’établir une évaluation de leur
# proximité ou de leur éloignement par le calcul:
# • du pourcentage d’identité* entre ces 2 séquences
# * résidus strictement identique
# • du pourcentage de similarité* entre ces 2 séquences
# * résidus identique + proche (critère à déterminer; ex: caractéristiques physicochimiques)
# • Seuil de significativité >20% (dépendant de la famille de protéines)
# 9
# ====================================================================================================
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Remarques:
# • Un % similarité/identité non significatif ne veut pas dire que les gènes, ne sont
# pas homologues.
# • 2 séquences similaires peuvent l’être :
# • par hasard (région de faible complexité)
# • par convergence évolutive
# <15% identité
# Actine humaine MreB bactérienne
# 10
# ====================================================================================================
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# Biologie du gène – dogme central
# 11
# ====================================================================================================
# ====================================================================================================
# L1SpS: UE 2 Les molécules du vivant
# Références
# • Le génome est une des références d’un organisme
# …
# méthylome
# protéome
# transcriptome
# génome
# 12
# ====================================================================================================

# %%
encoder = tiktoken.get_encoding("cl100k_base")  # GPT-4 encoding
text_course_with_slides = str(content_json_str)
token_count = len(encoder.encode(text_course_with_slides))
print(token_count)
# Out:
# 12309

# %%
def build_system_prompt() -> str:
    """
    Prompt système définissant le rôle et les règles
    """
    return """Tu es un expert en rédaction pédagogique. Ta tâche est de transformer du contenu brut de slides en paragraphes de cours structurés.

Règles :
- Traite TOUTES les sections du JSON (ne t'arrête pas à la première)
- Pour chaque section, synthétise tous les éléments content[] en 2-10 paragraphes cohérents
- Chaque paragraphe = maximum 10 phrases liées au titre de la section
- Conserve la structure JSON exacte (mêmes IDs, titres, ordre)
- Style académique fluide"""


def build_user_prompt(content_json: str) -> str:
    """
    Prompt utilisateur avec le contenu à traiter
    """
    return content_json


def build_assistant_prompt() -> str:
    """
    Prompt assistant avec exemple d'input/output
    """
    return """Voici un exemple de transformation attendue :

INPUT EXEMPLE:
```json
{
  "sections": [
    {
      "id": "SEC_1",
      "title": "Introduction aux Algorithmes",
      "content": [
        "CS101: Algorithmique\\nAlgorithmes\\n• Définition: séquence d'instructions\\n• Résolution problèmes\\n• Entrée → Traitement → Sortie\\n• Propriétés essentielles\\n1",
        "CS101: Algorithmique\\nCaractéristiques\\n• Fini (nombre étapes)\\n• Non-ambigu\\n• Déterministe\\n• Efficacité importante\\n• Complexité temporelle/spatiale\\n2",
        "CS101: Algorithmique\\nTypes d'algorithmes\\n• Itératifs vs Récursifs\\n• Diviser pour régner\\n• Gloutons (greedy)\\n• Programmation dynamique\\nExemples concrets\\n3"
      ],
      "subsections": [
        {
          "id": "SEC_1.1",
          "title": "Notation Big-O",
          "content": [
            "CS101: Algorithmique\\nComplexité algorithmique\\n• Notation O(n)\\n• Mesure efficacité\\n• Pire cas considéré\\n• Croissance asymptotique\\n4",
            "CS101: Algorithmique\\nExemples complexités\\n• O(1) - constant\\n• O(log n) - logarithmique\\n• O(n) - linéaire\\n• O(n²) - quadratique\\n• O(2^n) - exponentielle\\n5"
          ],
          "subsections": []
        }
      ]
    },
    {
      "id": "SEC_2", 
      "title": "Structures de Données",
      "content": [
        "CS101: Algorithmique\\nStructures fondamentales\\n• Tableaux (arrays)\\n• Listes chaînées\\n• Piles (stacks)\\n• Files (queues)\\n• Organisation mémoire\\n6",
        "CS101: Algorithmique\\nOpérations de base\\n• Insertion / Suppression\\n• Recherche / Accès\\n• Parcours / Tri\\n• Complexité variable\\n• Trade-offs temps/espace\\n7"
      ],
      "subsections": []
    }
  ]
}
```

OUTPUT EXEMPLE:
```json
{
  "sections": [
    {
      "id": "SEC_1",
      "title": "Introduction aux Algorithmes", 
      "content": [
        "Un algorithme constitue une séquence finie et ordonnée d'instructions permettant de résoudre un problème spécifique ou d'accomplir une tâche donnée. Cette approche systématique transforme des données d'entrée en résultats de sortie par l'application d'un processus de traitement déterministe et reproductible.",
        "Les algorithmes présentent des caractéristiques fondamentales qui garantissent leur validité : ils doivent être finis dans le nombre d'étapes, non-ambigus dans leur interprétation, et déterministes dans leur exécution. L'efficacité algorithmique, mesurée par les complexités temporelle et spatiale, constitue un critère essentiel d'évaluation de leur performance.",
        "La classification des algorithmes distingue plusieurs approches méthodologiques selon leur stratégie de résolution : les algorithmes itératifs et récursifs, les méthodes diviser-pour-régner, les algorithmes gloutons, et la programmation dynamique. Chaque paradigme offre des avantages spécifiques selon la nature du problème à traiter."
      ],
      "subsections": [
        {
          "id": "SEC_1.1",
          "title": "Notation Big-O",
          "content": [
            "La notation Big-O fournit un outil mathématique pour caractériser la complexité algorithmique en décrivant la croissance asymptotique du temps d'exécution ou de l'espace mémoire requis. Cette mesure considère le comportement dans le pire cas et permet de comparer objectivement l'efficacité de différents algorithmes.",
            "Les classes de complexité courantes s'organisent selon une hiérarchie croissante : O(1) pour les opérations à temps constant, O(log n) pour les algorithmes logarithmiques, O(n) pour les traitements linéaires, O(n²) pour les approches quadratiques, et O(2^n) pour les solutions exponentielles. Cette classification guide le choix algorithmique selon les contraintes de performance requises."
          ],
          "subsections": []
        }
      ]
    },
    {
      "id": "SEC_2",
      "title": "Structures de Données",
      "content": [
        "Les structures de données fondamentales organisent et stockent l'information selon des patterns spécifiques adaptés aux besoins algorithmiques : les tableaux offrent un accès direct par index, les listes chaînées permettent une allocation dynamique, tandis que les piles et files implémentent des politiques d'accès particulières. L'organisation mémoire influence directement les performances d'accès et de manipulation.",
        "Les opérations de base sur ces structures - insertion, suppression, recherche, accès, parcours et tri - présentent des complexités variables selon l'implémentation choisie. Ces trade-offs entre temps d'exécution et espace mémoire orientent la sélection de la structure la plus appropriée selon les contraintes spécifiques de chaque application."
      ],
      "subsections": []
    }
  ]
}
```

Maintenant traite le JSON fourni en suivant ce modèle :"""


def build_prompt_fill_content(
    content_json: str
) -> str:
    """
    Version legacy - maintenant utilise les 3 fonctions séparées ci-dessus
    """
    return f"""
**SYSTEM:**
{build_system_prompt()}

**USER:**
{build_user_prompt(content_json)}

**ASSISTANT:**
{build_assistant_prompt()}
""".strip()


prompt_to_send = build_prompt_fill_content(content_json_str)

response = client.responses.parse(
    model="gpt-4.1-mini",
    input=[
        {"role": "system", "content": "Tu es un Professeur qui remplit le contenu des sections du plan de cours à partir du contenu des slides."},
        {"role": "user", "content": prompt_to_send}
    ],
    text_format=Content,
    temperature=0,
)

print(response.output_parsed)
# Out:
# sections=[ContentSection(id='SEC_1', title='Introduction', content=["Ce cours intitulé « Les molécules du vivant » aborde une large gamme de sujets fondamentaux liés au génome humain et à son évolution. Le plan du cours inclut une introduction aux notions fondamentales, une étude détaillée du génome humain, le projet de séquençage, ainsi que l'architecture globale du génome. Il traite également des génomes mitochondrial et nucléaire, des principaux éléments constituants, des gènes codants et non-codants, des pseudogènes et des éléments répétés. Une comparaison avec d'autres génomes est proposée, ainsi qu'une analyse des types de variations du génome humain et de leurs conséquences. Enfin, le cours explore la variabilité du génome humain et les mécanismes essentiels de son évolution.", "L'arbre de la vie est présenté comme un concept central, illustrant les notions d'évolution, de temps, d'adaptation et de sélection. Le dernier ancêtre commun universel (LUCA) est évoqué comme point de départ de la diversité biologique. L'arbre des eucaryotes est également abordé, avec un choix d'organismes modèles basé sur des critères économiques, techniques, de facilité d'hébergement, de développement embryonnaire et de temps de génération. Ces organismes partagent des éléments communs d'ADN hérités et transmis, ce qui justifie leur intérêt pour l'étude comparative.", "Le concept d'homologie est défini comme un caractère partagé par plusieurs espèces en raison d'un ancêtre commun, que ce soit au niveau anatomique, moléculaire ou génétique. Cette notion est distinguée de l'analogie, qui résulte d'une évolution convergente indépendante. Deux types d'homologie génétique sont précisés : l'orthologie, où les gènes homologues dans deux espèces proviennent d'un gène ancestral suite à une spéciation, et la paralogie, où les gènes homologues au sein d'une même espèce résultent d'une duplication génétique au cours de l'évolution.", "Pour déterminer si des gènes sont homologues, on compare leurs séquences génomiques ou protéiques par alignement. Cette comparaison permet d'évaluer la proximité ou l'éloignement des séquences en calculant le pourcentage d'identité (résidus strictement identiques) et de similarité (résidus identiques ou physico-chimiquement proches). Un seuil de significativité supérieur à 20 % est généralement retenu, bien que des exceptions existent. Il est important de noter qu'un faible pourcentage d'identité ne signifie pas nécessairement l'absence d'homologie, car des similarités peuvent résulter du hasard ou d'une convergence évolutive."], subsections=[ContentSection(id='SEC_1.1', title='Notions fondamentales', content=["Les notions fondamentales du cours s'articulent autour de l'arbre de la vie, mettant en lumière les concepts d'évolution, de temps, d'adaptation et de sélection. Le dernier ancêtre commun universel (LUCA) est présenté comme la source originelle des espèces actuelles. L'arbre des eucaryotes est détaillé avec un choix d'organismes modèles basé sur des critères économiques, techniques, de facilité d'hébergement, de développement embryonnaire et de temps de génération. Ces organismes partagent des éléments communs d'ADN hérités, ce qui facilite leur étude comparative.", "L'homologie est définie comme un caractère partagé par plusieurs espèces en raison d'un ancêtre commun, que ce soit au niveau anatomique, moléculaire ou génétique. Cette notion est distinguée de l'analogie, qui résulte d'une évolution convergente indépendante. Deux types d'homologie génétique sont précisés : l'orthologie, où les gènes homologues dans deux espèces proviennent d'un gène ancestral suite à une spéciation, et la paralogie, où les gènes homologues au sein d'une même espèce résultent d'une duplication génétique au cours de l'évolution.", "Un exemple concret illustre ces notions d'homologie. Pour déterminer si des gènes sont homologues, on compare leurs séquences génomiques ou protéiques par alignement. Cette comparaison permet d'évaluer la prox ...

# %%
course = response.output_parsed
print(course.print_outline())
# Out:
# Course Outline:
# ==================================================
# Introduction
#   Notions fondamentales
# Le génome humain
#   Projet de séquençage
#   Architecture globale
#     Génome mitochondrial
#     Génome nucléaire
#   Description des principaux éléments constituants
#     Gènes (codants et non-codants), pseudogènes et éléments répétés
# Comparaison aux autres génomes
# Les types de variations du génome humain et leurs conséquences
# La variabilité du génome humain
# Evolution des génomes: notions essentielles, mécanismes

# %%
print(course.print_content())
# Out:
# Course Content:
# ============================================================
#
# [Root] ID: SEC_1
# Title: Introduction
# Content:
#   [1] Ce cours intitulé « Les molécules du vivant » aborde une large gamme de
#       sujets fondamentaux liés au génome humain et à son évolution. Le plan du
#       cours inclut une introduction aux notions fondamentales, une étude
#       détaillée du génome humain, le projet de séquençage, ainsi que
#       l'architecture globale du génome. Il traite également des génomes
#       mitochondrial et nucléaire, des principaux éléments constituants, des
#       gènes codants et non-codants, des pseudogènes et des éléments répétés. Une
#       comparaison avec d'autres génomes est proposée, ainsi qu'une analyse des
#       types de variations du génome humain et de leurs conséquences. Enfin, le
#       cours explore la variabilité du génome humain et les mécanismes essentiels
#       de son évolution.
#   [2] L'arbre de la vie est présenté comme un concept central, illustrant les
#       notions d'évolution, de temps, d'adaptation et de sélection. Le dernier
#       ancêtre commun universel (LUCA) est évoqué comme point de départ de la
#       diversité biologique. L'arbre des eucaryotes est également abordé, avec un
#       choix d'organismes modèles basé sur des critères économiques, techniques,
#       de facilité d'hébergement, de développement embryonnaire et de temps de
#       génération. Ces organismes partagent des éléments communs d'ADN hérités et
#       transmis, ce qui justifie leur intérêt pour l'étude comparative.
#   [3] Le concept d'homologie est défini comme un caractère partagé par plusieurs
#       espèces en raison d'un ancêtre commun, que ce soit au niveau anatomique,
#       moléculaire ou génétique. Cette notion est distinguée de l'analogie, qui
#       résulte d'une évolution convergente indépendante. Deux types d'homologie
#       génétique sont précisés : l'orthologie, où les gènes homologues dans deux
#       espèces proviennent d'un gène ancestral suite à une spéciation, et la
#       paralogie, où les gènes homologues au sein d'une même espèce résultent
#       d'une duplication génétique au cours de l'évolution.
#   [4] Pour déterminer si des gènes sont homologues, on compare leurs séquences
#       génomiques ou protéiques par alignement. Cette comparaison permet
#       d'évaluer la proximité ou l'éloignement des séquences en calculant le
#       pourcentage d'identité (résidus strictement identiques) et de similarité
#       (résidus identiques ou physico-chimiquement proches). Un seuil de
#       significativité supérieur à 20 % est généralement retenu, bien que des
#       exceptions existent. Il est important de noter qu'un faible pourcentage
#       d'identité ne signifie pas nécessairement l'absence d'homologie, car des
#       similarités peuvent résulter du hasard ou d'une convergence évolutive.
#
#   [Level 1] ID: SEC_1.1
#   Title: Notions fondamentales
#   Content:
#     [1] Les notions fondamentales du cours s'articulent autour de l'arbre de la
#         vie, mettant en lumière les concepts d'évolution, de temps, d'adaptation
#         et de sélection. Le dernier ancêtre commun universel (LUCA) est présenté
#         comme la source originelle des espèces actuelles. L'arbre des eucaryotes
#         est détaillé avec un choix d'organismes modèles basé sur des critères
#         économiques, techniques, de facilité d'hébergement, de développement
#         embryonnaire et de temps de génération. Ces organismes partagent des
#         éléments communs d'ADN hérités, ce qui facilite leur étude comparative.
#     [2] L'homologie est définie comme un caractère partagé par plusieurs espèces
#         en raison d'un ancêtre commun, que ce soit au niveau anatomique,
#         moléculaire ou génétique. Cette notion est distinguée de l'analogie, qui
#         résulte d'une évolution convergente indépendante. Deux types d'homologie
#         génétique sont précisés : l'orthologie, où les gènes homologues dans
#         deux espèces proviennent d'un gène ancestral suite à une spéciation, et
#         la paralogie, où les gènes homologues au sein d'une même espèce
#         résultent d'une duplication génétique au cours de l'évolution.
#     [3] Un exemple concret illustre ces notions d'homologie. Pour déterminer si
#         des gènes sont homologues, on compare leurs séquences génomiques ou
#         protéiques par alignement. Cette comparaison permet d'évaluer la
#         proximité ou l'éloignement des séquences en calculant le pourcentage
#         d'identité (résidus strictement identiques) et de similarité (résidus
#         identiques ou physico-chimiquement proches). Un seuil de significativité
#         supérieur à 20 % est généralement retenu, bien que des exceptions
#         existent.
#     [4] Il est important de noter qu'un faible pourcentage d'identité ne
#         signifie pas nécessairement l'absence d'homologie, car des similarités
#         peuvent résulter du hasard, notamment dans des régions de faible
#         complexité, ou d'une convergence évolutive. Par exemple, l'actine
#         humaine et la protéine MreB bactérienne présentent moins de 15 %
#         d'identité, illustrant cette complexité d'interprétation.
#     [5] Enfin, le dogme central de la biologie moléculaire est évoqué,
#         soulignant le rôle fondamental du gène dans la transmission de
#         l'information génétique. Le génome est présenté comme une référence
#         essentielle d'un organisme, complétée par d'autres niveaux d'information
#         tels que le méthylome, le protéome et le transcriptome.
#
# [Root] ID: SEC_2
# Title: Le génome humain
# Content:
#   [1] Le génome humain est constitué de deux composantes principales : le génome
#       nucléaire et le génome mitochondrial. Le génome nucléaire comprend 22
#       paires de chromosomes homologues appelés autosomes, ainsi qu'une paire de
#       chromosomes sexuels, les gonosomes X et Y. Le génome mitochondrial est une
#       molécule circulaire distincte, présente en de nombreuses copies dans
#       chaque cellule.
#   [2] La composition générale du génome humain est décrite selon la nomenclature
#       de Paris (1971), distinguant le génome haploïde et diploïde. Le génome
#       diploïde résulte de la combinaison des génomes maternel et paternel.
#       Environ 5 % du génome est conservé au cours de l'évolution, témoignant de
#       régions fonctionnellement importantes et stables.
#   [3] Le projet international de séquençage du génome humain, lancé en 1990 avec
#       un budget d'environ 3 milliards de dollars, visait principalement la
#       séquence de l'euchromatine. Ce projet a duré environ 15 ans, impliquant 20
#       centres dans 6 pays. La cartographie génétique, basée sur les fréquences
#       de recombinaison, et la cartographie physique, mesurant les distances
#       réelles en kilobases ou mégabases, ont été des étapes clés. La séquence
#       brouillon a été publiée en 2000, couvrant 90 % du génome avec une qualité
#       variable, et la version finale, de haute qualité (99 %), a été achevée en
#       2003.
#   [4] L'architecture globale du génome humain est explorée à l'aide d'outils
#       tels que le navigateur du génome de l'Université de Californie, Santa Cruz
#       (UCSC). Ce navigateur permet la visualisation des chromosomes, des gènes,
#       des protéines et des régions conservées. Le génome nucléaire haploïde
#       humain mesure environ 3,1 gigabases, avec une distinction entre
#       l'hétérochromatine constitutive, partie condensée et
#       transcriptionnellement inactive, et l'euchromatine, riche en gènes et
#       transcriptionnellement active.
#   [5] Le génome mitochondrial est compact, d'environ 16,6 kilobases, et contient
#       37 gènes, dont 13 codants pour des protéines impliquées dans la
#       phosphorylation oxydative, et 24 ARN non codants (22 ARNt et 2 ARNr). Il
#       utilise un code génétique légèrement différent de celui du génome
#       nucléaire. Ce génome est d'origine endosymbiotique, proche de celui des
#       bactéries alpha-protéobactéries, et est hérité de manière maternelle.
#       Chaque cellule contient plus de 1000 copies du génome mitochondrial, avec
#       une hétéroplasmie variable selon le tissu et l'âge.
#   [6] Le génome nucléaire, séquencé initialement en 2001 sous forme de brouillon
#       et complété en 2022, comprend environ 3,1 gigabases haploïdes. Il est
#       composé d'environ 0,2 gigabases d'hétérochromatine constitutive, zones
#       condensées et transcriptionnellement inactives, et de 2,9 gigabases
#       d'euchromatine, riches en gènes et transcriptionnellement actives.
#
#   [Level 1] ID: SEC_2.1
#   Title: Projet de séquençage
#   Content:
#     [1] Le projet international de séquençage du génome humain, initié en 1990,
#         a duré environ 15 ans avec un budget global d'environ 3 milliards de
#         dollars. L'objectif principal était de déterminer la séquence de
#         l'euchromatine, la partie active du génome.
#     [2] La cartographie génétique, basée sur les fréquences de recombinaison
#         exprimées en centimorgans, a permis de localiser les gènes sur les
#         chromosomes. Parallèlement, la cartographie physique, mesurant les
#         distances réelles en kilobases ou mégabases, a affiné cette
#         localisation.
#     [3] Le séquençage a débuté en 1999, impliquant 20 centres répartis dans 6
#         pays. En 2000, une version brouillon couvrant environ 90 % du génome a
#         été publiée, bien que la qualité fût variable. La version finale, de
#         haute qualité (99 %), a été achevée en 2003, marquant une étape majeure
#         dans la compréhension du génome humain. Cependant, des travaux
#         complémentaires sont toujours nécessaires pour parfaire cette
#         connaissance.
#
#   [Level 1] ID: SEC_2.2
#   Title: Architecture globale
#   Content:
#     [1] L'architecture du génome humain est complexe et peut être explorée à
#         l'aide de navigateurs génomiques tels que celui de l'Université de
#         Californie, Santa Cruz (UCSC). Ces outils permettent la visualisation
#         détaillée des chromosomes, des gènes, des protéines et des régions
#         conservées, facilitant ainsi l'étude fonctionnelle et comparative.
#     [2] Le génome nucléaire haploïde humain mesure environ 3,1 gigabases. Il est
#         organisé en deux grandes parties : l'hétérochromatine constitutive,
#         d'environ 0,2 gigabases, qui correspond à une partie condensée du génome
#         et est transcriptionnellement inactive, et l'euchromatine, d'environ 2,9
#         gigabases, riche en gènes et transcriptionnellement active.
#     [3] Le génome mitochondrial, quant à lui, est compact, circulaire et
#         d'environ 16,6 kilobases. Il contient 37 gènes, dont 13 codants pour des
#         protéines impliquées dans la phosphorylation oxydative, et 24 ARN non
#         codants. Ce génome est d'origine endosymbiotique, proche de celui des
#         bactéries alpha-protéobactéries, et est hérité de manière maternelle.
#         Chaque cellule contient plus de 1000 copies du génome mitochondrial,
#         avec une hétéroplasmie variable selon le tissu et l'âge.
#
#     [Level 2] ID: SEC_2.2.1
#     Title: Génome mitochondrial
#     Content:
#       [1] Le génome mitochondrial humain est une molécule compacte d'environ
#           16,6 kilobases, séquencée complètement dès 1981. Il contient 37 gènes
#           au total, dont 13 codent pour des protéines impliquées dans la
#           phosphorylation oxydative, et 24 sont des ARN non codants, comprenant
#           22 ARN de transfert (ARNt) et 2 ARN ribosomaux (ARNr).
#       [2] Bien que le code génétique soit universel, son utilisation diffère
#           légèrement dans le génome mitochondrial, avec 60 codons codant pour
#           des acides aminés et 4 codons stop. Ce génome est très proche de celui
#           des bactéries, témoignant de son origine endosymbiotique issue d'une
#           alpha-protéobactérie.
#       [3] Le génome mitochondrial est hérité exclusivement de la mère et chaque
#           cellule contient plus de 1000 copies. L'hétéroplasmie, c'est-à-dire la
#           présence de copies différentes du génome mitochondrial au sein d'une
#           même cellule, varie selon le tissu et l'âge, ce qui peut avoir des
#           implications fonctionnelles et pathologiques.
#       [4] Une comparaison des génomes mitochondriaux entre différentes espèces,
#           telles que Drosophila melanogaster, Saccharomyces cerevisiae,
#           Arabidopsis thaliana et Homo sapiens, révèle des différences de
#           taille, d'organisation et de nombre de gènes, illustrant la diversité
#           évolutive de ces génomes.
#
#     [Level 2] ID: SEC_2.2.2
#     Title: Génome nucléaire
#     Content:
#       [1] Le génome nucléaire humain haploïde mesure environ 3,1 gigabases. Il a
#           été séquencé et rendu disponible sous forme de brouillon en 2001, avec
#           une version complète finalisée en 2022.
#       [2] Ce génome est composé d'hétérochromatine constitutive, représentant
#           environ 0,2 gigabases, qui correspond à une partie condensée du génome
#           et est transcriptionnellement inactive, notamment dans les zones
#           hautement répétées.
#       [3] L'euchromatine, d'environ 2,9 gigabases, est la partie riche en gènes
#           et transcriptionnellement active, jouant un rôle central dans
#           l'expression génétique et la fonction cellulaire.
#
#   [Level 1] ID: SEC_2.3
#   Title: Description des principaux éléments constituants
#   Content:
#     [1] Le génome humain est constitué de divers éléments, dont les gènes
#         codants et non codants, les pseudogènes et les éléments répétés. Ces
#         composants structurent l'information génétique et participent à la
#         régulation et à la diversité fonctionnelle du génome.
#
#     [Level 2] ID: SEC_2.3.1
#     Title: Gènes (codants et non-codants), pseudogènes et éléments répétés
#     Content:
#       [1] Un gène est défini comme un segment d'ADN utilisé comme matrice pour
#           la synthèse d'un ARN simple brin lors de la transcription. Les ARN
#           codants, ou ARNm, contiennent l'information nécessaire à la synthèse
#           protéique, tandis que les ARN non codants, répartis en onze classes
#           majeures, jouent divers rôles fonctionnels, notamment dans la
#           traduction (ARNt, ARNr) et la régulation de l'expression génétique
#           (miARN, snARN, snoARN, lncARN).
#       [2] Le nombre total de gènes codants est estimé à environ 20 000, couvrant
#           environ 1,1 % du génome, tandis que les gènes non codants dépassent
#           les 40 000, avec un total combiné proche de 60 000, bien que ce
#           chiffre reste à valider et s'affine avec l'amélioration des
#           annotations.
#       [3] Les gènes présentent une grande diversité en taille et en structure.
#           La taille moyenne est d'environ 54 kilobases, avec des extrêmes allant
#           de quelques centaines de paires de bases à plusieurs mégabases. Les
#           protéines codées varient également en taille, de quelques acides
#           aminés à plus de 34 000. Les gènes sont composés d'exons et d'introns,
#           avec une moyenne de 10 exons par gène et des introns pouvant atteindre
#           plusieurs kilobases.
#       [4] L'organisation des gènes sur le génome peut être non regroupée, avec
#           des territoires géniques indépendants et des sens de transcription
#           variables, ou groupée en clusters résultant de duplications en tandem.
#           Ces clusters partagent souvent des séquences homologues, un sens de
#           transcription identique et peuvent contenir des pseudogènes. Des
#           exemples remarquables incluent la famille des gènes d'histones et
#           celle des récepteurs olfactifs, ce dernier comprenant plus de 900
#           gènes répartis en 25 grands clusters.
#       [5] Les gènes non codants comprennent notamment les ARN de transfert
#           (environ 500 gènes et 300 pseudogènes) et les ARN ribosomaux,
#           essentiels à la traduction. Les ARN ribosomaux 5S sont présents en
#           plusieurs copies dans de petits clusters, tandis que les ARN 45S,
#           incluant 28S, 5,8S et 18S, sont répétées de 30 à 40 fois. Le nombre
#           total de ces gènes reste mal connu, car ils ont été exclus du projet
#           initial du génome humain.
#       [6] Les pseudogènes sont des copies généralement défectueuses de gènes
#           fonctionnels, partageant une similarité de séquence significative. Ils
#           représentent environ 10 % des gènes codants, avec plus de 14 000
#           pseudogènes décrits, répartis en trois catégories principales :
#           processés (rétrotransposés), non processés (duplications) et unitaires
#           (gènes en fin de vie).
#       [7] Les pseudogènes non processés conservent la structure intron-exon et
#           les régions régulatrices, tandis que les pseudogènes processés
#           résultent de la rétrotransposition d'ARNm, perdant la structure
#           intron-exon et les régions régulatrices. Les pseudogènes unitaires
#           résultent de la désactivation progressive d'un gène sous faible
#           pression de sélection.
#       [8] Bien que longtemps considérés comme des gènes fossiles, environ 15 %
#           des pseudogènes sont transcrits, suggérant des fonctions potentielles
#           encore mal comprises. Ils participent aux mécanismes évolutifs du
#           génome, avec une corrélation entre l'expression des gènes et le nombre
#           de pseudogènes, notamment de type processé.
#       [9] Les éléments répétés constituent une part importante du génome humain,
#           avec environ 6,5 % en répétitions en tandem, telles que les ADN
#           satellites, minisatellites et microsatellites, et 40 à 45 % en
#           éléments répétés dispersés, dérivés des transposons. Ces éléments
#           mobiles, incluant les rétrotransposons (LINE, SINE, rétrovirus) et les
#           transposons, ont des mécanismes de déplacement variés et jouent un
#           rôle dans l'évolution du génome.
#       [10] Les éléments répétés en tandem sont principalement localisés dans
#           l'hétérochromatine constitutive et se caractérisent par des unités
#           répétées de tailles variables. Les microsatellites, polymorphiques et
#           répartis en moyenne tous les 30 kilobases, sont utilisés en
#           génotypage, cartographie génétique et médecine légale.
#       [11] Les éléments répétés dispersés comprennent les rétrotransposons, qui
#           se déplacent par un mécanisme de copie via un intermédiaire ARN, et
#           les transposons, qui se déplacent par excision et réinsertion. Les
#           rétrotransposons LINE et SINE sont les plus abondants, avec LINE-1
#           encore actif dans le génome humain. Les transposons sont généralement
#           considérés comme inactifs ou fossiles.
#       [12] En conclusion, les éléments répétés représentent une part
#           significative du génome humain, la plupart étant inactifs, mais ils
#           constituent un mécanisme important de l'évolution génomique.
#
# [Root] ID: SEC_3
# Title: Comparaison aux autres génomes
# Content:
#   [1] La comparaison entre le génome nucléaire et mitochondrial humain révèle
#       des différences marquées. Le génome nucléaire est composé de 23 paires de
#       chromosomes, totalisant environ 3,1 gigabases, tandis que le génome
#       mitochondrial est une molécule circulaire unique d'environ 16,6 kilobases.
#       Le nombre de copies du génome nucléaire est de 23 ou 46 selon le stade
#       cellulaire, alors que le génome mitochondrial est présent en plus de 1000
#       copies par cellule.
#   [2] Le nombre de gènes codants est d'environ 20 000 pour le génome nucléaire
#       et de 13 pour le génome mitochondrial. Les gènes non codants sont estimés
#       à plus de 40 000 dans le génome nucléaire et à 24 dans le génome
#       mitochondrial. La densité génique est beaucoup plus élevée dans le génome
#       mitochondrial, avec un gène tous les 0,45 kilobases, contre un gène tous
#       les 120 kilobases dans le génome nucléaire.
#   [3] Les zones répétées occupent plus de 50 % du génome nucléaire, alors
#       qu'elles sont peu présentes dans le génome mitochondrial. Les introns sont
#       présents dans le génome nucléaire mais absents dans le génome
#       mitochondrial. La composition en bases G+C est similaire, autour de 41 %
#       pour le génome nucléaire et 44 % pour le mitochondrial. L'hérédité du
#       génome nucléaire est mendélienne, avec un allèle d'origine paternelle et
#       un d'origine maternelle, tandis que le génome mitochondrial est hérité
#       exclusivement de la mère.
#   [4] La comparaison des génomes humains avec ceux d'autres espèces montre que
#       la capacité codante n'est pas proportionnelle à la taille du génome ni au
#       nombre de chromosomes. Par exemple, certains protozoaires unicellulaires
#       possèdent un nombre de gènes comparable ou supérieur à celui d'organismes
#       multicellulaires complexes. Le nombre de gènes varie selon les groupes
#       d'organismes, sans refléter directement leur complexité biologique.
#   [5] Une relation linéaire est observée entre la compacité des génomes et leur
#       densité en gènes, avec des génomes compacts présentant une forte densité
#       génique. Cependant, il n'existe pas de corrélation entre la taille d'un
#       génome eucaryote et le nombre de gènes qu'il contient, illustrant la
#       complexité de l'organisation génomique.
#   [6] Parmi les génomes nucléaires comparés, celui de Drosophila melanogaster
#       mesure environ 122,6 mégabases avec environ 14 000 gènes, Saccharomyces
#       cerevisiae 12,2 mégabases avec 5 800 gènes, Oryza sativa japonica 430
#       mégabases avec environ 40 000 gènes, tandis que le génome humain atteint
#       3,1 gigabases avec environ 21 000 gènes. Le plus grand génome connu,
#       d'environ 150 gigabases, possède 40 chromosomes, illustrant la diversité
#       extrême des génomes.
#
# [Root] ID: SEC_4
# Title: Les types de variations du génome humain et leurs conséquences
# Content:
#   [1] Les variations du génome humain sont multiples et ont des conséquences
#       diverses. Une mutation est définie en biologie comme une modification
#       héritée de l'information génétique d'une espèce. En génétique médicale,
#       elle désigne une modification de la séquence du génome responsable d'un
#       phénotype, souvent pathologique. Un polymorphisme est une variation
#       bénigne, non pathologique, présente à une fréquence élevée dans une
#       population.
#   [2] La terminologie précise est essentielle pour éviter les confusions. Une
#       variation désigne toute différence entre la séquence d'un génome de
#       référence et celle d'un individu de la même espèce. Les variations peuvent
#       concerner une ou quelques bases (1-50 bases), appelées Single Nucleotide
#       Variations (SNV), ou un grand nombre de bases (>50 bases), appelées
#       variations de structure ou Copy Number Variations (CNV).
#   [3] La nomenclature des variations utilise des référentiels stables et non
#       ambigus, incluant le nom du gène, la référence ARNm ou protéique, et la
#       position génomique. Par exemple, une substitution peut être notée c.76A>T
#       au niveau de l'ARN messager, ou p.Arg22Ser au niveau protéique, indiquant
#       le changement d'un acide aminé spécifique.
#   [4] Un individu peut présenter plusieurs variations, soit sur des allèles
#       différents, soit sur le même allèle, ce qui complique l'interprétation
#       génétique. Les polymorphismes, tels que les Single Nucleotide
#       Polymorphisms (SNP), sont des variations fréquentes dans la population,
#       avec des exemples connus dans des gènes comme BBS1 ou CFTR, présentant des
#       fréquences variables selon les populations.
#   [5] Les variants pathogènes ou délétères affectent la fonction des protéines
#       et sont responsables de pathologies. Par exemple, des mutations dans le
#       gène RPGR sur le chromosome X causent une rétinopathie pigmentaire chez
#       l'homme, tandis que des mutations dans le gène BBS1 sur le chromosome 11
#       sont associées au syndrome de Bardet-Biedl en mode autosomique récessif.
#   [6] Les variations peuvent être rares ou fréquentes, bénignes ou pathogènes,
#       et peuvent causer des phénotypes variés, allant de traits physiques comme
#       la couleur des cheveux à des maladies génétiques. La variabilité du génome
#       humain est une source majeure de diversité et de susceptibilité aux
#       maladies.
#   [7] Les types de variations incluent les substitutions, les insertions et
#       délétions (indels), les variations d'épissage, les expansions de triplets,
#       et les variations de structure. Les substitutions peuvent être des
#       transitions (purine à purine ou pyrimidine à pyrimidine) ou des
#       transversions (purine à pyrimidine ou inverse). Les indels peuvent
#       provoquer un décalage du cadre de lecture si leur taille n'est pas
#       multiple de trois.
#   [8] Les variations d'épissage affectent les sites donneurs ou accepteurs,
#       entraînant des modifications dans l'inclusion ou l'exclusion d'exons, ce
#       qui peut perturber la structure protéique. Les expansions de triplets,
#       mutations dynamiques, sont responsables d'environ 50 pathologies, telles
#       que la maladie de Huntington ou le syndrome X-Fragile.
#   [9] Les variations de structure concernent des modifications importantes du
#       génome (>50 bases), incluant des délétions, duplications, inversions ou
#       translocations. Elles peuvent être équilibrées ou déséquilibrées,
#       affectant un grand nombre de bases et représentant la plus grande source
#       de variation en termes de taille.
#   [10] D'autres mécanismes rares, comme la conversion génique ou l'empreinte
#       parentale, modifient l'expression génétique par des mécanismes
#       épigénétiques. Chaque type de variation doit être évalué pour son
#       potentiel causal dans les pathologies.
#   [11] Les effets des variations peuvent être une perte de fonction (totale ou
#       partielle), un gain de fonction, ou un effet dominant négatif. Ces
#       mécanismes influencent la gravité et la nature des maladies génétiques
#       associées.
#
# [Root] ID: SEC_5
# Title: La variabilité du génome humain
# Content:
#   [1] La variabilité du génome humain est considérable, résultant de nombreuses
#       sources de variations, tant rares que fréquentes. Certaines variations
#       sont dues à des effets fondateurs ou à des mécanismes moléculaires
#       spécifiques.
#   [2] Plus d'1,1 milliard de variations ont été décrites dans la base de données
#       dbSNP, couvrant environ 34 % du génome humain. Par ailleurs, plus de 7
#       millions de variations structurales sont recensées dans la base DGV,
#       représentant environ 79 % du génome. Ces données illustrent l'ampleur et
#       la complexité de la diversité génomique au sein de l'espèce humaine.
#
# [Root] ID: SEC_6
# Title: Evolution des génomes: notions essentielles, mécanismes
# Content:
#   [1] L'évolution des génomes est un processus dynamique qui modifie le matériel
#       génétique des espèces au fil du temps. Ce processus repose sur les notions
#       essentielles d'évolution, de temps, d'adaptation et de sélection
#       naturelle. Les variations génomiques peuvent conférer un avantage
#       sélectif, permettant aux espèces de mieux s'adapter à leur environnement
#       et favorisant l'apparition de nouvelles espèces.
#   [2] Les mécanismes d'évolution génomique incluent les variations ponctuelles,
#       telles que les substitutions et les insertions/délétions, ainsi que les
#       variations structurales plus importantes. Ces modifications peuvent
#       entraîner l'ajout, la perte ou le remaniement de segments d'ADN.
#   [3] La duplication d'exons en tandem est un mécanisme fréquent, affectant
#       environ 10 % des gènes humains. Elle est responsable de la formation de
#       domaines répétés dans les protéines, résultant souvent d'une recombinaison
#       illégitime avec une résolution inégale d'un crossing-over.
#   [4] Le brassage d'exons, ou exon shuffling, est un autre mécanisme évolutif,
#       impliquant des recombinaisons non alléliques ou l'action de
#       rétrotransposons tels que les LINEs. Ce processus permet la création de
#       nouvelles combinaisons d'exons, favorisant la diversité protéique.
#   [5] La duplication des gènes peut se produire selon différents scénarios,
#       allant de la duplication partielle à la duplication complète du génome.
#       Ces événements ont joué un rôle majeur dans l'expansion des familles de
#       gènes et la complexification des organismes.
#   [6] La duplication complète du génome, bien que rare, a été observée dans
#       certaines lignées évolutives, contribuant à une augmentation massive du
#       matériel génétique et à la diversification fonctionnelle.
#   [7] Ces mécanismes évolutifs sont fondamentaux pour comprendre la diversité
#       biologique et les adaptations des espèces, ainsi que les bases génétiques
#       des maladies et des traits phénotypiques.

# %%
encoder = tiktoken.get_encoding("cl100k_base")  # GPT-4 encoding
text_course_with_slides = str(course)
token_count = len(encoder.encode(text_course_with_slides))
print(token_count)
# Out:
# 3992
