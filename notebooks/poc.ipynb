# %%
import pdfplumber
from statistics import mean


def extract_slides(pdf_path: str,
                   min_avg_len: int = 10,
                   max_lines: int = 20,
                   merge_tol: float = 2.0):
    slides = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            txt = page.extract_text() or ""
            lines = [l for l in txt.splitlines() if l.strip()]
            if not lines:                      # page vide
                continue
            if mean(map(len, lines)) < min_avg_len or len(lines) > max_lines:
                continue

            words = page.extract_words(extra_attrs=["size"], use_text_flow=True)
            # regroupe en lignes
            rows, cur, cur_top = [], [], None
            for w in sorted(words, key=lambda w: w["top"]):
                if cur_top is None or abs(w["top"] - cur_top) <= merge_tol:
                    cur.append(w); cur_top = cur_top or w["top"]
                else:
                    rows.append(cur); cur, cur_top = [w], w["top"]
            if cur: rows.append(cur)

            first5 = rows[:5]
            title = (
                " ".join(w["text"] for w in max(first5,
                                                key=lambda r: mean(w["size"] for w in r)))
                if first5 else f"Slide {page.page_number}"
            )

            slides.append({
                "id": f"SL_{page.page_number:03}",   # <─ identifiant slide
                "title": title,
                "content": txt.strip()
            })
    return slides




slides = extract_slides("./volume/slides/cours_1.pdf")

for slide in slides[:10]:
    print(f"Slide number: {slide['id']}")
    print(f"Slide title: {slide['title']}")
    print(slide["content"])
    print("="*100)
# Out:
# Cannot set gray non-stroke color because /'P412' is an invalid float value
# Cannot set gray non-stroke color because /'P414' is an invalid float value
# Cannot set gray non-stroke color because /'P444' is an invalid float value
# Cannot set gray non-stroke color because /'P451' is an invalid float value
# Cannot set gray non-stroke color because /'P455' is an invalid float value
# Cannot set gray non-stroke color because /'P465' is an invalid float value
# Cannot set gray non-stroke color because /'P467' is an invalid float value
# Cannot set gray non-stroke color because /'P482' is an invalid float value
# Cannot set gray non-stroke color because /'P488' is an invalid float value
# Slide number: SL_001
# Slide title: 7.1 Architecture du génome
# L1SpS: UE 2 Les molécules du vivant
# U.E.2 Les molécules du vivant
# 7. Organisation du génome humain, méthodes en
# biotechnologie
# 7.1 Architecture du génome
# humain
# Jean Muller
# Laboratoire Diagnostic Génétique (HUS)
# Laboratoire de Génétique médicale (Inserm U1112)
# jeanmuller@unistra.fr
# ====================================================================================================
# Slide number: SL_002
# Slide title: Plan du cours
# L1SpS: UE 2 Les molécules du vivant
# Plan du cours
# • Introduction
# • Notions fondamentales
# • Le génome humain
# • Projet de séquençage
# • Architecture globale
# • Génome mitochondrial
# • Génome nucléaire
# • Description des principaux éléments constituants
# • Gènes (codants et non-codants), pseudogènes et éléments répétés
# • Comparaison aux autres génomes
# • Les types de variations du génome humain et leurs conséquences
# • La variabilité du génome humain
# • Evolution des génomes: notions essentielles, mécanismes
# 2
# ====================================================================================================
# Slide number: SL_003
# Slide title: Introduction
# L1SpS: UE 2 Les molécules du vivant
# Introduction
# 3
# ====================================================================================================
# Slide number: SL_004
# Slide title: L’arbre de la vie
# L1SpS: UE 2 Les molécules du vivant
# L’arbre de la vie
# Notions essentielles:
# • Evolution
# • Temps
# • Adaptation
# • Sélection
# LUCA
# Last Universal Common Ancestor
# 4
# ====================================================================================================
# Slide number: SL_005
# Slide title: Arbre des eucaryotes
# L1SpS: UE 2 Les molécules du vivant
# Arbre des eucaryotes
# Choix d’organismes modèles
# • Intérêt(s) économique(s)
# • Intérêt(s) technique(s)
# • Facilités hébergement,
# • Développement embryonnaire/temps
# de génération
# • Partage d’éléments communs (ADN)
# • Hérités/Transmis
# 35 eucaryotes
# 18 métazoaires
# 5
# ====================================================================================================
# Slide number: SL_006
# Slide title: A propos de l’homologie
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Définition
# • En biologie, l'homologie désigne un caractère propre à plusieurs
# espèces hérité d'un ancêtre commun. Les structures en question, qu'elles
# soient d'ordre anatomique, moléculaire ou génétique, partagent donc une
# histoire évolutive.
# • ≠ analogie (ex: ailes oiseaux et insectes qui est une évolution séparée)
# • Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant
# évolué à partir d’un gène ancestral suite à une spéciation
# • Paralogie (gènes paralogues): gènes homologues au sein de la même
# espèce ayant évolué à partir d’un gène ancestral par duplication au cours de
# l’évolution de cette espèce.
# 6
# ====================================================================================================
# Slide number: SL_007
# Slide title: A propos de l’homologie
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Définition
# • En biologie, l'homologie désigne un caractère propre à plusieurs espèces
# hérité d'un ancêtre commun. Les structures en question, qu'elles soient
# d'ordre anatomique, moléculaire ou génétique, partagent donc une histoire
# évolutive.
# • Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant
# évolué à partir d’un gène ancestral suite à une spéciation
# • Paralogie (gènes paralogues): gènes homologues au sein de la même
# espèce ayant évolué à partir d’un gène ancestral par duplication au cours de
# l’évolution de cette espèce.
# 7
# ====================================================================================================
# Slide number: SL_008
# Slide title: A propos de l’homologie
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Exemple
# 8
# ====================================================================================================
# Slide number: SL_009
# Slide title: A propos de l’homologie
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Comment déterminer si les gènes sont homologues ou pas?
# • Les séquences des génomes peuvent être alignées entres elles tout comme
# les séquences des protéines.
# • La comparaison de 2 séquences permet d’établir une évaluation de leur
# proximité ou de leur éloignement par le calcul:
# • du pourcentage d’identité* entre ces 2 séquences
# * résidus strictement identique
# • du pourcentage de similarité* entre ces 2 séquences
# * résidus identique + proche (critère à déterminer; ex: caractéristiques physicochimiques)
# • Seuil de significativité >20% (dépendant de la famille de protéines)
# 9
# ====================================================================================================
# Slide number: SL_010
# Slide title: A propos de l’homologie
# L1SpS: UE 2 Les molécules du vivant
# A propos de l’homologie
# • Remarques:
# • Un % similarité/identité non significatif ne veut pas dire que les gènes, ne sont
# pas homologues.
# • 2 séquences similaires peuvent l’être :
# • par hasard (région de faible complexité)
# • par convergence évolutive
# <15% identité
# Actine humaine MreB bactérienne
# 10
# ====================================================================================================

# %%
import dotenv
dotenv.load_dotenv()

import openai

client = openai.OpenAI()

from models import *

# %%
from models import Slides, Content, ContentSection, SectionSlideMapping

formated_slides = []


for slide in slides:
    #-print(type(slide['id']), type(slide['title']), type(slide['content']))
    formated_slides.append(Slides(id=slide['id'], 
                                title=slide['title'],
                                content=slide['content']))

formated_slides
# Out:
# [Slides(id='SL_001', title='7.1 Architecture du génome', content='L1SpS: UE 2 Les molécules du vivant\nU.E.2 Les molécules du vivant\n7. Organisation du génome humain, méthodes en\nbiotechnologie\n7.1 Architecture du génome\nhumain\nJean Muller\nLaboratoire Diagnostic Génétique (HUS)\nLaboratoire de Génétique médicale (Inserm U1112)\njeanmuller@unistra.fr'),
#  Slides(id='SL_002', title='Plan du cours', content='L1SpS: UE 2 Les molécules du vivant\nPlan du cours\n• Introduction\n• Notions fondamentales\n• Le génome humain\n• Projet de séquençage\n• Architecture globale\n• Génome mitochondrial\n• Génome nucléaire\n• Description des principaux éléments constituants\n• Gènes (codants et non-codants), pseudogènes et éléments répétés\n• Comparaison aux autres génomes\n• Les types de variations du génome humain et leurs conséquences\n• La variabilité du génome humain\n• Evolution des génomes: notions essentielles, mécanismes\n2'),
#  Slides(id='SL_003', title='Introduction', content='L1SpS: UE 2 Les molécules du vivant\nIntroduction\n3'),
#  Slides(id='SL_004', title='L’arbre de la vie', content='L1SpS: UE 2 Les molécules du vivant\nL’arbre de la vie\nNotions essentielles:\n• Evolution\n• Temps\n• Adaptation\n• Sélection\nLUCA\nLast Universal Common Ancestor\n4'),
#  Slides(id='SL_005', title='Arbre des eucaryotes', content='L1SpS: UE 2 Les molécules du vivant\nArbre des eucaryotes\nChoix d’organismes modèles\n• Intérêt(s) économique(s)\n• Intérêt(s) technique(s)\n• Facilités hébergement,\n• Développement embryonnaire/temps\nde génération\n• Partage d’éléments communs (ADN)\n• Hérités/Transmis\n35 eucaryotes\n18 métazoaires\n5'),
#  Slides(id='SL_006', title='A propos de l’homologie', content="L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Définition\n• En biologie, l'homologie désigne un caractère propre à plusieurs\nespèces hérité d'un ancêtre commun. Les structures en question, qu'elles\nsoient d'ordre anatomique, moléculaire ou génétique, partagent donc une\nhistoire évolutive.\n• ≠ analogie (ex: ailes oiseaux et insectes qui est une évolution séparée)\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\névolué à partir d’un gène ancestral suite à une spéciation\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\nl’évolution de cette espèce.\n6"),
#  Slides(id='SL_007', title='A propos de l’homologie', content="L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Définition\n• En biologie, l'homologie désigne un caractère propre à plusieurs espèces\nhérité d'un ancêtre commun. Les structures en question, qu'elles soient\nd'ordre anatomique, moléculaire ou génétique, partagent donc une histoire\névolutive.\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\névolué à partir d’un gène ancestral suite à une spéciation\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\nl’évolution de cette espèce.\n7"),
#  Slides(id='SL_008', title='A propos de l’homologie', content='L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Exemple\n8'),
#  Slides(id='SL_009', title='A propos de l’homologie', content='L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Comment déterminer si les gènes sont homologues ou pas?\n• Les séquences des génomes peuvent être alignées entres elles tout comme\nles séquences des protéines.\n• La comparaison de 2 séquences permet d’établir une évaluation de leur\nproximité ou de leur éloignement par le calcul:\n• du pourcentage d’identité* entre ces 2 séquences\n* résidus strictement identique\n• du pourcentage de similarité* entre ces 2 séquences\n* résidus identique + proche (critère à déterminer; ex: caractéristiques physicochimiques)\n• Seuil de significativité >20% (dépendant de la famille de protéines)\n9'),
#  Slides(id='SL_010', title='A propos de l’homologie', content='L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Remarques:\n• Un % similarité/identité non significatif ne veut pas dire que les gènes, ne sont\npas homologues.\n• 2 séquences similaires peuvent l’être :\n• par hasard (région de faible complexité)\n• par convergence évolutive\n<15% identité\nActine humaine MreB bactérienne\n10'),
#  Slides(id='SL_011', title='Biologie du gène – dogme central', content='L1SpS: UE 2 Les molécules du vivant\nBiologie du gène – dogme central\n11'),
#  Slides(id='SL_012', title='Références', content='L1SpS: UE 2 Les molécules du vivant\nRéférences\n• Le génome est une des références d’un organisme\n…\nméthylome\nprotéome\ntranscriptome\ngénome\n12'),
#  Slides(id='SL_013', title='Le génome humain', content='L1SpS: UE 2 Les molécules du vivant\nLe génome humain\n13'),
#  Slides(id='SL_014', title='Homo sapiens', content='L1SpS: UE 2 Les molécules du vivant\nHomo sapiens\n• Composition du génome humain :\n• Génome nucléaire\n• 22 paires chromosomes homologues (autosomes: 1 à 22)\n• 1 paire chromosomes sexuels (gonosomes: X et Y)\n• Génome mitochondrial\n• Molécule circulaire\nIllustration des chromosomes humains condensés en métaphase du cycle cellulaire (≠organisation des chromosomes dans le noyau hors métaphase)\n14'),
#  Slides(id='SL_015', title='Composition générale du génome', content='L1SpS: UE 2 Les molécules du vivant\nComposition générale du génome\nGénome haploïde\nNomenclature de Paris (1971)\n15'),
#  Slides(id='SL_016', title='Composition générale du génome', content='L1SpS: UE 2 Les molécules du vivant\nComposition générale du génome\nRésolution\nNomenclature de Paris (1971)\n16'),
#  Slides(id='SL_017', title='Composition générale du génome', content='L1SpS: UE 2 Les molécules du vivant\nComposition générale du génome\nGénome diploïde\n• Génome maternel et paternel\n17'),
#  Slides(id='SL_018', title='Détermination de la séquence du génome Humain', content='L1SpS: UE 2 Les molécules du vivant\nDétermination de la séquence du génome Humain\n• Projet international: durée ~15 ans, budget global ~3 milliards $\n• Démarrage en 1990\n• Cible principale: séquence de l’euchromatine\n18'),
#  Slides(id='SL_019', title='Projet Génome Humain', content='L1SpS: UE 2 Les molécules du vivant\nProjet Génome Humain\n• Projet international: durée ~15 ans, budget global ~3 milliards $\n• Cartographie génétique: basée sur les fréquences de recombinaison (cM)\n19'),
#  Slides(id='SL_020', title='Projet Génome Humain', content='L1SpS: UE 2 Les molécules du vivant\nProjet Génome Humain\n• Projet international: durée ~15 ans, budget global ~3 milliards $\n• Cartographie physique: distance réelle (en kb ou Mb)\n20'),
#  Slides(id='SL_021', title='Projet Génome Humain', content='L1SpS: UE 2 Les molécules du vivant\nProjet Génome Humain\n• Projet international: durée ~15 ans, budget global ~3 milliards $\n• Début du séquençage en 1999 (20 centres, 6 pays)\n21'),
#  Slides(id='SL_022', title='Projet Génome Humain', content='L1SpS: UE 2 Les molécules du vivant\nProjet Génome Humain\n• Projet international: durée ~15 ans, budget global ~3 milliards $\n• Séquence complète en 2000, version brouillon ou « draft » (90%, qualité variable)\n• Séquence finalisée en 2003, version finale (99%, haute qualité)\n• Fini, vraiment ?\n22'),
#  Slides(id='SL_024', title='Visualisation et exploration du génome humain', content='L1SpS: UE 2 Les molécules du vivant\nVisualisation et exploration du génome humain\n« Genome browser » (navigateur) de l’Université de Californie, Santa Cruz (UCSC)\nChromosome\nZoom\nAnnotations:\n• Gènes\nhttp://genome-euro.ucsc.edu/\n• Protéines\n• Conservation…\n24'),
#  Slides(id='SL_025', title='Exploration du génome humain', content='L1SpS: UE 2 Les molécules du vivant\nExploration du génome humain\nGène X, Y et Z\nZoom\n25'),
#  Slides(id='SL_026', title='Sens de transcription', content='L1SpS: UE 2 Les molécules du vivant\nGène X\nZoom\nSens de transcription\n26'),
#  Slides(id='SL_027', title='Exons', content='L1SpS: UE 2 Les molécules du vivant\nExons\nZoom\nIntrons\n27'),
#  Slides(id='SL_028', title='Zoom', content='L1SpS: UE 2 Les molécules du vivant\nZoom\n28'),
#  Slides(id='SL_029', title='Nucléotides', content='L1SpS: UE 2 Les molécules du vivant\nNucléotides\nAcide aminés\n29'),
#  Slides(id='SL_030', title='Composition générale du génome', content='L1SpS: UE 2 Les molécules du vivant\nComposition générale du génome\n5% du génome conservé au cours de l’évolution\n30'),
#  Slides(id='SL_031', title='Génome mitochondrial', content='L1SpS: UE 2 Les molécules du vivant\nGénome mitochondrial\n• Génome compact\n• 16,6 kb\n• Séquence complète en 1981\n• 37 gènes au total:\n• 13 codants pour des protéines\n• Phosphorylation oxydative\n• 24 non codants (22 ARNt et 2 ARNr)\n• Code génétique universel mais\nutilisation différente (cf chapitre 9):\n• 60 codons codants pour des AA,\n• 4 codons STOP\n31'),
#  Slides(id='SL_032', title='Génome mitochondrial', content='L1SpS: UE 2 Les molécules du vivant\nGénome mitochondrial\n• Très proche d’un génome de bactérie\n• Origine endosymbiotique (alpha-protéobactérie)\n• Héritage maternel\n• >1000 copies/cellule\n• Hétéroplasmie: présence de copies différentes du génome mitochondrial\nau sein de la même cellule:\n• Selon le tissu\n• Selon l’âge\nStewart, J., Larsson, N. PLOS Genetics2014 32'),
#  Slides(id='SL_033', title='Comparaison des génomes mitochondriaux', content='L1SpS: UE 2 Les molécules du vivant\nComparaison des génomes mitochondriaux\nDrosophila Saccharomyces Arabidopsis\nGénome Homo sapiens\nmelanogaster cerevisiae thaliana\nTaille 16,6 kb 19,5 kb 86 kb 367 kb\nOrganisation circulaire linéaire/circulaire\nNombre de copies >1000 20-200\nTotal gènes 37 37 55 60\nGènes codants 13 13 28 33\nGènes ARN 24 24 27 25\nhttps://www.yeastgenome.org/contig/Chromosome_Mito#feature 33'),
#  Slides(id='SL_034', title='Génome nucléaire', content='L1SpS: UE 2 Les molécules du vivant\nGénome nucléaire\n• Taille: 3,1 Gb (haploïde)\n• Séquencé et disponible en 2001 (brouillon)\n• Complète en 2022\n• Hétérochromatine constitutive\n• 0,2 Gb: partie condensée du génome, transcription inactive\n(zones hautement répétées)\n• Euchromatine\n• 2,9 Gb: partie riche en gènes et dont la transcription est active\nCf cours Didier Devys 34'),
#  Slides(id='SL_035', title='Génome nucléaire', content='L1SpS: UE 2 Les molécules du vivant\nGénome nucléaire\n35'),
#  Slides(id='SL_036', title='Les éléments constitutifs du', content='L1SpS: UE 2 Les molécules du vivant\nLes éléments constitutifs du\ngénome humain\n36'),
#  Slides(id='SL_037', title='Gène', content='L1SpS: UE 2 Les molécules du vivant\nGène\n• Définition:\n• Segment d’ADN génomique utilisé comme matrice pour\nsynthétiser un ARN simple brin (transcription).\n• ARN codants, ARNm:\n• contiennent l’information pour la synthèse protéique\n• ARN non-codants:\n• 11 classes majeures\n• ARNt, ARNr: utilisés pour la traduction\n• miARN (microARN): régulation de l’expression\n• snARN, snoARN, lncARN…\n37'),
#  Slides(id='SL_038', title='Définition - Gène', content='L1SpS: UE 2 Les molécules du vivant\nDéfinition - Gène\n38'),
#  Slides(id='SL_039', title='Définition - Gène', content='L1SpS: UE 2 Les molécules du vivant\nDéfinition - Gène\n• Définition:\n• Segment d’ADN génomique utilisé comme matrice pour\nsynthétiser un ARN simple brin (transcription).\n• ARN codants: ~20 000 gènes pour ~35 Mb (~1,1% du génome)*\n• ARN non-codants: > 40 000\n• Le nombre définitif de gènes (codants + non codants) est proche des\n60 000 mais demeure encore incertain (besoin de validation) mais se\nstabilise avec le temps et l’amélioration des annotations.\n*En ne tenant compte que les régions codantes (exclusion des régions régulatrices)\nNurk et al., Science 2022 39'),
#  Slides(id='SL_040', title='Evolution du compte total: gènes codants', content='L1SpS: UE 2 Les molécules du vivant\nEvolution du compte total: gènes codants\n19,969\n2022\n40'),
#  Slides(id='SL_041', title='Ordres de grandeurs', content='L1SpS: UE 2 Les molécules du vivant\nOrdres de grandeurs\n• Taille des gènes: • Taille des protéines:\n• Moyenne: 54 kb • Plus petite: ~10 AA\n• Plus petit: quelques 100aines pb • Plus grande: 34 350 AA (Titin)\n• Plus grand: 2,5 Mb (DMD, dystrophine)\n• Nombre / taille d’exons • Taille des introns\n• Moyenne: 10 / 280 pb • Plus petit: <30 pb\n• Plus petit: 1 (pas d’intron) / <10 pb • Plus grand: 1 Mb\n• Plus grand: 363 (titin) / 18 kb\nLe valeurs sont arrondies au plus proche\nAA:AcideAminé\n41'),
#  Slides(id='SL_042', title='Quelques exemples de structures de gènes codants', content='L1SpS: UE 2 Les molécules du vivant\nQuelques exemples de structures de gènes codants\nGène CDS AA Nombre d’exons\nBleu: exons numérotés ALMS1 13 kb 4169 23 exons\nJaune: intron CEP290 7,4 kb 2403 54 exons\nCDS: séquence codante MKKS 1,7 kb 571 6 exons (3 codants)\nBBS10 2,1 kb 724 2 exons (2 codants)\nBBS12 2,1 kb 711 3 exons (1 codant)\nALMS1\nCEP290\nMKKS\nBBS10\nBBS12\nVisualisation avecAlamut Visual (InteractiveBiosoftware) 42'),
#  Slides(id='SL_043', title='Organisation des gènes sur le génome', content='L1SpS: UE 2 Les molécules du vivant\nOrganisation des gènes sur le génome\n• 2 organisation possibles\n• Non regroupée:\n• Territoire génique indépendant et bien défini\n• Gènes avec des fonctions différentes\n• Pas de similarité de séquence particulière\n• Sens de transcription variable\n43'),
#  Slides(id='SL_044', title='Organisation des gènes sur le génome', content='L1SpS: UE 2 Les molécules du vivant\nOrganisation des gènes sur le génome\n• Non regroupée:\n• Situation bien souvent plus complexe\n• Territoires chevauchants\n44'),
#  Slides(id='SL_045', title='Organisation des gènes sur le génome', content='L1SpS: UE 2 Les molécules du vivant\nOrganisation des gènes sur le génome\n• Groupée ou dite en « cluster »:\n• Origine: liée à une duplication en tandem\n• Les gènes partagent souvent:\n• Sens de transcription identique\n• Séquences homologues\n• Présence de pseudogènes\n• 1 cluster sur 1 chromosome\n• 2 clusters sur 2 chromosomes\n45'),
#  Slides(id='SL_046', title='Exemples d’organisations remarquables', content='L1SpS: UE 2 Les molécules du vivant\nExemples d’organisations remarquables\n• Famille des gènes d’histones (>60 gènes)\n• 3 clusters principaux\n• 2 sur le chromosome 6\n• 1 sur le chromosome 1\n• Plusieurs pseudogènes\nVisualisation avecensemblgenomebrowser 46'),
#  Slides(id='SL_047', title='Exemples d’organisations remarquables', content='L1SpS: UE 2 Les molécules du vivant\nExemples d’organisations remarquables\n• Famille de gènes des récepteurs olfactifs\n• Répertoire définissant notre capacité à détecter des\nodeurs différentes\n• >900 gènes\n• 25 grands clusters\nVisualisation avecensemblgenomebrowser 47'),
#  Slides(id='SL_048', title='Gènes non codants', content='L1SpS: UE 2 Les molécules du vivant\nGènes non codants\n• ARN de transfert (ARNt):\n• Fonction lors de la traduction\n• ~500 gènes et ~300 pseudogènes\n• Plusieurs clusters répartis un peu partout sur le génome\n• ARN ribosomaux (ARNr):\n• Fonction lors de la traduction (composants du ribosome)\n• 5S: plusieurs copies dans de petits clusters (le plus grands\ncontient 16 gènes sur le chromosome 1)\n• 45S incluant 28S/5,8S/18S: 30-40 répétitions\n• Le nombre total est mal connu (exclu du projet initial du\ngénome humain)\n48'),
#  Slides(id='SL_049', title='Pseudogène', content='L1SpS: UE 2 Les molécules du vivant\nPseudogène\n• Définition:\n• Copie généralement défectueuse d’un gène fonctionnel avec lequel le\npseudogène partage une similarité de séquence significative.\n• Concerne 10% des gènes codants, avec un nombre plus important\npour des gènes activement transcrits\n• >14000 décrits pour 3 catégories principales:\n• Pseudogène processé (~72%, ~10 000 copies)\n• Pseudogène non processé (~23%, ~3 500 copies)\n• Pseudogène unitaire (~1,4%, ~200 copies)\n49'),
#  Slides(id='SL_050', title='Origine des pseudogènes', content='L1SpS: UE 2 Les molécules du vivant\nOrigine des pseudogènes\n• Pseudogène dit non processé\n• Mécanisme lié à la duplication d’une partie du génome\n• Conservation de la structure intron/exon*\n• Conservation de la région de régulation\n* divergence par accumulation de variations 50'),
#  Slides(id='SL_051', title='Origine des pseudogènes', content='L1SpS: UE 2 Les molécules du vivant\nOrigine des pseudogènes\n• Pseudogène dit processé\n• Mécanisme lié à la rétrotransposition\nd’un ARNm\n• Perte de la structure intron/exon\n(le pseudogène ne contient que de\nl’exon)\n• Perte de la région de régulation\n51'),
#  Slides(id='SL_052', title='Origine des pseudogènes', content='L1SpS: UE 2 Les molécules du vivant\nOrigine des pseudogènes\n• Pseudogène dit unitaire\n• Mécanisme de fin de vie du gène (pression de sélection diminuée\n-> accumulation de mutations)\n52'),
#  Slides(id='SL_053', title='Pseudogènes - remarques', content='L1SpS: UE 2 Les molécules du vivant\nPseudogènes - remarques\n• Remarques:\n• Longtemps catégorisés comme des gènes « fossiles », leur\nfonction est encore mal connue\n• Pourtant, 15% des pseudogènes sont transcrits\n• Un des mécanismes de l’évolution des génomes\n• En règle générale:\n• Les gènes les plus fortement exprimés ont plus de pseudogènes,\net en particulier de type « processé »\n• Les pseudogènes non processés sont souvent physiquement\nproches des gènes dont ils sont dérivés\n53'),
#  Slides(id='SL_054', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés en tandem\n• 6,5% du génome\n• ADN satellite\n• ADN minisatellite\n• ADN microsatellite\n• Eléments répétés dispersés (« interspersed »)\n• 40-45% du génome\n• Rétrotransposons\n• LINE, SINE (Long/Short Interspersed Elements), rétrovirus\n• Autonomes, non autonomes\n• Transposons\n54'),
#  Slides(id='SL_055', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés en tandem\n• 6,5% du génome\n• Hétérochromatine constitutive\n• 3 classes d’éléments selon la taille totale de la zone répétée\n• Chaque élément est constitué d’unités plus petites hautement répétées\n55'),
#  Slides(id='SL_056', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés en tandem\n• 6,5% du génome\n• Hétérochromatine constitutive\n• 3 classes d’éléments selon la taille totale de la zone répétée\n• Chaque élément est constitué d’unités plus petites hautement répétées\n56'),
#  Slides(id='SL_057', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés en tandem\n• 6,5% du génome\n• Hétérochromatine constitutive\n• 3 classes d’éléments selon la taille totale de la zone répétée\n• Chaque élément est constitué d’unités plus petites hautement répétées\n57'),
#  Slides(id='SL_058', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés en tandem\n• 6,5% du génome\n• Hétérochromatine constitutive\n• 3 classes d’éléments selon la taille totale de la zone répétée\n• Chaque élément est constitué d’unités plus petites hautement répétées\n58'),
#  Slides(id='SL_059', title='Eléments répétés', content="L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés en tandem\n• Microsatellites\n• Disposés en moyenne tous les 30 kb sur le génome humain\n• Polymorphiques (séquences et/ou nombre de répétitions variables d'un\ngénome/individu à l'autre)\n• Application génotypage\n• Carte génétique pour le génome humain\n• Empreintes génétiques et médecine légale\nIndividu 1 Individu 2\n(CA)20 (CA)10\n(CA)35 (CA)40\n59"),
#  Slides(id='SL_060', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés dispersés (« interspersed »)\n• 40-45% du génome\n• Eléments dérivés des transposons. Ce sont des éléments mobiles\ncapables de migrer d’une région du génome à une autre\n• 2 grandes catégories:\n• Rétrotransposons\n• LINE, SINE, rétrovirus\n• Autonomes, non autonomes\n• Transposons\n60'),
#  Slides(id='SL_061', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés dispersés (« interspersed »)\n• Rétrotransposons (« Copié/Collé »): Passage par une étape de\ntranscription (ARN), transcription inverse (ADN) puis intégration\n• LINE: « Long Interspersed Nuclear Elements »\n• 3 sous-familles (Line-1, Line-2, Line-3), seule la 1ère est encore active\n• 1 000 000 de copies dont <1% sont complètes\n• ~100 éléments encore actifs (Line-1)\nORF1: protéine de fixation à l’ARN\nORF2: endonucléase, transcriptase inverse\n61'),
#  Slides(id='SL_062', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés dispersés (« interspersed »)\n• Rétrotransposons (« Copié/Collé »)\n• SINE: « Short Interspersed Nuclear Elements » répartis en 3 sous-\nfamilles dont principalement:\n• Alu: spécifique des primates (élément le plus abondant du génome)\n• MIR: présent chez les mammifères\n• Non autonomes, ils utilisent la machinerie des LINEs\n62'),
#  Slides(id='SL_063', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés dispersés (« interspersed »)\n• Rétrotransposons (« Copié/Collé »):\n• LTR transposons ou rétrovirus\n• LTR (Long Terminal Repeat) contiennent la machinerie utile à la\ntranscription\n2-3 gènes typiques de rétrovirus (gag/pol/env) codent pour une protéase,\ntranscriptase inverse, RNAseH et une intégrase\n63'),
#  Slides(id='SL_064', title='Eléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nEléments répétés\n• Eléments répétés dispersés (« interspersed »)\n• Transposons (« Coupé/Collé »)\n• Déplacement par une transposase qui va exciser l’élément et le\nréinsérer à une autre localisation du génome\n• De nombreuses sous-familles\n• Durée de vie limitée dans un génome\n• Eléments considérés comme inactifs ou « fossiles » du génome\nhumain\n64'),
#  Slides(id='SL_065', title='Conclusion: éléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nConclusion: éléments répétés\n• Une part importante de notre génome\n• La plupart de ces éléments sont inactifs\n• Un des mécanismes de l’évolution des génomes\n65'),
#  Slides(id='SL_066', title='Exemples: visualisation des éléments répétés', content='L1SpS: UE 2 Les molécules du vivant\nExemples: visualisation des éléments répétés\n66'),
#  Slides(id='SL_067', title='Comparaison de nos 2 génomes', content="L1SpS: UE 2 Les molécules du vivant\nComparaison de nos 2 génomes\nGénome Nucléaire Mitochondrial\nTaille 3,1Gb 16,6 kb\nNombre de molécules 23/24 1 circulaire\nNombre de copies 23/46 >1000\nGène codant ~20 000 13\nGène non codant >40 000 (incertitude) 24\nDensité en gène ~1/120 kb 1/0,45 kb\nZones répétées >50% peu\nIntrons Oui Non\n% codant ~1,1% ~66%\n% G+C 41% [38-49] 44%\nHérédité Mendélienne* Maternelle\n* 1 allèle d'origine paternelle et 1 d'origine maternelle\n67"),
#  Slides(id='SL_068', title='Comparaison aux autres génomes', content='L1SpS: UE 2 Les molécules du vivant\nComparaison aux autres génomes\n68'),
#  Slides(id='SL_069', title='Comparaison des génomes', content="L1SpS: UE 2 Les molécules du vivant\nComparaison des génomes\nLa capacité codante d'une espèce n’est pas proportionnelle à la taille du génome en\npaires de bases ni au nombre de chromosomes.\n69\nProtozoaires: eucaryotes unicellulaires, métazoaires: animaux (eucaryotes multicellulaires)"),
#  Slides(id='SL_070', title='Comparaison des génomes', content='L1SpS: UE 2 Les molécules du vivant\nComparaison des génomes\n• Distribution du nombre de gènes dans les 3\ndomaines du vivant:\n• Le nombre de gènes est variable selon les groupes\nd’organismes\n• Le nombre de gènes n’est pas le reflet de la complexité\nd’un organisme\n70'),
#  Slides(id='SL_071', title='Comparaison des génomes', content='L1SpS: UE 2 Les molécules du vivant\nComparaison des génomes\nRelation linéaire, génomes compacts et denses en gènes\n71'),
#  Slides(id='SL_072', title='Comparaison des génomes', content='L1SpS: UE 2 Les molécules du vivant\nComparaison des génomes\nPas de lien entre la taille d’un génome eucaryote et le nombre de gènes\n72'),
#  Slides(id='SL_073', title='Comparaison des génomes nucléaires', content='L1SpS: UE 2 Les molécules du vivant\nComparaison des génomes nucléaires\nDrosophila Saccharomyces Oryza Paris\nGénome Homme\nmelanogaster cerevisiae sativa japonica\nTaille 3,1 Gb 122,6 Mb 12,2 Mb 430 Mb ~150 Gb\nTotal\n~21 000 ~14 000 ~5 800 ~40 000 ?\ngènes\nLe plus grand génome connu (40 chromosomes)\n73'),
#  Slides(id='SL_074', title='Les types de variations du génome', content='L1SpS: UE 2 Les molécules du vivant\nLes types de variations du génome\nhumain et leurs conséquences\n74'),
#  Slides(id='SL_075', title='Définitions', content="L1SpS: UE 2 Les molécules du vivant\nDéfinitions\n• Une mutation?\n• En biologie: une modification héritée de l'information contenue\ndans le génome d’une espèce.\n• En génétique/santé: modification de la séquence du génome\nresponsable d’un phénotype (modification d’un caractère\npathologique) pour cette espèce.\n• Un polymorphisme?\n• Une mutation bénigne/non pathologique\n• Mutation pathogène ou délétère?\n• Possible confusion, besoin d’un vocabulaire contrôlé\n75"),
#  Slides(id='SL_076', title='Définitions', content='L1SpS: UE 2 Les molécules du vivant\nDéfinitions\n• Vocabulaire et nomenclature contrôlée et non ambiguë\n• Une variation: mutation\n• Différence entre la séquence d’un génome de référence et la\nséquence d’un individu de la même espère\n• Une ou quelques bases (1-50 bases)\n• SNV: Single Nucleotide Variation\n• Un grande nombre de bases (>50 bases ou >1 kb)\n• Variation de structure équilibrée ou non\n• CNV: Copy Number Variation\nRéférence GTAAAAGC\nex1 GTATAAGC\nex2 GTA--AGC\n76'),
#  Slides(id='SL_077', title='Définitions', content='L1SpS: UE 2 Les molécules du vivant\nDéfinitions\n• Nomenclature\n• Mémorisable, éloquente, stable, non équivoque\n• Plusieurs référentiels:\n• Nom de gène, référence ARNm/protéine\n• Position (génomique, ARNm, protéique)\n• g. génomique\n• c. ARN messager/cDNA\nRéférence GTAAAAGC\n• p. protéique\nex1 GTATAAGC\nex2 GTA--AGC\nc.76A>T\nRéférentiel Base mutée\nPosition(s) Type de changement\nBase de référence\n77'),
#  Slides(id='SL_078', title='Nomenclature des protéines', content='L1SpS: UE 2 Les molécules du vivant\nNomenclature des protéines\n• Uniquement en plus des informations ADN et ARN\n• Acides aminés décrit sous la forme "Trp26" ou "W26“ (1ère\nlettre majuscule)\np.Arg22fs*5\np.Arg22*\np.Arg22Ser\nRéférentiel AA muté\nAA de référence Position(s)\n78'),
#  Slides(id='SL_079', title='Des variations multiples dans un individu', content='L1SpS: UE 2 Les molécules du vivant\nDes variations multiples dans un individu\n• Génotype\n• 2 variations sur des allèles différents\n• c.[76A>C];[87delG]\n• 2 variations sur le même allèle\n• c.[76A>C;83G>C]\n• 2 variations avec aucune appréciation\n• c.[76A>C(;)83G>C] ? ?\n79'),
#  Slides(id='SL_080', title='Définitions', content='L1SpS: UE 2 Les molécules du vivant\nDéfinitions\n• Un polymorphisme:\n• Variation présente à une fréquence élevée (≥1%) dans une\npopulation donnée\n• SNP: Single Nucleotide Polymorphism\n• Exemples:\n• NM_024649.4(BBS1):c.1413C>T, p.Leu471=\n• EU 38%, AFR 3,77%\n• NM_024649.4(BBS1):c.1169T>G, p.Met390Arg\n• EU 0,27%, AFR 0,09%\n• NM_000492.4(CFTR):c.1521_1523del, p.Phe508del\n– EU 1,24%, AFR 0,26%, SAS 0,0019%\n80'),
#  Slides(id='SL_081', title='Définitions', content='L1SpS: UE 2 Les molécules du vivant\nDéfinitions\n• Variant pathogène ou délétère?\n• Affecte la fonction de la protéine\n• Selon le contexte la variation est responsable de la pathologie\n(causale)\n• Ex. 1: Rétinopathie pigmentaire, gène RPGR (chromosome X)\n• Mode de transmission lié à l’X\n• Variation affectant la fonction de la protéine RPGR\n• Homme: rétinopathie pigmentaire\n• Femme: asymptomatique ou apparition très tardive\n• Ex. 2: Syndrome de Bardet-Biedl, gène BBS1 (chromosome 11)\n• Mode de transmission autosomique récessif\n• Causale d’un syndrome de Bardet-Biedl, si homozygote ou en\nprésence d’un second allèle affectant la fonction de la protéine\n81'),
#  Slides(id='SL_082', title='Définitions', content='L1SpS: UE 2 Les molécules du vivant\nDéfinitions\n• Notions complémentaires\n• Variation rare / fréquente\n• Variation bénigne vs pathogène/délétère\n• Variation causale d’un phénotype\n• Ex: Couleur des cheveux…\n• Une des plus grandes variabilités du génome humain\n• Responsables de la plupart des pathologies humaines liées à\nl’ADN (cancer et maladies rares génétiques)\n82'),
#  Slides(id='SL_083', title='Conséquences - Gène', content='L1SpS: UE 2 Les molécules du vivant\nConséquences - Gène\n83'),
#  Slides(id='SL_084', title='Conséquences - Gène', content='L1SpS: UE 2 Les molécules du vivant\nConséquences - Gène\n84'),
#  Slides(id='SL_085', title='Définitions – quelles variations?', content='L1SpS: UE 2 Les molécules du vivant\nDéfinitions – quelles variations?\nRéférence GTAAAAGC\nex1 GTATAAGC\n• Substitution:\n• Modification d’une base par une autre\n• Transition: Pu<->Pu ou Py<->Py\n• Transversion: Pu<->Py\nPurine\nPyrimidine\n85'),
#  Slides(id='SL_086', title='Définitions – quelles variations?', content='L1SpS: UE 2 Les molécules du vivant\nDéfinitions – quelles variations?\n• Insertion/délétion (indel) :\n• Indel ou petites insertion/délétions (<50pb)\n• Ajout ou délétion d’une ou plusieurs bases\nRéférence GTAAAAGC Référence GTAAAA-GC\nex1 GTAA--GC ex2 GTAAAAAGC\n86'),
#  Slides(id='SL_087', title='Substitutions/indels', content='L1SpS: UE 2 Les molécules du vivant\nSubstitutions/indels\n• Localisation :\n• Partout sur le génome (exon, intron et intergénique)\n• Fréquence:\n• 3-5 millions entre 2 génomes (même sexe)\n• La plus grande source de variation du génome en\nnombre d’évènements\n87'),
#  Slides(id='SL_088', title='Variation du gène', content='L1SpS: UE 2 Les molécules du vivant\nVariation du gène\nSéquence de référence/normale/Sauvage\n88'),
#  Slides(id='SL_089', title='Variation du gène', content='L1SpS: UE 2 Les molécules du vivant\nVariation du gène\nSubstitution dans le gène\nModification d’une base de l’ADN/ARN\nVariation faux-sens Variation silencieuse\n89'),
#  Slides(id='SL_090', title='Variation du gène', content='L1SpS: UE 2 Les molécules du vivant\nVariation du gène\nVariation non-sens\nRappel: 3 codons STOP du génome nucléaire humain: UAA, UAG, UGA\n90'),
#  Slides(id='SL_091', title='Variation du gène', content='L1SpS: UE 2 Les molécules du vivant\nVariation du gène\n• Variation de la 1ère base\n• 95% de chance d’avoir un faux sens\n• Variation de la 2ème base\n• 100% de chance d’avoir un impact (faux\nsens ou non-sens)\n• Variation de la 3ème base\n• 28% de chance d’avoir un faux sens\n91'),
#  Slides(id='SL_092', title='Variation du gène', content='L1SpS: UE 2 Les molécules du vivant\nVariation du gène\nInsertion/délétion d’un nombre de bases non multiple de 3\ninsertion 1 base délétion 1 base\n...\n...\nDécalage du cadre de lecture Décalage du cadre de lecture\nprotéine erronée protéine erronée\n92'),
#  Slides(id='SL_093', title='Variation du gène', content='L1SpS: UE 2 Les molécules du vivant\nVariation du gène\nInsertion/délétion d’un nombre de bases multiple de 3\ndélétion 3 bases insertion 3 bases\nCadre de lecture conservé Cadre de lecture conservé\nperte d’un acide aminé gain d’un acide aminé\n93'),
#  Slides(id='SL_094', title='Variation du gène', content='L1SpS: UE 2 Les molécules du vivant\nVariation du gène\nSite de branchement\n60 100 100\n70 100 100\nADN T T T\nprotéine\nExon n Intron n Exon n+1\nSite donneur (5’) Site accepteur (3’)\nVariation d’épissage\nGT-AG: >98% site d’épissage canonique 94'),
#  Slides(id='SL_095', title='Variation du gène', content='L1SpS: UE 2 Les molécules du vivant\nVariation du gène\nConséquences sur l’épissage:\nRétention complète de l’intron\nRétention partielle de l’intron (5’)\nRétention partielle de l’intron (3’)\nSaut complet d’un exon\nTrès probable décalage du cadre de lecture\n95'),
#  Slides(id='SL_096', title='Variation du gène', content='L1SpS: UE 2 Les molécules du vivant\nVariation du gène\nInsertion / délétion dans le gène Substitution dans le gène\nprotéine erronée variation faux-sens\nprotéine erronée variation non-sens\nInsertion/délétion d’un multiple\nde 3 bases\nmutation épissage\n96'),
#  Slides(id='SL_097', title='Définitions – quelles variations?', content='L1SpS: UE 2 Les molécules du vivant\nDéfinitions – quelles variations?\n• Expansion de triplet\n• Les répétitions (n) de trinucléotides et aussi tétra, penta,\nhexanucléotides\n• X-Fragile: (CGG)\nn\n• Huntington: (CAG)\nn\n• Localisation: 5’UTR, exon, intron ou 3’UTR\n• Zones instables lors de la réplication\n• Expansion du nombre de répétitions\n• Mutation dite dynamique\n• ~ 50 pathologies causées par expansion dans un gène\nDepienne& Mandel AJHG 2021 97'),
#  Slides(id='SL_098', title='Définitions – quelles variations?', content='L1SpS: UE 2 Les molécules du vivant\nDéfinitions – quelles variations?\n• Variations de structures:\n• Modification de la localisation d’un « morceau » du génome\n• Affecte un nombre important de bases (>50 pb à plusieurs Mb)\n• Origine: remaniements chromosomiques ou autres mécanismes\nspécifiques\n• 2 classes:\n• Equilibrées\n• Déséquilibrées (variation du nombre de copies ou CNV\npour Copy Number Variant)\n98'),
#  Slides(id='SL_099', title='Variations de structure', content='L1SpS: UE 2 Les molécules du vivant\nVariations de structure\nDéséquilibrées\nEquilibrées\n99'),
#  Slides(id='SL_100', title='Variations de structure', content='L1SpS: UE 2 Les molécules du vivant\nVariations de structure\n• Localisation :\n• Partout dans le génome (exon, intron et intergénique)\n• Fréquence:\n• 2 000 à 10 000 entre 2 génomes (même sexe)\n• ~1000 grandes délétions\n• ~160 CNV\n• ~1000 insertions éléments mobiles\n• ~10 inversions\n• La plus grande source de variation du génome en nombre de\nbases affectées (20 millions)\nSudmant et al 2015 100'),
#  Slides(id='SL_101', title='Autres mécanismes rares et commentaires', content='L1SpS: UE 2 Les molécules du vivant\nAutres mécanismes rares et commentaires\n• Conversion génique\n• Séquences très homologues entres elles\n• Empreinte parentale\n• Modification spécifique de la méthylation du génome\n• Selon le gène (pathologie)\n• Chaque type de variations doit être évalué et potentiellement identifié\ncomme causal\n• Type de mutations spécifiques\n• Que des mutations faux sens\n• Grandes délétions du gène\n101'),
#  Slides(id='SL_102', title='Les différents effets des variations', content='L1SpS: UE 2 Les molécules du vivant\nLes différents effets des variations\n• Perte de fonction (totale ou partielle):\n• Non sens, décalage du cadre de lecture\n• Faux sens si il y a un effet drastique sur la fonction, la localisation ou\nla stabilité de la protéine\n• Gain de fonction:\n• Protéine plus active ou avec une action différente ou alors il y a un\ngain de propriété toxique\n• Variations très spécifiques (ex: activation site catalytique d’une\nenzyme)\n• Dominant négatif:\n• La protéine mutée perd sa fonction et interfère avec la fonction de la\nprotéine codée par l’allèle normal\n102'),
#  Slides(id='SL_103', title='Variabilité du génome humain', content='L1SpS: UE 2 Les molécules du vivant\nVariabilité du génome humain\n103'),
#  Slides(id='SL_104', title='Bilan sur la variabilité du génome humain', content='L1SpS: UE 2 Les molécules du vivant\nBilan sur la variabilité du génome humain\n• De nombreuses sources de variabilité\n• Variations qui sont rares et d’autres plus fréquentes (effet fondateur ou\nmécanique)\n• >1,1 milliard de variations déjà décrites dans dbSNP soit ~34% du génome\n• >7 millions de variations structurales décrites dans DGV soit ~79% du génome\nhttp://www.ncbi.nlm.nih.gov/snp http://dgv.tcag.ca/dgv/app/statistics 104'),
#  Slides(id='SL_105', title='notions essentielles et mécanismes', content='L1SpS: UE 2 Les molécules du vivant\nEvolution des génomes:\nnotions essentielles et mécanismes\n105'),
#  Slides(id='SL_106', title='Evolution des génomes', content='L1SpS: UE 2 Les molécules du vivant\nEvolution des génomes\nNotions essentielles:\n• Evolution, Temps, Adaptation, Sélection\n• Les génomes des espèces se modifient au cours du temps\n• Processus dynamique qui permet l’ajout, la perte et/ou un\nremaniement du matériel génétique (ADN)\n• Adaptation aux conditions environnementales ou non: les\nvariations du génome peuvent permettre un avantage sélectif\n• Espèces plus performantes au regard des conditions de vie\n• Nouvelles espèces\n• Comment?\n• Variations ponctuelles (substitutions et indels)\n• Variations structurales\n106'),
#  Slides(id='SL_107', title='Duplication d’exons', content='L1SpS: UE 2 Les molécules du vivant\nDuplication d’exons\n• Duplication en tandem des exons d’un gène\n• ~10% des gènes chez l’Homme\n• Responsable de domaines répétés dans une protéine\n• Recombinaison illégitime avec une résolution inégale d’un\n« crossing-over » (cf autre cours)\n107'),
#  Slides(id='SL_108', title='Brassage d’exon ou exon « shuffling »', content='L1SpS: UE 2 Les molécules du vivant\nBrassage d’exon ou exon « shuffling »\n• Plusieurs mécanismes possibles:\n• Recombinaison non-allélique\n• Rétransposons (LINEs)\n108'),
#  Slides(id='SL_109', title='Duplication des gènes', content='L1SpS: UE 2 Les molécules du vivant\nDuplication des gènes\n• Scénarios possibles:\n109'),
#  Slides(id='SL_110', title='Duplication complète du génome', content='L1SpS: UE 2 Les molécules du vivant\nDuplication complète du génome\n110'),
#  Slides(id='SL_111', title="Certains schémas de ce cours ont été adaptés à partir d'illustrations provenant des ouvrages", content="L1SpS: UE 2 Les molécules du vivant\nCertains schémas de ce cours ont été adaptés à partir d'illustrations provenant des ouvrages\nsuivants:\n-Biologie moléculaire de la cellule, B. Alberts et al. 6ième ed. (Garland science)\n-Human Molecular Genetics, Strachan and Reed, 4ième ed., (Garland science)\n-Génétique médicale, Enseignement thématique, Collège National des Enseignants et Praticiens\nde Génétique Médicale (Elsevier Masson)\nCertaines illustrations sont tirées d'articles scientifiques (références sur les diapos) ou de l'espace\nnumérique (creative commons licensing)\nCourtesy: National Human Genome Research Institute and the Smithsonian National Museum of\nNatural History“ ou du DataBase Center for Life Science (DBCLS)\nMentions légales :\nL'utilisation des documents de cours est strictement réservée à l'usage privé des étudiants inscrits à\nl'université de Strasbourg. Leur diffusion et/ou mise en réseau est strictement réservée à l'université\nde Strasbourg, et à une association agréée (association amicale des étudiants en médecine de\nStrasbourg). Toute autre utilisation, diffusion ou mise en réseau est interdite. Ces documents sont\ninterdits à la vente ou à la location, et à tout usage par des organismes privés (préparations, etc).\nL'ensemble de ces documents relève des législations française et internationale sur le droit d'auteur\net la propriété intellectuelle.\n111")]

# %% [markdown]
# # Get the outline and mapping for the course

# %%
import json
from typing import List


def build_outline_and_mapping_prompt(slides: List[Slides]) -> str:
    slides_json = json.dumps(
        [s.model_dump() for s in slides], ensure_ascii=False, indent=2
    )
    return f"""
OBJECTIF
A partir de la liste ordonnée de diapositives, produire:
1) Un plan de cours hiérarchique cohérent (OUTLINE) de profondeur maximale 3.
2) Un MAPPING associant chaque section du plan aux identifiants de slides pertinents.

DONNÉES
SLIDES: liste d'objets {{id, title, content}} dans l'ordre d'apparition. Attention: le champ "title" n'est PAS fiable. Il correspond souvent à la plus grande police parmi les 5 premières lignes et peut être trompeur. Déduire les titres de sections à partir du contenu réel.
{slides_json}

SCHÉMA DE SORTIE - STRICTEMENT OBLIGATOIRE
Un JSON valide avec exactement deux clés de premier niveau: "outline" et "mapping".

class ContentSection(BaseModel):
    id: str                           # SEC_1, SEC_1.1, SEC_1.1.1
    title: str                        # 5 à 12 mots, clair et informatif
    content: List[str]                # Toujours [] à ce stade
    subsections: List["ContentSection"]

class Content(BaseModel):
    sections: List[ContentSection]

class MappingItem(BaseModel):
    section_id: str                   # Doit exister dans outline
    slide_ids: List[str]              # Identifiants "SL_xxx" fournis en entrée

class OutlineAndMapping(BaseModel):
    outline: Content
    mapping: List[MappingItem]

CONTRAINTES OUTLINE
- Profondeur maximale: 3 niveaux. Exemple autorisé: SEC_2.3.1. Exemple interdit: SEC_2.3.1.4.
- Numérotation continue par niveau: SEC_1, SEC_2, ... puis SEC_2.1, SEC_2.2, etc.
- L'ordre du plan suit la progression implicite des SLIDES.
- Les titres sont générés à partir du contenu des slides. Traiter "title" comme indice faible seulement.
- Le champ "content" de chaque section doit être [].

CONTRAINTES MAPPING
- Chaque section du plan apparaît exactement une fois dans "mapping" via son "section_id".
- Chaque slide_id fourni apparaît au moins une fois dans l'ensemble de "mapping".
- Une slide peut être mappée à plusieurs sections si pertinent. Favoriser des groupes contigus.
- N'utiliser que des identifiants existants.

HEURISTIQUES DE STRUCTURATION
- Regrouper par thèmes en s'appuyant sur: mots-clés dominants, listes à puces, définitions, exemples, transitions comme "Introduction", "Objectifs", "Méthodes", "Résultats", "Conclusion".
- Détecter les limites de sections par changements nets de vocabulaire, apparition de nouveaux items de liste, ou marqueurs forts.
- Ignorer le bruit: en-têtes répétés, numéros de page, crédits, filigranes, sauf si une section Bibliographie est manifeste.
- En cas d'ambiguïté, assigner la slide à la section la plus spécifique qui couvre la majorité de son contenu.

FORMAT DE SORTIE - EXEMPLE FACTICE
{{
  "outline": {{
    "sections": [
      {{
        "id": "SEC_1",
        "title": "Contexte du domaine et objectifs d apprentissage",
        "content": [],
        "subsections": [
          {{
            "id": "SEC_1.1",
            "title": "Problématique centrale et périmètre du cours",
            "content": [],
            "subsections": []
          }},
          {{
            "id": "SEC_1.2",
            "title": "Organisation du cours et attendus",
            "content": [],
            "subsections": []
          }}
        ]
      }},
      {{
        "id": "SEC_2",
        "title": "Notions fondamentales et définitions clés",
        "content": [],
        "subsections": []
      }}
    ]
  }},
  "mapping": [
    {{ "section_id": "SEC_1",   "slide_ids": ["SL_001", "SL_002"] }},
    {{ "section_id": "SEC_1.1", "slide_ids": ["SL_003"] }},
    {{ "section_id": "SEC_1.2", "slide_ids": ["SL_004", "SL_005"] }},
    {{ "section_id": "SEC_2",   "slide_ids": ["SL_006", "SL_007", "SL_008"] }}
  ]
}}

SORTIE
- Retourner uniquement le JSON valide conforme à OutlineAndMapping.
- Aucune explication ni commentaire hors du JSON.
""".strip()


prompt = build_outline_and_mapping_prompt(formated_slides)

response = client.responses.parse(
    model="gpt-5-mini",
    input=[
        {
            "role": "system",
            "content": "Tu es un expert en structuration pédagogique. Tu infères un plan hiérarchique fiable et un mapping de slides à partir d'un deck bruité.",
        },
        {"role": "user", "content": prompt},
    ],
    text_format=OutlineAndMapping,
    reasoning={"effort": "high"},
    text={"verbosity": "medium"},  # titres concis et propres
)

result: OutlineAndMapping = response.output_parsed

# %%
slides_mapping = SectionSlideMapping(mapping=result.mapping)
print(slides_mapping.visualize_mapping(result.outline))
# Out:
# Section-to-Slides Mapping:
# ============================================================
#
# [Root] SEC_1
# Title: Introduction, objectifs et plan du cours
# Slides: 2 slide(s)
# Slide IDs: SL_001, SL_002
#
#   [Level 1] SEC_1.1
#   Title: Présentation et introduction au module
#   Slides: 1 slide(s)
#   Slide IDs: SL_003
#
# [Root] SEC_2
# Title: Notions fondamentales en biologie évolutive et moléculaire
# Slides: 1 slide(s)
# Slide IDs: SL_004
#
#   [Level 1] SEC_2.1
#   Title: Arbre du vivant et organismes modèles
#   Slides: 2 slide(s)
#   Slide IDs: SL_004, SL_005
#
#   [Level 1] SEC_2.2
#   Title: Homologie et comparaison de séquences
#   Slides: 5 slide(s)
#   Slide IDs: SL_006, SL_007, SL_008, SL_009, SL_010
#
#   [Level 1] SEC_2.3
#   Title: Biologie du gène et dogme central
#   Slides: 2 slide(s)
#   Slide IDs: SL_011, SL_012
#
# [Root] SEC_3
# Title: Le génome humain : composition et ressources majeures
# Slides: 1 slide(s)
# Slide IDs: SL_013
#
#   [Level 1] SEC_3.1
#   Title: Présentation générale et nomenclature du génome
#   Slides: 4 slide(s)
#   Slide IDs: SL_014, SL_015, SL_016, SL_017
#
#   [Level 1] SEC_3.2
#   Title: Projet de séquençage et historique du génome humain
#   Slides: 5 slide(s)
#   Slide IDs: SL_018, SL_019, SL_020, SL_021, SL_022
#
#   [Level 1] SEC_3.3
#   Title: Visualisation, annotation et navigation dans le génome
#   Slides: 5 slide(s)
#   Slide IDs: SL_024, SL_025, SL_026, SL_027, SL_028
#
#   [Level 1] SEC_3.4
#   Title: Unités de base et conservation génomique
#   Slides: 2 slide(s)
#   Slide IDs: SL_029, SL_030
#
#   [Level 1] SEC_3.5
#   Title: Génome mitochondrial : structure et caractéristiques principales
#   Slides: 3 slide(s)
#   Slide IDs: SL_031, SL_032, SL_033
#
#   [Level 1] SEC_3.6
#   Title: Génome nucléaire : taille, euchromatine et hétérochromatine
#   Slides: 2 slide(s)
#   Slide IDs: SL_034, SL_035
#
#   [Level 1] SEC_3.7
#   Title: Éléments constitutifs du génome humain
#   Slides: 1 slide(s)
#   Slide IDs: SL_036
#
#     [Level 2] SEC_3.7.1
#     Title: Gènes : définition, nombres et caractéristiques
#     Slides: 5 slide(s)
#     Slide IDs: SL_037, SL_038, SL_039, SL_040, SL_041
#
#     [Level 2] SEC_3.7.2
#     Title: Organisation des gènes et exemples de clusters
#     Slides: 6 slide(s)
#     Slide IDs: SL_042, SL_043, SL_044, SL_045, SL_046, SL_047
#
#     [Level 2] SEC_3.7.3
#     Title: ARN non codants : classes et fonctions principales
#     Slides: 1 slide(s)
#     Slide IDs: SL_048
#
#     [Level 2] SEC_3.7.4
#     Title: Pseudogènes : origines et remarques fonctionnelles principales
#     Slides: 5 slide(s)
#     Slide IDs: SL_049, SL_050, SL_051, SL_052, SL_053
#
#     [Level 2] SEC_3.7.5
#     Title: Éléments répétitifs et transposons : types et rôles
#     Slides: 13 slide(s)
#     Slide IDs: SL_054, SL_055, SL_056, SL_057, SL_058, SL_059, SL_060, SL_061, SL_062, SL_063, SL_064, SL_065, SL_066
#
#   [Level 1] SEC_3.8
#   Title: Comparaison des génomes : mitochondrial et inter-espèces
#   Slides: 7 slide(s)
#   Slide IDs: SL_067, SL_068, SL_069, SL_070, SL_071, SL_072, SL_073
#
# [Root] SEC_4
# Title: Variations du génome humain : types et conséquences
# Slides: 1 slide(s)
# Slide IDs: SL_074
#
#   [Level 1] SEC_4.1
#   Title: Définitions, nomenclature et exemples de variants
#   Slides: 8 slide(s)
#   Slide IDs: SL_075, SL_076, SL_077, SL_078, SL_079, SL_080, SL_081, SL_082
#
#   [Level 1] SEC_4.2
#   Title: Types moléculaires de variations et mécanismes
#   Slides: 2 slide(s)
#   Slide IDs: SL_083, SL_084
#
#     [Level 2] SEC_4.2.1
#     Title: Substitutions, insertions et délétions : mécanismes et effets
#     Slides: 9 slide(s)
#     Slide IDs: SL_085, SL_086, SL_087, SL_088, SL_089, SL_090, SL_091, SL_092, SL_093
#
#     [Level 2] SEC_4.2.2
#     Title: Variations d'épissage et conséquences sur les protéines
#     Slides: 3 slide(s)
#     Slide IDs: SL_094, SL_095, SL_096
#
#     [Level 2] SEC_4.2.3
#     Title: Expansions de triplets et mutations dynamiques
#     Slides: 1 slide(s)
#     Slide IDs: SL_097
#
#     [Level 2] SEC_4.2.4
#     Title: Variations de structure : CNV, inversions et remaniements
#     Slides: 4 slide(s)
#     Slide IDs: SL_098, SL_099, SL_100, SL_101
#
#   [Level 1] SEC_4.3
#   Title: Effets fonctionnels des variants et mécanismes pathogènes
#   Slides: 1 slide(s)
#   Slide IDs: SL_102
#
#   [Level 1] SEC_4.4
#   Title: Variabilité populationnelle et bases de données génomiques
#   Slides: 2 slide(s)
#   Slide IDs: SL_103, SL_104
#
# [Root] SEC_5
# Title: Evolution des génomes : notions essentielles et exemples
# Slides: 1 slide(s)
# Slide IDs: SL_105
#
#   [Level 1] SEC_5.1
#   Title: Principes fondamentaux de l'évolution génomique
#   Slides: 1 slide(s)
#   Slide IDs: SL_106
#
#   [Level 1] SEC_5.2
#   Title: Mécanismes de diversification et duplication génomique
#   Slides: 1 slide(s)
#   Slide IDs: SL_107
#
#     [Level 2] SEC_5.2.1
#     Title: Duplication d'exons et ses conséquences protéiques
#     Slides: 1 slide(s)
#     Slide IDs: SL_107
#
#     [Level 2] SEC_5.2.2
#     Title: Brassage d'exons (exon shuffling) et réarrangements
#     Slides: 1 slide(s)
#     Slide IDs: SL_108
#
#     [Level 2] SEC_5.2.3
#     Title: Duplication de gènes : scénarios évolutifs
#     Slides: 1 slide(s)
#     Slide IDs: SL_109
#
#     [Level 2] SEC_5.2.4
#     Title: Duplication complète du génome et conséquences
#     Slides: 1 slide(s)
#     Slide IDs: SL_110
#
# [Root] SEC_6
# Title: Crédits, références et mentions légales du cours
# Slides: 1 slide(s)
# Slide IDs: SL_111

# %%
import pdfplumber
from statistics import mean
from typing import Optional

def extract_pdf_text(pdf_path: str, page_number: Optional[int] = None) -> str:
    """
    Extract text from a PDF file, either from a specific page or the full document.
    
    Args:
        pdf_path: Path to the PDF file
        page_number: Optional page number to extract (1-based). If None, extracts full PDF.
    
    Returns:
        Extracted text as string
    """
    with pdfplumber.open(pdf_path) as pdf:
        if page_number is not None:
            # Adjust for 0-based page indexing
            page_idx = page_number - 1
            if page_idx < 0 or page_idx >= len(pdf.pages):
                raise ValueError(f"Page number {page_number} is out of range")
            
            page = pdf.pages[page_idx]
            text = page.extract_text(layout=True)
            # Remove multiple consecutive newlines
            return '\n'.join(line for line in text.splitlines() if line.strip())
        
        else:
            # Extract full PDF
            all_text = []
            for page in pdf.pages:
                text = page.extract_text(layout=True)
                # Remove multiple consecutive newlines 
                text = '\n'.join(line for line in text.splitlines() if line.strip())
                all_text.append(text)
            return '\n'.join(all_text)

pdf_path = "./volume/slides/cours_1.pdf"
# Example usage:
# full_text = extract_pdf_text(pdf_path)  # Get full PDF
# page_3_text = extract_pdf_text(pdf_path, page_number=3)  # Get page 3 only

# Get full PDF text for now
full_text = extract_pdf_text(pdf_path, page_number=2)
print(full_text)
# Out:
#    L1SpS: UE 2 Les molécules du vivant
#       Plan      du     cours
#         •  Introduction
#              •  Notions  fondamentales
#         •  Le génome    humain
#              •  Projet de séquençage
#              •  Architecture globale
#                   •  Génome    mitochondrial
#                   •  Génome    nucléaire
#              •  Description  des principaux  éléments   constituants
#                   •  Gènes  (codants   et non-codants),  pseudogènes     et éléments  répétés
#         •  Comparaison    aux  autres génomes
#         •  Les types  de variations  du génome    humain   et leurs conséquences
#         •  La variabilité du génome   humain
#         •  Evolution des  génomes:    notions essentielles,  mécanismes
#                                                                                                  2

# %%
from models import Content, ContentSection, SectionSlideMapping
from typing import List, Dict, Optional

# %%
import tiktoken
encoder = tiktoken.get_encoding("cl100k_base")  # GPT-4 encoding
text_course_outline = str(full_text)
text_course_content = str(slides)
token_count, token_count_outline = len(encoder.encode(text_course_content)), len(encoder.encode(text_course_outline))
print(token_count, token_count_outline)
# Out:
# 13439 221

# %%
import dotenv
dotenv.load_dotenv()

import openai

client = openai.OpenAI()

system_prompt = """
You are a course structure analyzer specialized in French academic content.  
Your task is to parse a raw course outline text containing numbered section titles (like "I.", "1.", "1.1.", etc.) or indented bullet points.
and generate a hierarchical JSON structure matching this Pydantic model:

class ContentSection:
    id: str = ""
    title: str
    content: str = ""
    subsections: List[ContentSection]

class Content:
    sections: List[ContentSection]

Requirements:
- Detect all section titles and nest subsections correctly based on numbering.
- Maintain full recursive hierarchy.
- Return valid JSON exactly matching the Content model structure.
- Include every section and subsection with their titles.
- Ignore the content and the id of the sections, you only need to return the outline.
- Return ONLY the JSON, no additional text or explanation.
"""

user_message = full_text  # ton texte brut extrait

response = client.responses.parse(
    model="gpt-5-mini",
    input=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_message}
    ],
    reasoning = {
        "effort": "low",
    },
    text= {"verbosity": "low"},
    
    text_format=Content
)

outline = response.output_parsed

print(outline.print_outline())
# Out:
# Course Outline:
# ==================================================
# Introduction
#   Notions fondamentales
# Le génome    humain
#   Projet de séquençage
#   Architecture globale
#     Génome    mitochondrial
#     Génome    nucléaire
#   Description  des principaux  éléments   constituants
#     Gènes  (codants   et non-codants),  pseudogènes     et éléments  répétés
# Comparaison    aux  autres génomes
# Les types  de variations  du génome    humain   et leurs conséquences
# La variabilité du génome   humain
# Evolution des  génomes:    notions essentielles,  mécanismes

# %%
while len(outline.sections) == 1:
    outline.sections = outline.sections[0].subsections

print(outline.sections[0])
# Out:
# id='' title='Introduction' content=[] subsections=[ContentSection(id='', title='Notions fondamentales', content=[], subsections=[])]

# %%
def assign_ids(sec: ContentSection, parent_id: str = "", parent_section: Optional[ContentSection] = None):
    # Determine current section number
    if parent_id == "":
        # Top level section
        sec.id = f"SEC_{len([s for s in outline.sections if s.id.startswith('SEC_')])+ 1}"
    else:
        # Subsection - append next number to parent id
        parent_nums = parent_id.replace("SEC_", "")
        sibling_count = len([s for s in parent_section.subsections if s.id.startswith(f"SEC_{parent_nums}.")])
        sec.id = f"SEC_{parent_nums}.{sibling_count + 1}"
    
    # Recursively assign ids to subsections
    for sub in sec.subsections:
        assign_ids(sub, sec.id, sec)

for s in outline.sections:
    assign_ids(s)

# %%
outline_to_send = Content(sections=outline.sections[:])
print(outline_to_send.print_outline())

outline_json = outline_to_send.model_dump_json()

print(outline_json)
# Out:
# Course Outline:
# ==================================================
# Introduction
#   Notions fondamentales
# Le génome    humain
#   Projet de séquençage
#   Architecture globale
#     Génome    mitochondrial
#     Génome    nucléaire
#   Description  des principaux  éléments   constituants
#     Gènes  (codants   et non-codants),  pseudogènes     et éléments  répétés
# Comparaison    aux  autres génomes
# Les types  de variations  du génome    humain   et leurs conséquences
# La variabilité du génome   humain
# Evolution des  génomes:    notions essentielles,  mécanismes
# {"sections":[{"id":"SEC_1","title":"Introduction","content":[],"subsections":[{"id":"SEC_1.1","title":"Notions fondamentales","content":[],"subsections":[]}]},{"id":"SEC_2","title":"Le génome    humain","content":[],"subsections":[{"id":"SEC_2.1","title":"Projet de séquençage","content":[],"subsections":[]},{"id":"SEC_2.2","title":"Architecture globale","content":[],"subsections":[{"id":"SEC_2.2.1","title":"Génome    mitochondrial","content":[],"subsections":[]},{"id":"SEC_2.2.2","title":"Génome    nucléaire","content":[],"subsections":[]}]},{"id":"SEC_2.3","title":"Description  des principaux  éléments   constituants","content":[],"subsections":[{"id":"SEC_2.3.1","title":"Gènes  (codants   et non-codants),  pseudogènes     et éléments  répétés","content":[],"subsections":[]}]}]},{"id":"SEC_3","title":"Comparaison    aux  autres génomes","content":[],"subsections":[]},{"id":"SEC_4","title":"Les types  de variations  du génome    humain   et leurs conséquences","content":[],"subsections":[]},{"id":"SEC_5","title":"La variabilité du génome   humain","content":[],"subsections":[]},{"id":"SEC_6","title":"Evolution des  génomes:    notions essentielles,  mécanismes","content":[],"subsections":[]}],"slides":null,"mapping":null}

# %%
outline
# Out:
# Content(sections=[ContentSection(id='SEC_1', title='Introduction', content=[], subsections=[ContentSection(id='SEC_1.1', title='Notions fondamentales', content=[], subsections=[])]), ContentSection(id='SEC_2', title='Le génome    humain', content=[], subsections=[ContentSection(id='SEC_2.1', title='Projet de séquençage', content=[], subsections=[]), ContentSection(id='SEC_2.2', title='Architecture globale', content=[], subsections=[ContentSection(id='SEC_2.2.1', title='Génome    mitochondrial', content=[], subsections=[]), ContentSection(id='SEC_2.2.2', title='Génome    nucléaire', content=[], subsections=[])]), ContentSection(id='SEC_2.3', title='Description  des principaux  éléments   constituants', content=[], subsections=[ContentSection(id='SEC_2.3.1', title='Gènes  (codants   et non-codants),  pseudogènes     et éléments  répétés', content=[], subsections=[])])]), ContentSection(id='SEC_3', title='Comparaison    aux  autres génomes', content=[], subsections=[]), ContentSection(id='SEC_4', title='Les types  de variations  du génome    humain   et leurs conséquences', content=[], subsections=[]), ContentSection(id='SEC_5', title='La variabilité du génome   humain', content=[], subsections=[]), ContentSection(id='SEC_6', title='Evolution des  génomes:    notions essentielles,  mécanismes', content=[], subsections=[])], slides=None, mapping=None)

# %% [markdown]
# ## Pass 1.bis mapping slide number to section title

# %%
def build_mapping_prompt(outline_json: str, slides: List[dict]) -> str:
    """
    Génère le prompt demandant au modèle de produire le mapping section→slides.

    Paramètres
    ----------
    outline_json : str   JSON du plan (chaque section possède un id SEC_***)
    slides       : list  Liste de dicts {"id": "SL_***", "title": ..., "content": ...}

    Retour
    ------
    str : prompt clair et contraignant, prêt pour client.responses.parse
    """
    return f"""
OBJECTIF
Associer chaque section du plan aux diapositives pertinentes.

DONNÉES
1) PLAN_JSON : (structure hiérarchique, chaque section a un identifiant unique "SEC_xxx")


This is the structure of the outline that you will receive:
class ContentSection(BaseModel):
    id: str
    title: str
    content: Optional[str] = ""
    subsections: List["ContentSection"] = Field(default_factory=list)
    
class Content(BaseModel):
    sections: List[ContentSection]

This is the actual outline:

{outline_json}

          


2) SLIDES : (liste ordonnée, chaque slide a un identifiant unique "SL_xxx")
{slides}

FORMAT DE SORTIE — STRICTEMENT OBLIGATOIRE
Un JSON **valide** contenant UNE SEULE clé de premier niveau : "mapping".

This is the pydantic model SectionSlideMapping that you will use to return the mapping:

class MappingItem(BaseModel):
    section_id: str
    slide_ids:  List[str]

class SectionSlideMapping(BaseModel):
    mapping: List[MappingItem]


Exemple de structure attendue :
{{
  "mapping": [
    {{ "section_id": "SEC_1", "slide_ids": ["SL_001", "SL_002"] }},
    {{ "section_id": "SEC_1.1", "slide_ids": ["SL_003", "SL_004"] }}
  ]
}}

CONTRAINTES À RESPECTER IMPÉRATIVEMENT
- Chaque "section_id" présent dans PLAN_JSON doit apparaître **exactement une fois**.
- Chaque "slide_id" présent dans SLIDES doit apparaître **au moins une fois** (aucune slide orpheline).
- "slide_ids" est un tableau d'identifiants ; l’ordre interne n’a pas d’importance.
- N’utilise **que** des identifiants existants ; n’invente pas de clés ni de champs.
- AUCUNE explication, commentaire ou clé supplémentaire : la sortie doit être **uniquement** le JSON demandé.
""".strip()


mapping_rsp = client.responses.parse(
    model="gpt-5-mini",
    input=[{"role": "user", "content": build_mapping_prompt(outline_json, slides)}],
    text_format=SectionSlideMapping,
    reasoning={"effort": "high"},
    text={"verbosity": "low"},  # ← schéma fixe
)
slides_by_section: Dict[str, List[str]] = {
    item.section_id: item.slide_ids for item in mapping_rsp.output_parsed.mapping
}

# %%
section_mapping = mapping_rsp.output_parsed

print(section_mapping.visualize_mapping(outline))
# Out:
# Section-to-Slides Mapping:
# ============================================================
#
# [Root] SEC_1
# Title: Introduction
# Slides: 3 slide(s)
# Slide IDs: SL_002, SL_003, SL_012
#
#   [Level 1] SEC_1.1
#   Title: Notions fondamentales
#   Slides: 8 slide(s)
#   Slide IDs: SL_004, SL_005, SL_006, SL_007, SL_008, SL_009, SL_010, SL_011
#
# [Root] SEC_2
# Title: Le génome    humain
# Slides: 7 slide(s)
# Slide IDs: SL_013, SL_014, SL_015, SL_016, SL_017, SL_030, SL_067
#
#   [Level 1] SEC_2.1
#   Title: Projet de séquençage
#   Slides: 5 slide(s)
#   Slide IDs: SL_018, SL_019, SL_020, SL_021, SL_022
#
#   [Level 1] SEC_2.2
#   Title: Architecture globale
#   Slides: 4 slide(s)
#   Slide IDs: SL_001, SL_024, SL_025, SL_028
#
#     [Level 2] SEC_2.2.1
#     Title: Génome    mitochondrial
#     Slides: 3 slide(s)
#     Slide IDs: SL_031, SL_032, SL_033
#
#     [Level 2] SEC_2.2.2
#     Title: Génome    nucléaire
#     Slides: 2 slide(s)
#     Slide IDs: SL_034, SL_035
#
#   [Level 1] SEC_2.3
#   Title: Description  des principaux  éléments   constituants
#   Slides: 1 slide(s)
#   Slide IDs: SL_036
#
#     [Level 2] SEC_2.3.1
#     Title: Gènes  (codants   et non-codants),  pseudogènes     et éléments  répétés
#     Slides: 33 slide(s)
#     Slide IDs: SL_026, SL_027, SL_029, SL_037, SL_038, SL_039, SL_040, SL_041, SL_042, SL_043, SL_044, SL_045, SL_046, SL_047, SL_048, SL_049, SL_050, SL_051, SL_052, SL_053, SL_054, SL_055, SL_056, SL_057, SL_058, SL_059, SL_060, SL_061, SL_062, SL_063, SL_064, SL_065, SL_066
#
# [Root] SEC_3
# Title: Comparaison    aux  autres génomes
# Slides: 6 slide(s)
# Slide IDs: SL_068, SL_069, SL_070, SL_071, SL_072, SL_073
#
# [Root] SEC_4
# Title: Les types  de variations  du génome    humain   et leurs conséquences
# Slides: 29 slide(s)
# Slide IDs: SL_074, SL_075, SL_076, SL_077, SL_078, SL_079, SL_080, SL_081, SL_082, SL_083, SL_084, SL_085, SL_086, SL_087, SL_088, SL_089, SL_090, SL_091, SL_092, SL_093, SL_094, SL_095, SL_096, SL_097, SL_098, SL_099, SL_100, SL_101, SL_102
#
# [Root] SEC_5
# Title: La variabilité du génome   humain
# Slides: 2 slide(s)
# Slide IDs: SL_103, SL_104
#
# [Root] SEC_6
# Title: Evolution des  génomes:    notions essentielles,  mécanismes
# Slides: 7 slide(s)
# Slide IDs: SL_105, SL_106, SL_107, SL_108, SL_109, SL_110, SL_111

# %% [markdown]
# ### New way to build the Content object

# %%
outline = result.outline

# %%
section_mapping = SectionSlideMapping(mapping=result.mapping)

course_with_slides = result.outline.enrich_with_slides(formated_slides, section_mapping)
course_with_slides
# Out:
# Content(sections=[ContentSection(id='SEC_1', title='Introduction, objectifs et plan du cours', content=['L1SpS: UE 2 Les molécules du vivant\nU.E.2 Les molécules du vivant\n7. Organisation du génome humain, méthodes en\nbiotechnologie\n7.1 Architecture du génome\nhumain\nJean Muller\nLaboratoire Diagnostic Génétique (HUS)\nLaboratoire de Génétique médicale (Inserm U1112)\njeanmuller@unistra.fr', 'L1SpS: UE 2 Les molécules du vivant\nPlan du cours\n• Introduction\n• Notions fondamentales\n• Le génome humain\n• Projet de séquençage\n• Architecture globale\n• Génome mitochondrial\n• Génome nucléaire\n• Description des principaux éléments constituants\n• Gènes (codants et non-codants), pseudogènes et éléments répétés\n• Comparaison aux autres génomes\n• Les types de variations du génome humain et leurs conséquences\n• La variabilité du génome humain\n• Evolution des génomes: notions essentielles, mécanismes\n2'], subsections=[ContentSection(id='SEC_1.1', title='Présentation et introduction au module', content=['L1SpS: UE 2 Les molécules du vivant\nIntroduction\n3'], subsections=[])]), ContentSection(id='SEC_2', title='Notions fondamentales en biologie évolutive et moléculaire', content=['L1SpS: UE 2 Les molécules du vivant\nL’arbre de la vie\nNotions essentielles:\n• Evolution\n• Temps\n• Adaptation\n• Sélection\nLUCA\nLast Universal Common Ancestor\n4'], subsections=[ContentSection(id='SEC_2.1', title='Arbre du vivant et organismes modèles', content=['L1SpS: UE 2 Les molécules du vivant\nL’arbre de la vie\nNotions essentielles:\n• Evolution\n• Temps\n• Adaptation\n• Sélection\nLUCA\nLast Universal Common Ancestor\n4', 'L1SpS: UE 2 Les molécules du vivant\nArbre des eucaryotes\nChoix d’organismes modèles\n• Intérêt(s) économique(s)\n• Intérêt(s) technique(s)\n• Facilités hébergement,\n• Développement embryonnaire/temps\nde génération\n• Partage d’éléments communs (ADN)\n• Hérités/Transmis\n35 eucaryotes\n18 métazoaires\n5'], subsections=[]), ContentSection(id='SEC_2.2', title='Homologie et comparaison de séquences', content=["L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Définition\n• En biologie, l'homologie désigne un caractère propre à plusieurs\nespèces hérité d'un ancêtre commun. Les structures en question, qu'elles\nsoient d'ordre anatomique, moléculaire ou génétique, partagent donc une\nhistoire évolutive.\n• ≠ analogie (ex: ailes oiseaux et insectes qui est une évolution séparée)\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\névolué à partir d’un gène ancestral suite à une spéciation\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\nl’évolution de cette espèce.\n6", "L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Définition\n• En biologie, l'homologie désigne un caractère propre à plusieurs espèces\nhérité d'un ancêtre commun. Les structures en question, qu'elles soient\nd'ordre anatomique, moléculaire ou génétique, partagent donc une histoire\névolutive.\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\névolué à partir d’un gène ancestral suite à une spéciation\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\nl’évolution de cette espèce.\n7", 'L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Exemple\n8', 'L1SpS: UE 2 Les molécules du vivant\nA propos de l’homologie\n• Comment déterminer si les gènes sont homologues ou pas?\n• Les séquences des génomes peuvent être alignées entres elles tout comme\nles séquences des protéines.\n• La comparaison de 2 séquences permet d’établir une évaluation de leur\nproximité ou de leur éloignement par le calcul:\n• du pourcentage d’identité* entre ces 2 séquences\n* résidus strictement identique\n• du pourcentage de similarité* entre ces 2 séquences\n* résidus identique + proche (critère à déterm ...

# %%
new_content_json = course_with_slides.model_dump_json()

new_content_json
# Out:
# '{"sections":[{"id":"SEC_1","title":"Introduction, objectifs et plan du cours","content":["L1SpS: UE 2 Les molécules du vivant\\nU.E.2 Les molécules du vivant\\n7. Organisation du génome humain, méthodes en\\nbiotechnologie\\n7.1 Architecture du génome\\nhumain\\nJean Muller\\nLaboratoire Diagnostic Génétique (HUS)\\nLaboratoire de Génétique médicale (Inserm U1112)\\njeanmuller@unistra.fr","L1SpS: UE 2 Les molécules du vivant\\nPlan du cours\\n• Introduction\\n• Notions fondamentales\\n• Le génome humain\\n• Projet de séquençage\\n• Architecture globale\\n• Génome mitochondrial\\n• Génome nucléaire\\n• Description des principaux éléments constituants\\n• Gènes (codants et non-codants), pseudogènes et éléments répétés\\n• Comparaison aux autres génomes\\n• Les types de variations du génome humain et leurs conséquences\\n• La variabilité du génome humain\\n• Evolution des génomes: notions essentielles, mécanismes\\n2"],"subsections":[{"id":"SEC_1.1","title":"Présentation et introduction au module","content":["L1SpS: UE 2 Les molécules du vivant\\nIntroduction\\n3"],"subsections":[]}]},{"id":"SEC_2","title":"Notions fondamentales en biologie évolutive et moléculaire","content":["L1SpS: UE 2 Les molécules du vivant\\nL’arbre de la vie\\nNotions essentielles:\\n• Evolution\\n• Temps\\n• Adaptation\\n• Sélection\\nLUCA\\nLast Universal Common Ancestor\\n4"],"subsections":[{"id":"SEC_2.1","title":"Arbre du vivant et organismes modèles","content":["L1SpS: UE 2 Les molécules du vivant\\nL’arbre de la vie\\nNotions essentielles:\\n• Evolution\\n• Temps\\n• Adaptation\\n• Sélection\\nLUCA\\nLast Universal Common Ancestor\\n4","L1SpS: UE 2 Les molécules du vivant\\nArbre des eucaryotes\\nChoix d’organismes modèles\\n• Intérêt(s) économique(s)\\n• Intérêt(s) technique(s)\\n• Facilités hébergement,\\n• Développement embryonnaire/temps\\nde génération\\n• Partage d’éléments communs (ADN)\\n• Hérités/Transmis\\n35 eucaryotes\\n18 métazoaires\\n5"],"subsections":[]},{"id":"SEC_2.2","title":"Homologie et comparaison de séquences","content":["L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Définition\\n• En biologie, l\'homologie désigne un caractère propre à plusieurs\\nespèces hérité d\'un ancêtre commun. Les structures en question, qu\'elles\\nsoient d\'ordre anatomique, moléculaire ou génétique, partagent donc une\\nhistoire évolutive.\\n• ≠ analogie (ex: ailes oiseaux et insectes qui est une évolution séparée)\\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\\névolué à partir d’un gène ancestral suite à une spéciation\\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\\nl’évolution de cette espèce.\\n6","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Définition\\n• En biologie, l\'homologie désigne un caractère propre à plusieurs espèces\\nhérité d\'un ancêtre commun. Les structures en question, qu\'elles soient\\nd\'ordre anatomique, moléculaire ou génétique, partagent donc une histoire\\névolutive.\\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\\névolué à partir d’un gène ancestral suite à une spéciation\\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\\nl’évolution de cette espèce.\\n7","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Exemple\\n8","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Comment déterminer si les gènes sont homologues ou pas?\\n• Les séquences des génomes peuvent être alignées entres elles tout comme\\nles séquences des protéines.\\n• La comparaison de 2 séquences permet d’établir une évaluation de leur\\nproximité ou de leur éloignement par le calcul:\\n• du pourcentage d’identité* entre ces 2 séquences\\n* résidus strictement identique\\n• du pourcentage de similarité* entre ces 2 séquences\\n* ...

# %%
print(course_with_slides.print_outline())
# Out:
# Course Outline:
# ==================================================
# Introduction, objectifs et plan du cours
#   Présentation et introduction au module
# Notions fondamentales en biologie évolutive et moléculaire
#   Arbre du vivant et organismes modèles
#   Homologie et comparaison de séquences
#   Biologie du gène et dogme central
# Le génome humain : composition et ressources majeures
#   Présentation générale et nomenclature du génome
#   Projet de séquençage et historique du génome humain
#   Visualisation, annotation et navigation dans le génome
#   Unités de base et conservation génomique
#   Génome mitochondrial : structure et caractéristiques principales
#   Génome nucléaire : taille, euchromatine et hétérochromatine
#   Éléments constitutifs du génome humain
#     Gènes : définition, nombres et caractéristiques
#     Organisation des gènes et exemples de clusters
#     ARN non codants : classes et fonctions principales
#     Pseudogènes : origines et remarques fonctionnelles principales
#     Éléments répétitifs et transposons : types et rôles
#   Comparaison des génomes : mitochondrial et inter-espèces
# Variations du génome humain : types et conséquences
#   Définitions, nomenclature et exemples de variants
#   Types moléculaires de variations et mécanismes
#     Substitutions, insertions et délétions : mécanismes et effets
#     Variations d'épissage et conséquences sur les protéines
#     Expansions de triplets et mutations dynamiques
#     Variations de structure : CNV, inversions et remaniements
#   Effets fonctionnels des variants et mécanismes pathogènes
#   Variabilité populationnelle et bases de données génomiques
# Evolution des génomes : notions essentielles et exemples
#   Principes fondamentaux de l'évolution génomique
#   Mécanismes de diversification et duplication génomique
#     Duplication d'exons et ses conséquences protéiques
#     Brassage d'exons (exon shuffling) et réarrangements
#     Duplication de gènes : scénarios évolutifs
#     Duplication complète du génome et conséquences
# Crédits, références et mentions légales du cours

# %%
for section in course_with_slides.sections:
    print("--------------------------------")
    print(section.title)
    print(section.get_token_count())
# Out:
# --------------------------------
# Introduction, objectifs et plan du cours
# 323
# --------------------------------
# Notions fondamentales en biologie évolutive et moléculaire
# 1188
# --------------------------------
# Le génome humain : composition et ressources majeures
# 6011
# --------------------------------
# Variations du génome humain : types et conséquences
# 3469
# --------------------------------
# Evolution des génomes : notions essentielles et exemples
# 742
# --------------------------------
# Crédits, références et mentions légales du cours
# 408

# %% [markdown]
# # Volumen of tokens

# %%
import tiktoken
encoder = tiktoken.get_encoding("cl100k_base")  # GPT-4 encoding
text_course_with_slides = str(course_with_slides)
token_count = len(encoder.encode(text_course_with_slides))
print(token_count)
# Out:
# 26324

# %%
content_to_send = course_with_slides
content_json_str = content_to_send.model_dump_json()
content_json_str
# Out:
# '{"sections":[{"id":"SEC_1","title":"Introduction, objectifs et plan du cours","content":["L1SpS: UE 2 Les molécules du vivant\\nU.E.2 Les molécules du vivant\\n7. Organisation du génome humain, méthodes en\\nbiotechnologie\\n7.1 Architecture du génome\\nhumain\\nJean Muller\\nLaboratoire Diagnostic Génétique (HUS)\\nLaboratoire de Génétique médicale (Inserm U1112)\\njeanmuller@unistra.fr","L1SpS: UE 2 Les molécules du vivant\\nPlan du cours\\n• Introduction\\n• Notions fondamentales\\n• Le génome humain\\n• Projet de séquençage\\n• Architecture globale\\n• Génome mitochondrial\\n• Génome nucléaire\\n• Description des principaux éléments constituants\\n• Gènes (codants et non-codants), pseudogènes et éléments répétés\\n• Comparaison aux autres génomes\\n• Les types de variations du génome humain et leurs conséquences\\n• La variabilité du génome humain\\n• Evolution des génomes: notions essentielles, mécanismes\\n2"],"subsections":[{"id":"SEC_1.1","title":"Présentation et introduction au module","content":["L1SpS: UE 2 Les molécules du vivant\\nIntroduction\\n3"],"subsections":[]}]},{"id":"SEC_2","title":"Notions fondamentales en biologie évolutive et moléculaire","content":["L1SpS: UE 2 Les molécules du vivant\\nL’arbre de la vie\\nNotions essentielles:\\n• Evolution\\n• Temps\\n• Adaptation\\n• Sélection\\nLUCA\\nLast Universal Common Ancestor\\n4"],"subsections":[{"id":"SEC_2.1","title":"Arbre du vivant et organismes modèles","content":["L1SpS: UE 2 Les molécules du vivant\\nL’arbre de la vie\\nNotions essentielles:\\n• Evolution\\n• Temps\\n• Adaptation\\n• Sélection\\nLUCA\\nLast Universal Common Ancestor\\n4","L1SpS: UE 2 Les molécules du vivant\\nArbre des eucaryotes\\nChoix d’organismes modèles\\n• Intérêt(s) économique(s)\\n• Intérêt(s) technique(s)\\n• Facilités hébergement,\\n• Développement embryonnaire/temps\\nde génération\\n• Partage d’éléments communs (ADN)\\n• Hérités/Transmis\\n35 eucaryotes\\n18 métazoaires\\n5"],"subsections":[]},{"id":"SEC_2.2","title":"Homologie et comparaison de séquences","content":["L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Définition\\n• En biologie, l\'homologie désigne un caractère propre à plusieurs\\nespèces hérité d\'un ancêtre commun. Les structures en question, qu\'elles\\nsoient d\'ordre anatomique, moléculaire ou génétique, partagent donc une\\nhistoire évolutive.\\n• ≠ analogie (ex: ailes oiseaux et insectes qui est une évolution séparée)\\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\\névolué à partir d’un gène ancestral suite à une spéciation\\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\\nl’évolution de cette espèce.\\n6","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Définition\\n• En biologie, l\'homologie désigne un caractère propre à plusieurs espèces\\nhérité d\'un ancêtre commun. Les structures en question, qu\'elles soient\\nd\'ordre anatomique, moléculaire ou génétique, partagent donc une histoire\\névolutive.\\n• Orthologie (gènes orthologues): gènes homologues dans 2 espèces ayant\\névolué à partir d’un gène ancestral suite à une spéciation\\n• Paralogie (gènes paralogues): gènes homologues au sein de la même\\nespèce ayant évolué à partir d’un gène ancestral par duplication au cours de\\nl’évolution de cette espèce.\\n7","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Exemple\\n8","L1SpS: UE 2 Les molécules du vivant\\nA propos de l’homologie\\n• Comment déterminer si les gènes sont homologues ou pas?\\n• Les séquences des génomes peuvent être alignées entres elles tout comme\\nles séquences des protéines.\\n• La comparaison de 2 séquences permet d’établir une évaluation de leur\\nproximité ou de leur éloignement par le calcul:\\n• du pourcentage d’identité* entre ces 2 séquences\\n* résidus strictement identique\\n• du pourcentage de similarité* entre ces 2 séquences\\n* ...

# %%
encoder = tiktoken.get_encoding("cl100k_base")  # GPT-4 encoding
text_course_with_slides = str(content_json_str)
token_count = len(encoder.encode(text_course_with_slides))
print(token_count)
# Out:
# 25876

# %%
def build_system_prompt() -> str:
    """
    Prompt système définissant le rôle et les règles
    """
    return """Tu es un expert en rédaction pédagogique. Ta tâche est de transformer du contenu brut de slides en paragraphes de cours structurés.

Règles :
- Ne Mentione jamais la source des slides, l'université, le professeur, l'institut, etc.
- Traite TOUTES les sections du JSON (ne t'arrête pas à la première)
- Pour chaque section, synthétise tous les éléments content[] en 2-10 paragraphes cohérents
- Chaque paragraphe = maximum 10 phrases liées au titre de la section
- Conserve la structure JSON exacte (mêmes IDs, titres, ordre)
- Style académique fluide"""


def build_user_prompt(content_json: str) -> str:
    """
    Prompt utilisateur avec le contenu à traiter
    """
    return content_json


def build_assistant_prompt() -> str:
    """
    Prompt assistant avec exemple d'input/output
    """
    return """Voici un exemple de transformation attendue :

INPUT EXEMPLE:
```json
{
  "sections": [
    {
      "id": "SEC_1",
      "title": "Introduction aux Algorithmes",
      "content": [
        "CS101: Algorithmique\\nAlgorithmes\\n• Définition: séquence d'instructions\\n• Résolution problèmes\\n• Entrée → Traitement → Sortie\\n• Propriétés essentielles\\n1",
        "CS101: Algorithmique\\nCaractéristiques\\n• Fini (nombre étapes)\\n• Non-ambigu\\n• Déterministe\\n• Efficacité importante\\n• Complexité temporelle/spatiale\\n2",
        "CS101: Algorithmique\\nTypes d'algorithmes\\n• Itératifs vs Récursifs\\n• Diviser pour régner\\n• Gloutons (greedy)\\n• Programmation dynamique\\nExemples concrets\\n3"
      ],
      "subsections": [
        {
          "id": "SEC_1.1",
          "title": "Notation Big-O",
          "content": [
            "CS101: Algorithmique\\nComplexité algorithmique\\n• Notation O(n)\\n• Mesure efficacité\\n• Pire cas considéré\\n• Croissance asymptotique\\n4",
            "CS101: Algorithmique\\nExemples complexités\\n• O(1) - constant\\n• O(log n) - logarithmique\\n• O(n) - linéaire\\n• O(n²) - quadratique\\n• O(2^n) - exponentielle\\n5"
          ],
          "subsections": []
        }
      ]
    },
    {
      "id": "SEC_2", 
      "title": "Structures de Données",
      "content": [
        "CS101: Algorithmique\\nStructures fondamentales\\n• Tableaux (arrays)\\n• Listes chaînées\\n• Piles (stacks)\\n• Files (queues)\\n• Organisation mémoire\\n6",
        "CS101: Algorithmique\\nOpérations de base\\n• Insertion / Suppression\\n• Recherche / Accès\\n• Parcours / Tri\\n• Complexité variable\\n• Trade-offs temps/espace\\n7"
      ],
      "subsections": []
    }
  ]
}
```

OUTPUT EXEMPLE:
```json
{
  "sections": [
    {
      "id": "SEC_1",
      "title": "Introduction aux Algorithmes", 
      "content": [
        "Un algorithme constitue une séquence finie et ordonnée d'instructions permettant de résoudre un problème spécifique ou d'accomplir une tâche donnée. Cette approche systématique transforme des données d'entrée en résultats de sortie par l'application d'un processus de traitement déterministe et reproductible.",
        "Les algorithmes présentent des caractéristiques fondamentales qui garantissent leur validité : ils doivent être finis dans le nombre d'étapes, non-ambigus dans leur interprétation, et déterministes dans leur exécution. L'efficacité algorithmique, mesurée par les complexités temporelle et spatiale, constitue un critère essentiel d'évaluation de leur performance.",
        "La classification des algorithmes distingue plusieurs approches méthodologiques selon leur stratégie de résolution : les algorithmes itératifs et récursifs, les méthodes diviser-pour-régner, les algorithmes gloutons, et la programmation dynamique. Chaque paradigme offre des avantages spécifiques selon la nature du problème à traiter."
      ],
      "subsections": [
        {
          "id": "SEC_1.1",
          "title": "Notation Big-O",
          "content": [
            "La notation Big-O fournit un outil mathématique pour caractériser la complexité algorithmique en décrivant la croissance asymptotique du temps d'exécution ou de l'espace mémoire requis. Cette mesure considère le comportement dans le pire cas et permet de comparer objectivement l'efficacité de différents algorithmes.",
            "Les classes de complexité courantes s'organisent selon une hiérarchie croissante : O(1) pour les opérations à temps constant, O(log n) pour les algorithmes logarithmiques, O(n) pour les traitements linéaires, O(n²) pour les approches quadratiques, et O(2^n) pour les solutions exponentielles. Cette classification guide le choix algorithmique selon les contraintes de performance requises."
          ],
          "subsections": []
        }
      ]
    },
    {
      "id": "SEC_2",
      "title": "Structures de Données",
      "content": [
        "Les structures de données fondamentales organisent et stockent l'information selon des patterns spécifiques adaptés aux besoins algorithmiques : les tableaux offrent un accès direct par index, les listes chaînées permettent une allocation dynamique, tandis que les piles et files implémentent des politiques d'accès particulières. L'organisation mémoire influence directement les performances d'accès et de manipulation.",
        "Les opérations de base sur ces structures - insertion, suppression, recherche, accès, parcours et tri - présentent des complexités variables selon l'implémentation choisie. Ces trade-offs entre temps d'exécution et espace mémoire orientent la sélection de la structure la plus appropriée selon les contraintes spécifiques de chaque application."
      ],
      "subsections": []
    }
  ]
}
```

Maintenant traite le JSON fourni en suivant ce modèle :"""


def build_prompt_fill_content(content_json: str) -> str:
    """
    Version legacy - maintenant utilise les 3 fonctions séparées ci-dessus
    """
    return f"""
**SYSTEM:**
{build_system_prompt()}

**USER:**
{build_user_prompt(content_json)}

**ASSISTANT:**
{build_assistant_prompt()}
""".strip()


prompt_to_send = build_prompt_fill_content(content_json_str)

response = client.responses.parse(
    model="gpt-5-mini",
    input=[
        {
            "role": "system",
            "content": "Tu es un Professeur qui remplit le contenu des sections du plan de cours à partir du contenu des slides.",
        },
        {"role": "user", "content": prompt_to_send},
    ],
    text_format=Content,
    reasoning={"effort": "high"},  # for deep synthesis
    text={"verbosity": "high"},  # for complete, detailed course material
)


print(response.output_parsed)
# Out:
# sections=[ContentSection(id='SEC_1', title='Introduction, objectifs et plan du cours', content=["Ce module aborde l'organisation du génome humain et les méthodes de biotechnologie associées, en proposant une lecture intégrée des structures génomiques, de leurs composantes fonctionnelles et des principales approches d'analyse. L'objectif est d'offrir des repères conceptuels permettant de comprendre comment se combinent architecture, éléments codants et non codants, et mécanismes de variation pour produire la diversité biologique observée.", "Les objectifs pédagogiques sont de permettre aux étudiants d'identifier les unités constitutives du génome, de différencier génome nucléaire et mitochondrial, d'appréhender les principaux types de variations et leurs conséquences fonctionnelles, et d'acquérir une culture pratique d'outils d'exploration et d'annotation génomique. Le cours vise aussi à fournir des notions d'évolution des génomes afin d'interpréter la variabilité inter- et intra-espèce.", "Le parcours pédagogique couvre successivement une introduction générale, les notions fondamentales d'évolution et de biologie moléculaire, une présentation détaillée du génome humain (projet de séquençage, structure globale, génomes nucléaires et mitochondriaux), la description des éléments constituants (gènes codants et non codants, pseudogènes, éléments répétitifs), une comparaison inter-espèces, l'étude des types de variations et de leur variabilité, puis les mécanismes évolutifs responsables des changements observés."], subsections=[ContentSection(id='SEC_1.1', title='Présentation et introduction au module', content=["Ce module se place au carrefour de la biologie moléculaire, de la génétique et de l'évolution : il vise à fournir un cadre conceptuel pour analyser la structure et la fonction du génome humain ainsi que les méthodes modernes de biotechnologie utilisées pour l'explorer. L'approche est à la fois descriptive — cartographie et annotation des éléments génomiques — et fonctionnelle — conséquences des variants sur les gènes et les protéines.", "Les compétences attendues comprennent la capacité à lire et interpréter des annotations génomiques, à distinguer classes de variants et effets moléculaires, et à relier ces connaissances aux notions d'héritabilité et d'évolution. Une attention particulière sera portée à l'utilisation critique des ressources génomiques et à l'interprétation des données dans un contexte clinique et évolutif."], subsections=[])]), ContentSection(id='SEC_2', title='Notions fondamentales en biologie évolutive et moléculaire', content=["Les concepts centraux qui sous-tendent l'étude des génomes sont ceux de l'évolution, du temps évolutif, de l'adaptation et de la sélection. Ces notions permettent d'interpréter la distribution des caractères et des séquences au sein d'un arbre du vivant et d'expliquer la présence de traits hérités d'un ancêtre commun.", "L'idée de l'ancêtre universel commun (LUCA) illustre la continuité historique des lignées et fournit un cadre pour comparer les génomes : la mise en regard des séquences et des structures moléculaires entre espèces permet d'identifier des éléments conservés et des innovations adaptatives au cours du temps."], subsections=[ContentSection(id='SEC_2.1', title='Arbre du vivant et organismes modèles', content=["L'arbre du vivant organise les organismes selon leurs relations de parenté et guide le choix d'organismes modèles en biologie. Le choix d'un modèle repose sur des critères pratiques et scientifiques tels que l'intérêt économique, la pertinence technique, la facilité d'hébergement, le développement embryonnaire et le temps de génération, et surtout le partage d'éléments moléculaires communs permettant des comparaisons informatives.", "Les organismes modèles sont choisis pour leur capacité à répondre à des questions biologiques générales tout en offrant des avantages expérimentaux (rapidité, maniabilité génétique, coût). Les approches comparatives entre plusieurs  ...

# %%
course = response.output_parsed
print(course.print_outline())
# Out:
# Course Outline:
# ==================================================
# Introduction, objectifs et plan du cours
#   Présentation et introduction au module
# Notions fondamentales en biologie évolutive et moléculaire
#   Arbre du vivant et organismes modèles
#   Homologie et comparaison de séquences
#   Biologie du gène et dogme central
# Le génome humain : composition et ressources majeures
#   Présentation générale et nomenclature du génome
#   Projet de séquençage et historique du génome humain
#   Visualisation, annotation et navigation dans le génome
#   Unités de base et conservation génomique
#   Génome mitochondrial : structure et caractéristiques principales
#   Génome nucléaire : taille, euchromatine et hétérochromatine
#   Éléments constitutifs du génome humain
#     Gènes : définition, nombres et caractéristiques
#     Organisation des gènes et exemples de clusters
#     ARN non codants : classes et fonctions principales
#     Pseudogènes : origines et remarques fonctionnelles principales
#     Éléments répétitifs et transposons : types et rôles
#   Comparaison des génomes : mitochondrial et inter-espèces
# Variations du génome humain : types et conséquences
#   Définitions, nomenclature et exemples de variants
#   Types moléculaires de variations et mécanismes
#     Substitutions, insertions et délétions : mécanismes et effets
#     Variations d'épissage et conséquences sur les protéines
#     Expansions de triplets et mutations dynamiques
#     Variations de structure : CNV, inversions et remaniements
#   Effets fonctionnels des variants et mécanismes pathogènes
#   Variabilité populationnelle et bases de données génomiques
# Evolution des génomes : notions essentielles et exemples
#   Principes fondamentaux de l'évolution génomique
#   Mécanismes de diversification et duplication génomique
#     Duplication d'exons et ses conséquences protéiques
#     Brassage d'exons (exon shuffling) et réarrangements
#     Duplication de gènes : scénarios évolutifs
#     Duplication complète du génome et conséquences
# Crédits, références et mentions légales du cours

# %%
print(course.print_content())
# Out:
# Course Content:
# ============================================================
#
# [Root] ID: SEC_1
# Title: Introduction, objectifs et plan du cours
# Content:
#   [1] Ce module s'intègre à l'UE2 « Les molécules du vivant » et porte sur
#       l'organisation du génome humain ainsi que sur les méthodes en
#       biotechnologie qui permettent son exploration. Il est présenté par Jean
#       Muller du Laboratoire Diagnostic Génétique et du Laboratoire de Génétique
#       Médicale (Inserm U1112) et s'appuie sur des ressources expérimentales et
#       informatiques actuelles.
#   [2] L'objectif central du cours est d'apporter une compréhension systématique
#       de l'architecture du génome humain, de la distinction entre génome
#       nucléaire et mitochondrial, de la structure des gènes, des éléments
#       répétitifs, des pseudogènes et des éléments non codants, ainsi que des
#       types de variations et de leur impact fonctionnel et évolutif.
#   [3] Le cours se déroule selon un plan progressif qui commence par une
#       introduction conceptuelle, enchaîne sur les notions fondamentales en
#       biologie moléculaire et évolutive, présente le projet de séquençage humain
#       et l'architecture globale des génomes, décrit en détail les constituants
#       génomiques et leurs comparaisons inter-espèces, puis aborde la variabilité
#       et l'évolution des génomes.
#
#   [Level 1] ID: SEC_1.1
#   Title: Présentation et introduction au module
#   Content:
#     [1] Cette introduction situe le module dans le parcours d'enseignement et
#         précise ses finalités pédagogiques : fournir des bases solides sur la
#         structure et la dynamique des génomes et permettre la lecture critique
#         des données génomiques. Le module vise à combiner connaissances
#         théoriques et compétences pratiques de lecture d'annotations et
#         d'interprétation de variants.
#     [2] Les étudiants sont invités à mobiliser des acquis en biologie
#         moléculaire de base et en génétique et à se familiariser avec des outils
#         de navigation génomique. Les attentes incluent la capacité à décrire
#         l'organisation des éléments génomiques, à comprendre les principales
#         méthodes de séquençage et d'annotation, et à interpréter les
#         conséquences des variations génomiques.
#
# [Root] ID: SEC_2
# Title: Notions fondamentales en biologie évolutive et moléculaire
# Content:
#   [1] Les concepts fondamentaux de l'évolution — temps, adaptation et sélection
#       — forment le cadre pour comprendre la diversité et la conservation des
#       génomes. L'arbre du vivant illustre les relations de parenté entre
#       organismes actuels et leur ancêtre commun, souvent résumé par l'acronyme
#       LUCA (Last Universal Common Ancestor).
#   [2] Relier la biologie moléculaire à l'évolution permet d'interpréter pourquoi
#       certaines séquences sont conservées, comment des innovations moléculaires
#       apparaissent, et quels mécanismes génèrent la diversité génétique observée
#       dans et entre les espèces.
#
#   [Level 1] ID: SEC_2.1
#   Title: Arbre du vivant et organismes modèles
#   Content:
#     [1] L'arbre des eucaryotes sert de repère pour choisir des organismes
#         modèles adaptés à des questions biologiques précises. Le choix d'un
#         modèle repose sur des critères économiques, techniques, sur la facilité
#         d'hébergement, sur le temps de génération et sur la pertinence du
#         développement embryonnaire pour l'objet d'étude.
#     [2] Les organismes modèles partagent des éléments génomiques communs qui
#         facilitent les extrapolations comparatives, mais ils présentent aussi
#         des spécificités importantes ; la stratégie expérimentale doit donc être
#         adaptée au contexte biologique étudié. Dans la pratique, des panels
#         d'une trentaine d'eucaryotes et d'une vingtaine de métazoaires servent à
#         couvrir une large palette de traits et de phylums.
#     [3] L'utilisation d'organismes modèles permet d'accélérer la compréhension
#         des mécanismes moléculaires conservés et des adaptations propres à des
#         lignées particulières, tout en fournissant des systèmes expérimentaux
#         manipulables pour tester des hypothèses évolutives.
#
#   [Level 1] ID: SEC_2.2
#   Title: Homologie et comparaison de séquences
#   Content:
#     [1] En biologie évolutive et moléculaire, l'homologie désigne un caractère
#         partagé par plusieurs espèces parce qu'il hérite d'un ancêtre commun ;
#         elle s'applique aux structures anatomiques, aux protéines et aux
#         séquences d'ADN. Il est important de distinguer homologie et analogie,
#         cette dernière résultant d'une convergence évolutive indépendante.
#     [2] On distingue des relations évolutives particulières : l'orthologie
#         concerne des gènes homologues séparés par un événement de spéciation et
#         généralement conservant une fonction similaire, tandis que la paralogie
#         désigne des gènes homologues résultant d'une duplication dans une même
#         lignée et pouvant évoluer vers des fonctions distinctes.
#     [3] La détermination empirique de l'homologie repose sur l'alignement des
#         séquences d'ADN ou de protéines et sur le calcul de métriques telles que
#         le pourcentage d'identité et de similarité. Des seuils de
#         significativité sont utiles mais dépendants des familles protéiques ;
#         des valeurs faibles d'identité ne signent pas nécessairement l'absence
#         d'homologie.
#     [4] Il convient d'interpréter les similarités avec prudence car des
#         ressemblances peuvent résulter du hasard dans des régions de faible
#         complexité, ou de convergence évolutive. Un exemple pédagogique montre
#         que deux protéines peuvent avoir une identité très faible tout en étant
#         morphologiquement ou fonctionnellement proches, illustrant les limites
#         des seules comparaisons numériques.
#
#   [Level 1] ID: SEC_2.3
#   Title: Biologie du gène et dogme central
#   Content:
#     [1] Le dogme central de la biologie moléculaire synthétise le flux
#         d'information génétique : l'ADN est transcrit en ARN, qui est traduit en
#         protéines pour les gènes codants. Cette cascade reste le cadre
#         conceptuel permettant de relier la séquence génomique aux fonctions
#         cellulaires et phénotypiques.
#     [2] Le génome s'intègre à un ensemble d'analyses 'omiques' complémentaires —
#         transcriptome, protéome, méthylome, etc. — qui fournissent des
#         références multidimensionnelles pour caractériser l'état et la
#         régulation d'un organisme au-delà de sa simple séquence d'ADN.
#
# [Root] ID: SEC_3
# Title: Le génome humain : composition et ressources majeures
# Content:
#   [1] Le génome humain constitue l'ensemble des séquences d'ADN caractéristiques
#       de l'espèce Homo sapiens et regroupe le génome nucléaire ainsi que le
#       génome mitochondrial. Sa connaissance détaillée repose sur des projets de
#       séquençage massif, des bases de données et des navigateurs génomiques qui
#       centralisent annotations et ressources fonctionnelles.
#   [2] Comprendre la composition du génome implique d'aborder son organisation en
#       chromosomes, la distinction entre régions actives et silencieuses, ainsi
#       que l'utilisation d'outils informatiques (genome browsers) pour visualiser
#       gènes, transcrits, éléments répétitifs et traces de conservation
#       évolutive.
#
#   [Level 1] ID: SEC_3.1
#   Title: Présentation générale et nomenclature du génome
#   Content:
#     [1] Le génome humain comprend un génome nucléaire constitué de 22 paires
#         d'autosomes et d'une paire de chromosomes sexuels (X et Y), ainsi qu'un
#         génome mitochondrial circulaire distinct. Le génome mitochondrial, peu
#         volumineux, coexiste avec le génome nucléaire et répond à des règles
#         d'hérédité différentes.
#     [2] La distinction haploïde / diploïde traduit l'existence de jeux de
#         chromosomes simples ou doublés dans les cellules somatiques, et la
#         nomenclature chromosomique classique (par exemple la nomenclature de
#         Paris, 1971) fournit un cadre standardisé pour référencer les
#         chromosomes et leurs anomalies.
#     [3] Il est utile de rappeler que la présentation schématique des chromosomes
#         condensés en métaphase diffère de leur organisation dans le noyau en
#         interphase ; la compaction et la topologie nucléaire influencent
#         l'accessibilité de la chromatine et la régulation transcriptionnelle.
#
#   [Level 1] ID: SEC_3.2
#   Title: Projet de séquençage et historique du génome humain
#   Content:
#     [1] Le séquençage du génome humain a été porté par un projet international
#         lancé au début des années 1990, mobilisant une dizaine de milliards de
#         dollars au sens large et des consortiums internationaux, avec un
#         objectif majeur d'obtenir la séquence de l'euchromatine. Les travaux de
#         cartographie et de séquençage ont mobilisé des approches complémentaires
#         et des centres répartis dans plusieurs pays.
#     [2] La cartographie génétique, fondée sur les fréquences de recombinaison
#         exprimées en centimorgans, et la cartographie physique, mesurée en
#         kilobases ou mégabases, ont préparé les étapes de séquençage et
#         d'assemblage. Les premiers grands jalons incluent la publication d'un
#         brouillon vers l'an 2000 puis d'une version finalisée à haute qualité en
#         2003.
#     [3] L'aventure n'a pas été strictement linéaire : des régions répétées et
#         complexes ont demandé des approches complémentaires et des améliorations
#         technologiques, et des refinements et réassemblages ultérieurs
#         (notamment avec des technologies longues) ont permis d'augmenter la
#         complétude et la qualité des génomes de référence.
#
#   [Level 1] ID: SEC_3.3
#   Title: Visualisation, annotation et navigation dans le génome
#   Content:
#     [1] Les genome browsers, tels que le navigateur UCSC, sont des outils
#         essentiels pour la visualisation intégrée des annotations génomiques :
#         ils permettent de superposer pistes de gènes, protéines, niveaux de
#         conservation et autres données fonctionnelles. La capacité de zoomer du
#         chromosome à la structure d'un gène facilite l'interprétation des
#         éléments annotés.
#     [2] La navigation dans ces interfaces met en évidence des attributs comme le
#         sens de transcription, la position des exons et des introns, et les
#         régions régulatrices. Une lecture attentive des pistes d'annotation et
#         une compréhension des coordonnées génomiques sont indispensables pour
#         interpréter les effets potentiels de variations identifiées au niveau
#         d'un locus.
#     [3] Les annotations étant progressivement améliorées, il faudra garder à
#         l'esprit l'existence de multiples référentiels et versions de génome de
#         référence, et toujours vérifier l'origine et la date des annotations
#         utilisées lors d'analyses ou d'analyses cliniques.
#
#   [Level 1] ID: SEC_3.4
#   Title: Unités de base et conservation génomique
#   Content:
#     [1] Les nucléotides forment l'unité de base de l'ADN et, par triplets,
#         codent les acides aminés qui constituent les protéines ; ces unités sont
#         traitées différemment selon qu'elles appartiennent à des régions
#         codantes ou régulatrices. La compréhension du lien entre séquence et
#         fonction nécessite la maîtrise de cette correspondance fondamentale
#         entre nucléotides et acides aminés.
#     [2] Une fraction limitée du génome humain — de l'ordre de quelques pourcents
#         — est hautement conservée au cours de l'évolution, ce qui reflète
#         l'existence d'éléments fonctionnels contraints. L'analyse de
#         conservation comparative est donc un outil puissant pour détecter
#         régions codantes et éléments régulateurs d'importance biologique.
#
#   [Level 1] ID: SEC_3.5
#   Title: Génome mitochondrial : structure et caractéristiques principales
#   Content:
#     [1] Le génome mitochondrial humain est un petit génome circulaire de 16,6
#         kilobases qui contient 37 gènes au total, dont treize codent pour des
#         protéines impliquées dans la phosphorylation oxydative et vingt-quatre
#         correspondent à des ARN (22 ARNt et 2 ARNr). Sa compacité et sa
#         composition en font un modèle contrasté avec le génome nucléaire.
#     [2] Le génome mitochondrial présente des particularités rappelant ses
#         origines endosymbiotiques : organisation proche de celle de certaines
#         bactéries, code génétique légèrement décalé pour quelques codons, et
#         transmission essentiellement maternelle. Les cellules contiennent de
#         nombreuses copies de l'ADN mitochondrial, et la coexistence de
#         différentes versions dans une même cellule (hétéroplasmie) varie selon
#         le tissu et l'âge.
#     [3] La comparaison des génomes mitochondriaux entre espèces met en évidence
#         une variation en taille et en organisation, tout en soulignant la
#         conservation fonctionnelle de gènes essentiels, ce qui fait du génome
#         mitochondrial un marqueur utile en phylogénie et en études évolutives.
#
#   [Level 1] ID: SEC_3.6
#   Title: Génome nucléaire : taille, euchromatine et hétérochromatine
#   Content:
#     [1] Le génome nucléaire haploïde humain est d'environ 3,1 gigabases ; il a
#         fait l'objet d'une première disponibilité sous forme de brouillon autour
#         de 2001 et d'améliorations successives qui ont rapproché la référence
#         d'une complétude élevée au cours des années récentes. La composition en
#         régions euchromatiques et hétérochromatiques reflète une organisation
#         fonctionnelle et structurale du noyau.
#     [2] L'euchromatine, d'environ 2,9 Gb, est relativement riche en gènes et
#         accessible à la machinerie transcriptionnelle, tandis que
#         l'hétérochromatine constitutive, d'environ 0,2 Gb, est plus condensée,
#         peu transcrite et souvent peuplée d'éléments hautement répétitifs. Cette
#         dichotomie influence la distribution des fonctions et la dynamique
#         génomique.
#
#   [Level 1] ID: SEC_3.7
#   Title: Éléments constitutifs du génome humain
#   Content:
#     [1] Le génome humain est composé d'un mélange ordonné d'unités
#         fonctionnelles et structurelles : gènes codants, ARN non codants,
#         pseudogènes, éléments répétés en tandem et dispersés, et régions
#         régulatrices. Chacun de ces constituants joue un rôle distinct dans
#         l'organisation, la régulation et l'évolution du génome.
#     [2] Les sections suivantes détaillent la définition et les caractéristiques
#         des gènes codants et non codants, la nature et l'origine des
#         pseudogènes, ainsi que la diversité et le rôle évolutif des éléments
#         répétitifs.
#
#     [Level 2] ID: SEC_3.7.1
#     Title: Gènes : définition, nombres et caractéristiques
#     Content:
#       [1] Un gène est défini comme un segment d'ADN utilisé comme matrice pour
#           la synthèse d'un ARN monocaténaire ; cet ARN peut être codant (ARNm)
#           et porter l'information pour la synthèse protéique, ou non codant et
#           participer à diverses fonctions cellulaires (ARNt, ARNr, miARN,
#           lncARN, snARN, snoARN, etc.).
#       [2] Les estimations contemporaines suggèrent environ 20 000 gènes codants
#           et plus de 40 000 gènes non codants, donnant un ordre de grandeur du
#           nombre total de loci transcrits proche de 60 000 ; ces chiffres
#           restent susceptibles d'ajustements à mesure que les annotations
#           s'affinent.
#       [3] La taille des gènes est très variable : la taille moyenne est de
#           l'ordre de quelques dizaines de kilobases, mais des gènes peuvent être
#           extrêmement compacts ou, à l'inverse, se répartir sur plusieurs
#           mégabases comme le gène DMD (dystrophine). Les protéines issues des
#           gènes présentent elles aussi une large gamme de tailles, de quelques
#           dizaines d'acides aminés à des protéines gigantesques comme la titine.
#       [4] La structure intron/exon varie largement d'un gène à l'autre ; en
#           moyenne, un gène humain comporte plusieurs exons de quelques centaines
#           de nucléotides, séparés par des introns dont la longueur peut aller de
#           quelques dizaines de bases à plusieurs kilobases, voire plus.
#
#     [Level 2] ID: SEC_3.7.2
#     Title: Organisation des gènes et exemples de clusters
#     Content:
#       [1] Les gènes peuvent présenter des architectures très diverses : certains
#           sont isolés dans des territoires génomiques distincts tandis que
#           d'autres forment des clusters résultant de duplications en tandem. Des
#           exemples concrets illustrent cette diversité, avec des gènes
#           comportant peu d'exons et des CDS courts ou des gènes très ramifiés et
#           étendus en introns et exons.
#       [2] Dans les régions non regroupées, on observe parfois des agencements
#           complexes avec chevauchements et orientations variables, ce qui
#           complique l'annotation et la compréhension fonctionnelle. À l'inverse,
#           les clusters de gènes provenant de duplications partagent souvent
#           l'orientation de transcription, des similarités de séquence et la
#           présence de pseudogènes associés.
#       [3] Quelques familles exemplaires montrent ces organisations remarquables
#           : la famille des gènes d'histones, abondante et clusterisée, et le
#           répertoire des récepteurs olfactifs, riche en copies et réparti en de
#           nombreux grands clusters, illustrent respectivement des fonctions
#           cellulaires fondamentales et des expansions adaptatives.
#
#     [Level 2] ID: SEC_3.7.3
#     Title: ARN non codants : classes et fonctions principales
#     Content:
#       [1] Les ARN non codants couvrent des classes fonctionnelles variées : les
#           ARN de transfert (ARNt) assurent l'appariement codon-acide aminé lors
#           de la traduction, les ARN ribosomaux (ARNr) sont des composants
#           essentiels du ribosome, et d'autres ARN non codants (miARN, lncARN,
#           snARN, snoARN) participent à la régulation, l'épissage et la
#           maturation des ARN.
#       [2] Le génome humain contient plusieurs centaines de gènes codant des ARNt
#           et de nombreuses copies ou répétitions pour les ARNr (par exemple des
#           unités 45S répétées plusieurs dizaines de fois). La nature répétitive
#           et l'organisation en clusters de ces gènes rendent leur quantification
#           et leur annotation plus difficiles que celles des gènes codants
#           classiques.
#
#     [Level 2] ID: SEC_3.7.4
#     Title: Pseudogènes : origines et remarques fonctionnelles principales
#     Content:
#       [1] Les pseudogènes sont des copies de gènes qui ont perdu, partiellement
#           ou totalement, la capacité de produire une protéine fonctionnelle
#           similaire à l'original ; ils partagent cependant une similarité de
#           séquence significative avec leur gène parent. On dénombre plusieurs
#           milliers de pseudogènes dans le génome humain, répartis en catégories
#           principales : pseudogènes « processés », non processés et unitaires.
#       [2] Les pseudogènes non processés résultent généralement de duplications
#           génomiques et conservent souvent la structure intron/exon et des
#           régions régulatrices initiales, tandis que les pseudogènes processés
#           proviennent de la rétrotranscription d'un ARNm et apparaissent
#           dépourvus d'introns et de régions promotrices. Les pseudogènes
#           unitaires correspondent à la désactivation progressive d'un gène
#           précédemment fonctionnel.
#       [3] Si longtemps considérés comme des fossiles évolutifs sans fonction,
#           les pseudogènes suscitent aujourd'hui l'intérêt car une part
#           significative d'entre eux est transcrite et ils peuvent intervenir
#           dans la régulation des gènes, servir de réservoirs d'innovation ou
#           être impliqués dans des mécanismes d'évolution génomique.
#
#     [Level 2] ID: SEC_3.7.5
#     Title: Éléments répétitifs et transposons : types et rôles
#     Content:
#       [1] Les éléments répétitifs occupent une fraction importante du génome
#           humain ; on distingue les répétitions en tandem (satellites,
#           minisatellites, microsatellites) qui représentent une part notable du
#           génome et contribuent souvent à l'hétérochromatine constitutive, et
#           les éléments dispersés qui forment une portion encore plus importante.
#       [2] Les microsatellites, fréquents et polymorphes, sont disposés tous les
#           quelques dizaines de kilobases en moyenne et ont longtemps été
#           exploités pour le génotypage, la construction de cartes génétiques et
#           les empreintes génétiques en médecine légale.
#       [3] Les éléments dispersés comprennent les rétrotransposons (mécanisme «
#           copié/collé ») et les transposons à ADN (mécanisme « coupé/collé »).
#           Parmi les rétrotransposons, les LINEs (notamment LINE-1) et les SINEs
#           (Alu chez les primates) représentent des familles abondantes ; bien
#           que la plupart de ces copies soient inactives, quelques éléments
#           LINE-1 restent encore potentiellement mobiles et ont un rôle continu
#           dans l'évolution du génome.
#       [4] Les transposons ont laissé de nombreuses traces dans le génome et ont
#           contribué à des réarrangements, à l'innovation génétique et à la
#           modulation de l'expression ; globalement, les éléments répétitifs sont
#           un moteur important de la plasticité génomique, même si la majorité
#           d'entre eux sont aujourd'hui inactifs ou fossiles.
#
#   [Level 1] ID: SEC_3.8
#   Title: Comparaison des génomes : mitochondrial et inter-espèces
#   Content:
#     [1] Le génome nucléaire et le génome mitochondrial se distinguent nettement
#         par leur taille, leur densité en gènes et leur organisation : le génome
#         nucléaire haploïde humain est d'environ 3,1 Gb avec faible proportion
#         codante, tandis que le génome mitochondrial est très compact (~16,6 kb)
#         et à forte densité codante. Le nombre de copies par cellule diffère de
#         façon considérable et la transmission héréditaire suit des modes
#         différents (Mendelien vs maternel).
#     [2] La comparaison inter-espèces met en évidence que la capacité codante
#         n'est pas proportionnelle à la taille du génome ni au nombre de
#         chromosomes ; le nombre de gènes varie selon les taxons et ne reflète
#         pas directement la « complexité » de l'organisme. Des comparaisons avec
#         des espèces modèles (drosophile, levure, plantes, etc.) montrent des
#         distributions variables de taille génomique et de nombre de gènes,
#         illustrant le paradoxe de la taille du génome (C-value).
#     [3] Des relations linéaires existent pour des génomes très compacts, mais
#         pour les eucaryotes supérieurs la corrélation entre taille et nombre de
#         gènes est faible en raison de l'abondance d'éléments répétitifs et
#         d'autres séquences non codantes. Ces constats soulignent l'importance de
#         comparer non seulement la taille mais aussi la composition fonctionnelle
#         et la dynamique évolutive des génomes.
#
# [Root] ID: SEC_4
# Title: Variations du génome humain : types et conséquences
# Content:
#   [1] Le génome humain est l'objet d'une diversité de variations, depuis les
#       substitutions d'une base jusqu'aux remaniements structurels affectant des
#       kilobases à des mégabases. Ces variations peuvent être neutres, bénéfiques
#       ou pathogènes et elles constituent la matière première de l'évolution
#       ainsi que la cause de nombreuses pathologies.
#   [2] L'étude des types de variations et de leurs conséquences nécessite à la
#       fois des méthodes de détection adaptées et des référentiels de
#       nomenclature et d'interprétation pour relier une altération de séquence à
#       un impact fonctionnel ou clinique.
#
#   [Level 1] ID: SEC_4.1
#   Title: Définitions, nomenclature et exemples de variants
#   Content:
#     [1] Le terme « mutation » peut être employé dans un sens biologique général
#         pour désigner toute modification héritée de l'information génétique, ou
#         dans un sens médical pour signifier une modification de séquence
#         associée à un phénotype pathologique. Le terme « polymorphisme » est
#         réservé aux variations fréquentes dans une population (par exemple
#         fréquence ≥ 1 %) et souvent considérées comme bénignes.
#     [2] Les variations peuvent être décrites selon leur taille : les SNV (Single
#         Nucleotide Variations) et les petites insertions/délétions (<50 bases)
#         diffèrent des variations structurales qui affectent des segments plus
#         larges (>50 bases) et incluent les CNV (Copy Number Variants),
#         inversions et translocations. Une nomenclature standardisée (positions
#         génomiques g., codage c. pour ARNm, et p. pour protéine) est nécessaire
#         pour documenter de façon non ambiguë les variants.
#     [3] La représentation des changements protéiques suit des conventions
#         précises (par exemple p.Arg22Ser ou p.Arg22* pour un changement en codon
#         stop) et la notation génotypique permet d'indiquer la présence de
#         plusieurs variations sur un individu, en distinguant leur localisation
#         allélique lorsque l'information est disponible.
#     [4] La fréquence d'un variant dans différentes populations est cruciale pour
#         son interprétation clinique ; des exemples montrent des fréquences très
#         différentes selon les aires géographiques et ethniques, et la notion de
#         variant pathogène dépend du contexte génétique, du mode de transmission
#         (dominant, récessif, lié à l'X) et de la pénétrance.
#
#   [Level 1] ID: SEC_4.2
#   Title: Types moléculaires de variations et mécanismes
#   Content:
#     [1] Les variations moléculaires se répartissent en substitutions,
#         insertions/délétions (indels), mutations affectant l'épissage,
#         expansions répétées (mutations dynamiques) et remaniements de structure
#         (CNV, inversions, translocations). Chacun de ces types résulte de
#         mécanismes cellulaires différents tels que erreurs de réplication,
#         réparation fautive, rétrotransposition ou recombinaison illégitime.
#     [2] L'impact fonctionnel dépend de la localisation du variant (région
#         codante, régulatrice, intronique) et de sa nature moléculaire : une même
#         classe de variant peut être neutre, délétère ou conférer un gain de
#         fonction selon le gène et le contexte biologique.
#
#     [Level 2] ID: SEC_4.2.1
#     Title: Substitutions, insertions et délétions : mécanismes et effets
#     Content:
#       [1] Les substitutions correspondent au remplacement d'une base par une
#           autre et peuvent être classées en transitions (purine↔purine ou
#           pyrimidine↔pyrimidine) et transversions (purine↔pyrimidine). Les
#           insertions et délétions de petite taille (indels) correspondent à
#           l'ajout ou la perte de quelques bases et sont courantes dans le
#           génome.
#       [2] Sur l'ensemble du génome, les substitutions et petits indels
#           constituent la source la plus numérique de variation : on observe
#           généralement plusieurs millions de différences nucléotidiques entre
#           deux génomes humains. Ces variants surviennent partout dans le génome
#           et leur effet dépend fortement de la localisation et du cadre de
#           lecture.
#       [3] Dans les régions codantes, une substitution peut être silencieuse,
#           faux-sens (missense) ou non-sens selon sa conséquence sur le codon et
#           la position dans le triplet ; la position de la base dans le codon
#           influence fortement l'impact conservatoire. De même, une insertion ou
#           une délétion qui n'est pas multiple de trois décalera le cadre de
#           lecture et entraînera souvent une protéine tronquée ou non
#           fonctionnelle, tandis qu'un indel multiple de trois conserve le cadre
#           mais modifie le nombre d'acides aminés.
#       [4] L'interprétation des effets protéiques requiert donc la combinaison de
#           l'information séquentielle, du cadre de lecture et de la connaissance
#           fonctionnelle du domaine affecté.
#
#     [Level 2] ID: SEC_4.2.2
#     Title: Variations d'épissage et conséquences sur les protéines
#     Content:
#       [1] Les sites d'épissage (généralement motifs GT-AG aux jonctions intron-
#           exon et un site de branchement en amont) sont cruciaux pour l'excision
#           correcte des introns ; des variations affectant ces signaux ou des
#           éléments régulateurs d'épissage peuvent perturber la maturation de
#           l'ARN. Les mutations d'épissage entraînent des conséquences variées :
#           rétention complète ou partielle d'intron, saut d'exon ou usage de
#           sites cryptiques.
#       [2] Sur le plan protéique, ces altérations conduisent fréquemment à des
#           décalages du cadre de lecture, à l'introduction de codons stop
#           prématurés ou à la perte d'exons codants essentiels, aboutissant
#           souvent à une protéine non fonctionnelle ou dégradée.
#
#     [Level 2] ID: SEC_4.2.3
#     Title: Expansions de triplets et mutations dynamiques
#     Content:
#       [1] Les expansions de répétitions en tandem de trinucleotides (et parfois
#           de motifs plus longs) constituent des mutations dynamiques qui peuvent
#           s'accroître sur plusieurs générations et provoquer des pathologies.
#           Des exemples bien connus sont la dystrophie liée au X fragilisé (CGG)n
#           et la maladie de Huntington (CAG)n.
#       [2] Ces expansions peuvent se localiser dans des régions 5'UTR, exoniques,
#           introniques ou 3'UTR et leur instabilité au cours de la réplication ou
#           de la réparation de l'ADN explique les phénomènes d'anticipation
#           observés dans certaines maladies héréditaires.
#
#     [Level 2] ID: SEC_4.2.4
#     Title: Variations de structure : CNV, inversions et remaniements
#     Content:
#       [1] Les variations de structure englobent des remaniements génomiques
#           affectant des segments allant de plusieurs dizaines de bases à
#           plusieurs mégabases ; elles incluent des délétions, duplications
#           (CNV), inversions, translocations et insertions d'éléments mobiles.
#           Ces remaniements peuvent être équilibrés (sans perte de matériel) ou
#           déséquilibrés (entraînant une variation du nombre de copies).
#       [2] Au niveau de la variabilité inter-individuelle on estime plusieurs
#           milliers d'événements structuraux entre deux génomes, avec des
#           milliers d'insertions d'éléments mobiles et un nombre significatif de
#           grandes délétions et duplications recensées dans les bases de données.
#           Ces variants affectent souvent un grand nombre de bases et peuvent
#           avoir un impact majeur sur le phénotype si des gènes ou des régions
#           régulatrices sont impliqués.
#       [3] D'autres mécanismes moins fréquents mais importants incluent la
#           conversion génique et l'empreinte parentale (imprinting), qui reposent
#           sur des mécanismes épigénétiques et des échanges entre séquences très
#           homologues ; chaque type de variation structurelle doit être évalué
#           pour sa capacité causale dans une pathologie donnée.
#
#   [Level 1] ID: SEC_4.3
#   Title: Effets fonctionnels des variants et mécanismes pathogènes
#   Content:
#     [1] Les variants peuvent induire une perte de fonction totale ou partielle
#         (par ex. codons stop prématurés, décalages du cadre de lecture),
#         entraînant l'absence ou l'altération de l'activité protéique. Certaines
#         mutations faux-sens peuvent également être sévères si elles perturbent
#         un site actif, une interface de liaison ou la stabilité de la protéine.
#     [2] D'autres mécanismes incluent le gain de fonction, où la protéine
#         acquiert une activité nouvelle ou toxique, et l'effet dominant négatif,
#         où la forme mutée interfère avec la protéine normale produite par
#         l'allèle sain. L'effet phénotypique dépendra du gène concerné, du dosage
#         allélique et du contexte physiologique.
#
#   [Level 1] ID: SEC_4.4
#   Title: Variabilité populationnelle et bases de données génomiques
#   Content:
#     [1] La variabilité du génome humain est vaste ; des ressources publiques
#         cataloguent des centaines de millions à des milliards de variations
#         identifiées à travers diverses populations. Des bases comme dbSNP pour
#         les variants ponctuels et DGV pour les variations structurelles
#         centralisent ces données et fournissent des informations de fréquence
#         essentielles à l'interprétation clinique.
#     [2] L'accès et l'utilisation de ces bases permettent de distinguer variants
#         rares et fréquents, d'identifier des effets fondateurs ou
#         géographiquement localisés et d'évaluer la probabilité qu'un variant
#         observé soit causal pour un phénotype. Ces référentiels sont des outils
#         indispensables pour l'interprétation populationnelle et diagnostique des
#         variants génomiques.
#
# [Root] ID: SEC_5
# Title: Evolution des génomes : notions essentielles et exemples
# Content:
#   [1] L'évolution des génomes est un processus dynamique au cours duquel du
#       matériel génétique est ajouté, perdu ou réarrangé, conduisant à des
#       adaptations ou à des dérives neutres selon les conditions sélectives. Les
#       mécanismes qui y contribuent incluent des substitutions ponctuelles, des
#       insertions/délétions, des duplications et des remaniements structurels.
#   [2] L'analyse évolutive des génomes permet d'identifier des signatures de
#       sélection, d'étudier l'origine des nouveaux éléments fonctionnels et
#       d'expliquer comment des innovations moléculaires ont pu favoriser
#       l'émergence de nouvelles fonctions et, parfois, de nouvelles espèces.
#
#   [Level 1] ID: SEC_5.1
#   Title: Principes fondamentaux de l'évolution génomique
#   Content:
#     [1] Les principes de l'évolution appliqués aux génomes reposent sur la
#         variation aléatoire, la sélection naturelle, la dérive génétique et
#         l'effet du temps ; ces forces produisent des modifications accumulées
#         qui peuvent s'avérer adaptatives ou neutres. Le rôle de la sélection
#         positive est de favoriser des variantes offrant un avantage
#         environnemental, tandis que la dérive peut fixer des variantes neutres
#         dans des populations restreintes.
#     [2] Les génomes évoluent par un ensemble de processus moléculaires concrets
#         — mutations ponctuelles, duplications, réarrangements — qui sont ensuite
#         filtrés par des contraintes fonctionnelles et par l'histoire
#         démographique des populations. Comprendre ces principes est essentiel
#         pour interpréter la répartition des variantes et l'origine des
#         innovations génomiques.
#
#   [Level 1] ID: SEC_5.2
#   Title: Mécanismes de diversification et duplication génomique
#   Content:
#     [1] La duplication de matériel génomique — qu'il s'agisse d'exons, de gènes
#         entiers ou de génomes complets — est un moteur majeur de diversification
#         fonctionnelle. Les duplications en tandem d'exons ou de gènes peuvent
#         générer des domaines répétés au sein des protéines et fournir de la
#         matière première pour l'innovation évolutive.
#     [2] Différents mécanismes aboutissent à des réarrangements et à un brassage
#         des exons (exon shuffling), notamment la recombinaison non allélique et
#         l'action des éléments transposables, facilitant la création de nouvelles
#         architectures protéiques.
#
#     [Level 2] ID: SEC_5.2.1
#     Title: Duplication d'exons et ses conséquences protéiques
#     Content:
#       [1] La duplication en tandem d'exons est un phénomène fréquent qui est
#           détectable dans environ dix pour cent des gènes humains ; elle conduit
#           typiquement à l'apparition de domaines répétitifs au sein des
#           protéines. Ces répétitions de domaines peuvent moduler la fonction, la
#           régulation ou l'interaction protéine-protéine.
#       [2] Au plan moléculaire, ces duplications résultent souvent de
#           recombinaisons inégales ou d'autres erreurs de recombinaison qui
#           laissent des empreintes structurales identifiables dans la séquence
#           génomique. Au fil du temps, les copies peuvent diverger et acquérir
#           des fonctions nouvelles ou redondantes.
#
#     [Level 2] ID: SEC_5.2.2
#     Title: Brassage d'exons (exon shuffling) et réarrangements
#     Content:
#       [1] L'exon shuffling décrit le réarrangement d'exons entre gènes distincts
#           et peut générer des combinaisons de domaines protéiques inédites. Des
#           mécanismes tels que la recombinaison non allélique ou l'intégration
#           via des rétrotransposons (par exemple LINEs) favorisent ces
#           déplacements d'exons.
#       [2] Ce brassage contribue à la modularité des protéines en facilitant
#           l'assemblage de nouvelles architectures fonctionnelles, et il
#           représente une source importante d'innovation évolutive au niveau
#           moléculaire.
#
#     [Level 2] ID: SEC_5.2.3
#     Title: Duplication de gènes : scénarios évolutifs
#     Content:
#       [1] Suite à une duplication de gène, plusieurs trajectoires évolutives
#           sont possibles : la pseudogénisation (perte de fonction d'une copie),
#           la néofonctionnalisation (acquisition d'une nouvelle fonction par une
#           copie) ou la sous-fonctionnalisation (répartition des fonctions
#           ancestrales entre copies).
#       [2] Le devenir d'une duplication dépend de facteurs tels que la pression
#           de sélection, les contraintes fonctionnelles et la balance entre
#           avantage adaptatif et coût métabolique ; ces scénarios expliquent en
#           partie l'expansion des familles géniques et la diversification
#           fonctionnelle observées au cours de l'évolution.
#
#     [Level 2] ID: SEC_5.2.4
#     Title: Duplication complète du génome et conséquences
#     Content:
#       [1] La duplication complète du génome (polyploïdie) a des conséquences
#           profondes sur l'organisation génétique, en introduisant une redondance
#           qui peut favoriser la spéciation et l'innovation fonctionnelle. Après
#           une duplication globale, une fraction des copies peut être conservée
#           pour des fonctions dosage-sensibles, tandis que d'autres copies
#           peuvent dégénérer ou diverger.
#       [2] Des événements de duplication génomique à grande échelle ont été
#           documentés dans l'histoire évolutive de certains groupes et expliquent
#           des architectures génomiques complexes observées notamment chez des
#           plantes et certains ancêtres des vertébrés.
#
# [Root] ID: SEC_6
# Title: Crédits, références et mentions légales du cours
# Content:
#   [1] Certaines illustrations et schémas de ce cours sont adaptées d'ouvrages de
#       référence en biologie moléculaire et génétique médicale (par exemple
#       Alberts et al., Strachan & Read) et d'articles scientifiques dont les
#       références figurent sur les diapos. D'autres ressources visuelles
#       proviennent d'espaces numériques ou sont utilisées sous licences Creative
#       Commons, avec mentions d'attribution appropriées.
#   [2] Des institutions telles que le National Human Genome Research Institute et
#       le Smithsonian National Museum of Natural History, ainsi que des centres
#       de bases de données biologiques (DBCLS), ont fourni des images ou des jeux
#       de données dont l'utilisation est signalée. Les sources exactes et les
#       crédits sont indiqués dans les documents de cours pour chaque illustration
#       empruntée.
#   [3] Mentions légales : l'utilisation des documents de cours est strictement
#       réservée aux étudiants inscrits à l'université de Strasbourg, leur
#       diffusion ou mise en réseau est limitée aux instances autorisées et toute
#       autre exploitation commerciale est interdite. Ces documents sont protégés
#       par les législations françaises et internationales sur le droit d'auteur
#       et la propriété intellectuelle.

# %%
encoder = tiktoken.get_encoding("cl100k_base")  # GPT-4 encoding
text_course_with_slides = str(course)
token_count = len(encoder.encode(text_course_with_slides))
print(token_count)
# Out:
# 3992
